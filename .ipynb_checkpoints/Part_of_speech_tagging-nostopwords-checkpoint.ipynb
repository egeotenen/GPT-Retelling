# %% [markdown]
# ### 0. Initizalize Packages

# %%
#!pip install scipy,seaborn
import seaborn as sns
from scipy.stats import kstest

import pandas as pd
import numpy as np

#!pip install -U plotly
pd.options.plotting.backend = "plotly"

#!pip3 install nltk
import nltk
from nltk import pos_tag
from nltk import word_tokenize
from nltk.corpus import stopwords
from collections import Counter
from nltk.tokenize import word_tokenize, sent_tokenize
from scipy.stats import chi2_contingency

import math
from scipy.stats import shapiro 
from scipy.stats import lognorm
from scipy.stats import mannwhitneyu
import matplotlib.pyplot as plt

#!pip3 install openpyxl
import openpyxl as px
from statsmodels.stats.weightstats import ztest

# %% [markdown]
# ### 0.1. Read Dataset ( N = 114)

# %%
df = pd.read_excel('all_gpt_human_only_text.xlsx')

# %% [markdown]
# ### 0.1.1 Preprocess

# %% [markdown]
# Get rid of extra white spaces

# %%
def strip(dataframe):
    return [s.strip() for s in dataframe]

df= df.apply(strip)

# %% [markdown]
# ## 1. Pos Tagging with Less Category Separate for Each Sentence

# %% [markdown]
# Each story's pos taggings completed separately, and counted for the story itself

# %% [markdown]
# ### 1.1. Preprocess and Tag

# %%
#clean data from stopwords, tokenize it, and tag
punc = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
stop_words = [*set(stopwords.words('english'))]
stop_words.append("n't") # add n't as stopword too


def create_tokenized(text):
    tokenized = word_tokenize(text)
    'tag the tokens'
    tagged = nltk.pos_tag(tokenized)
    
    'Removes stopwords after tagging them'
    to_remove = set()
    for i in range(len(tagged)):
        word = tagged[i][0]
        if word.lower() in stop_words:
            to_remove.add(i)
        else:
            pass

        new_tagged = [tagged[i] for i in range(len(tagged)) if i not in to_remove]        

    return new_tagged

# %%
## Filter and get words as tokens
for column in df.columns:
    df[f'tokenized_{column}'] = df[column].apply(lambda x: create_tokenized(x))

# %% [markdown]
# ### 1.2. Count the pos-tags

# %%
#count the tags
def count_tags(mydata):
    counter_list=[]
    for i in mydata:
        counter_list.append(i[1])

    tag_counts = Counter(counter_list) 
    return tag_counts

# %%
for column in [col for col in df.columns if col.startswith('tokenized_')]:
    df[f'{column}_tag_counts'] = df[column].apply(lambda x: count_tags(x))

# %% [markdown]
# ### 1.3. Merge relevant categories together

# %% [markdown]
# Count tags for all nouns (plural nouns, proper nouns etc.), verbs, adjectives, adverbs, pronouns and prepositions/conjuctions/determiners

# %%
for column in [col for col in df.columns if col.endswith('tag_counts')]:
    df[f'{column[:-7]}_noun'] = [*(df[column].apply(lambda x: (x['NN'] + x['NNS'] + x['NNP']+ x['NNPS'])))]
    df[f'{column[:-7]}_verb'] = [*(df[column].apply(lambda x: (x['VB'] + x['VBN'] + x['VBG']+ x['VBZ'] + x['VBP']+x['VBD'])))]
    df[f'{column[:-7]}_adj'] = [*(df[column].apply(lambda x: (x['JJ'] + x['JJS'] + x['JJR'])))]
    df[f'{column[:-7]}_adv'] = [*(df[column].apply(lambda x: (x['RB'] + x['RBR'] + x['WRB'] +x['RBS'])))]
    df[f'{column[:-7]}_pron'] = [*(df[column].apply(lambda x: (x['PRP'] + x['PRP$'] + x['WB']+ x['WB$'])))]
    df[f'{column[:-7]}_con_det_prep'] = [*(df[column].apply(lambda x: (x['DT'] + x['IN'] + x['UH']+ x['TO']+ x['WDT']+ x['EX'])))]
    df[f'{column[:-7]}_prep'] = [*(df[column].apply(lambda x: (x['IN'])))]

# %%
df['tokenized_GPT_R3'].apply(lambda x: len(x))
df.tokenized_GPT_R3_tag_noun
# Out:
# 0      15
# 1      12
# 2      11
# 3       9
# 4      10
#        ..
# 111    13
# 112     7
# 113    12
# 114    11
# 115    11
# Name: tokenized_GPT_R3_tag_noun, Length: 116, dtype: int64

# %% [markdown]
# ## 1.4. Get Ratio of Grammatical Categories to Word Count

# %%
cols = [('tokenized_GPT_R3', 'GPT_3'), 
        ('tokenized_GPT_R2', 'GPT_2'), 
        ('tokenized_GPT_R1', 'GPT_1'), 
        ('tokenized_Retell_1', 'Retell_1'), 
        ('tokenized_Retell_2', 'Retell_2'), 
        ('tokenized_Retell_3', 'Retell_3'), 
        ('tokenized_STORY', 'story')]

# Define a list of tuples with the tag types and their corresponding suffixes
tag_types = [('tag_noun', 'noun'), 
             ('tag_verb', 'verb'), 
             ('tag_adj', 'adj'), 
             ('tag_adv', 'adv'), 
             ('tag_con_det_prep', 'con_det_prep'), 
             ('tag_pron', 'pron'), 
             ('tag_prep', 'prep')]

# Loop over each tag type
for tag_type, suffix in tag_types:
    # Loop over each column and calculate the corresponding tag ratio
    for col, col_suffix in cols:
        tag_col = col + '_' + tag_type
        ratio_col = col_suffix + '_' + suffix + '_ratio'
        df[ratio_col] = df[tag_col] / df[col].apply(len)
# Out:
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_5300/4017749826.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[ratio_col] = df[tag_col] / df[col].apply(len)
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_5300/4017749826.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[ratio_col] = df[tag_col] / df[col].apply(len)
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_5300/4017749826.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[ratio_col] = df[tag_col] / df[col].apply(len)
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_5300/4017749826.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[ratio_col] = df[tag_col] / df[col].apply(len)
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_5300/4017749826.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[ratio_col] = df[tag_col] / df[col].apply(len)
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_5300/4017749826.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[ratio_col] = df[tag_col] / df[col].apply(len)
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_5300/4017749826.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[ratio_col] = df[tag_col] / df[col].apply(len)
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_5300/4017749826.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[ratio_col] = df[tag_col] / df[col].apply(len)
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_5300/4017749826.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[ratio_col] = df[tag_col] / df[col].apply(len)
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_5300/4017749826.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[ratio_col] = df[tag_col] / df[col].apply(len)
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_5300/4017749826.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[ratio_col] = df[tag_col] / df[col].apply(len)
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_5300/4017749826.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[ratio_col] = df[tag_col] / df[col].apply(len)
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_5300/4017749826.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[ratio_col] = df[tag_col] / df[col].apply(len)

# %% [markdown]
# ### 1.4.1. Carry counts and ratios into different DataFrame

# %%
count_ratio = pd.DataFrame

count_ratio= df[['GPT_3_noun_ratio',
 'GPT_2_noun_ratio',
 'GPT_1_noun_ratio',
 'Retell_1_noun_ratio',
 'Retell_2_noun_ratio',
 'Retell_3_noun_ratio',
 'story_noun_ratio',
 'GPT_3_verb_ratio',
 'GPT_2_verb_ratio',
 'GPT_1_verb_ratio',
 'Retell_1_verb_ratio',
 'Retell_2_verb_ratio',
 'Retell_3_verb_ratio',
 'story_verb_ratio',
 'GPT_3_adj_ratio',
 'GPT_2_adj_ratio',
 'GPT_1_adj_ratio',
 'Retell_1_adj_ratio',
 'Retell_2_adj_ratio',
 'Retell_3_adj_ratio',
 'story_adj_ratio',
 'GPT_3_adv_ratio',
 'GPT_2_adv_ratio',
 'GPT_1_adv_ratio',
 'Retell_1_adv_ratio',
 'Retell_2_adv_ratio',
 'Retell_3_adv_ratio',
 'story_adv_ratio',
 'GPT_3_con_det_prep_ratio',
 'GPT_2_con_det_prep_ratio',
 'GPT_1_con_det_prep_ratio',
 'Retell_1_con_det_prep_ratio',
 'Retell_2_con_det_prep_ratio',
 'Retell_3_con_det_prep_ratio',
 'story_con_det_prep_ratio',
 'GPT_3_pron_ratio',
 'GPT_2_pron_ratio',
 'GPT_1_pron_ratio',
 'Retell_1_pron_ratio',
 'Retell_2_pron_ratio',
 'Retell_3_pron_ratio',
 'story_pron_ratio',
 'GPT_3_prep_ratio',
 'GPT_2_prep_ratio',
 'GPT_1_prep_ratio',
 'Retell_1_prep_ratio',
 'Retell_2_prep_ratio',
 'Retell_3_prep_ratio',
 'story_prep_ratio']]

# %%
#store counts into a dataframe 
counts = pd.DataFrame()

df_count = df[['tokenized_STORY_tag_noun',
 'tokenized_STORY_tag_verb',
 'tokenized_STORY_tag_adj',
 'tokenized_STORY_tag_adv',
 'tokenized_STORY_tag_pron',
 'tokenized_STORY_tag_con_det_prep',
 'tokenized_STORY_tag_prep',
 'tokenized_GPT_R1_tag_noun',
 'tokenized_GPT_R1_tag_verb',
 'tokenized_GPT_R1_tag_adj',
 'tokenized_GPT_R1_tag_adv',
 'tokenized_GPT_R1_tag_pron',
 'tokenized_GPT_R1_tag_con_det_prep',
 'tokenized_GPT_R1_tag_prep',
 'tokenized_GPT_R2_tag_noun',
 'tokenized_GPT_R2_tag_verb',
 'tokenized_GPT_R2_tag_adj',
 'tokenized_GPT_R2_tag_adv',
 'tokenized_GPT_R2_tag_pron',
 'tokenized_GPT_R2_tag_con_det_prep',
 'tokenized_GPT_R2_tag_prep',
 'tokenized_GPT_R3_tag_noun',
 'tokenized_GPT_R3_tag_verb',
 'tokenized_GPT_R3_tag_adj',
 'tokenized_GPT_R3_tag_adv',
 'tokenized_GPT_R3_tag_pron',
 'tokenized_GPT_R3_tag_con_det_prep',
 'tokenized_GPT_R3_tag_prep',
 'tokenized_Retell_1_tag_noun',
 'tokenized_Retell_1_tag_verb',
 'tokenized_Retell_1_tag_adj',
 'tokenized_Retell_1_tag_adv',
 'tokenized_Retell_1_tag_pron',
 'tokenized_Retell_1_tag_con_det_prep',
 'tokenized_Retell_1_tag_prep',
 'tokenized_Retell_2_tag_noun',
 'tokenized_Retell_2_tag_verb',
 'tokenized_Retell_2_tag_adj',
 'tokenized_Retell_2_tag_adv',
 'tokenized_Retell_2_tag_pron',
 'tokenized_Retell_2_tag_con_det_prep',
 'tokenized_Retell_2_tag_prep',
 'tokenized_Retell_3_tag_noun',
 'tokenized_Retell_3_tag_verb',
 'tokenized_Retell_3_tag_adj',
 'tokenized_Retell_3_tag_adv',
 'tokenized_Retell_3_tag_pron',
 'tokenized_Retell_3_tag_con_det_prep',
 'tokenized_Retell_3_tag_prep']

]

# %% [markdown]
# Our dataframes are:
#
# 1-count = df_count
# 2- ratio = count_ratio

# %% [markdown]
# ### 1.5. Significance Test Between Retellings (Counts of Words)

# %%
mannwhitneyu(df_count['tokenized_GPT_R3_tag_con_det_prep'], df_count['tokenized_Retell_3_tag_con_det_prep']) #significant
# Out:
# MannwhitneyuResult(statistic=5917.0, pvalue=0.041110994337190315)

# %%
shapiro(df_count) #data is not normal, so we will use Mann-u Whitney
# Out:
# /Users/eotenen/mambaforge/lib/python3.10/site-packages/scipy/stats/_morestats.py:1816: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# ShapiroResult(statistic=0.6938356161117554, pvalue=0.0)

# %%
tags = ['noun', 'verb', 'adj', 'adv', 'pron', 'con_det_prep', 'prep']

for tag in tags:
    for i in range(1, 4):
        gpt_tag = f"tokenized_GPT_R{i}_tag_{tag}"
        retell_tag = f"tokenized_Retell_{i}_tag_{tag}"
        
        p_value = mannwhitneyu(df_count[gpt_tag], df_count[retell_tag])[1]
        if p_value < 0.05:
            print(f"{tag.capitalize()}s in GPT_R{i} and Retell_{i} are significantly different (p-value={p_value:.3f}), gpt= {df_count[gpt_tag].mean()}, human= {df_count[retell_tag].mean()}.")
        else:
            print(f"{tag.capitalize()}s in GPT_R{i} and Retell_{i} are not significantly different (p-value={p_value:.3f}), gpt= {df_count[gpt_tag].mean()}, human= {df_count[retell_tag].mean()}.")
    print("")
# Out:
# Nouns in GPT_R1 and Retell_1 are significantly different (p-value=0.020), gpt= 13.28448275862069, human= 15.793103448275861.
# Nouns in GPT_R2 and Retell_2 are not significantly different (p-value=0.814), gpt= 11.741379310344827, human= 12.120689655172415.
# Nouns in GPT_R3 and Retell_3 are significantly different (p-value=0.000), gpt= 10.655172413793103, human= 9.422413793103448.
#
# Verbs in GPT_R1 and Retell_1 are significantly different (p-value=0.000), gpt= 7.974137931034483, human= 10.862068965517242.
# Verbs in GPT_R2 and Retell_2 are significantly different (p-value=0.015), gpt= 6.577586206896552, human= 8.120689655172415.
# Verbs in GPT_R3 and Retell_3 are not significantly different (p-value=0.581), gpt= 5.956896551724138, human= 6.603448275862069.
#
# Adjs in GPT_R1 and Retell_1 are significantly different (p-value=0.014), gpt= 3.3017241379310347, human= 4.112068965517241.
# Adjs in GPT_R2 and Retell_2 are not significantly different (p-value=0.409), gpt= 3.0344827586206895, human= 2.8793103448275863.
# Adjs in GPT_R3 and Retell_3 are significantly different (p-value=0.005), gpt= 2.6724137931034484, human= 2.2327586206896552.
#
# Advs in GPT_R1 and Retell_1 are significantly different (p-value=0.000), gpt= 1.3448275862068966, human= 2.4827586206896552.
# Advs in GPT_R2 and Retell_2 are significantly different (p-value=0.000), gpt= 0.9913793103448276, human= 1.6896551724137931.
# Advs in GPT_R3 and Retell_3 are significantly different (p-value=0.005), gpt= 0.8620689655172413, human= 1.4913793103448276.
#
# Prons in GPT_R1 and Retell_1 are significantly different (p-value=0.045), gpt= 0.0, human= 0.034482758620689655.
# Prons in GPT_R2 and Retell_2 are not significantly different (p-value=0.083), gpt= 0.0, human= 0.02586206896551724.
# Prons in GPT_R3 and Retell_3 are not significantly different (p-value=0.322), gpt= 0.0, human= 0.008620689655172414.
#
# Con_det_preps in GPT_R1 and Retell_1 are not significantly different (p-value=0.270), gpt= 0.39655172413793105, human= 0.5862068965517241.
# Con_det_preps in GPT_R2 and Retell_2 are not significantly different (p-value=0.264), gpt= 0.3103448275862069, human= 0.4224137931034483.
# Con_det_preps in GPT_R3 and Retell_3 are significantly different (p-value=0.041), gpt= 0.2413793103448276, human= 0.43103448275862066.
#
# Preps in GPT_R1 and Retell_1 are not significantly different (p-value=0.270), gpt= 0.33620689655172414, human= 0.47413793103448276.
# Preps in GPT_R2 and Retell_2 are not significantly different (p-value=0.770), gpt= 0.27586206896551724, human= 0.3275862068965517.
# Preps in GPT_R3 and Retell_3 are not significantly different (p-value=0.093), gpt= 0.19827586206896552, human= 0.3448275862068966.

# %% [markdown]
# ### 1.6. Visualize Counts

# %% [markdown]
# Prepare dataset accordingly

# %%
count_means = pd.DataFrame()
count_means['mean'] = [*df_count.mean()]
count_means['gen']= ['origin','origin','origin','origin','origin','origin','origin','GPT_R1','GPT_R1','GPT_R1','GPT_R1','GPT_R1','GPT_R1','GPT_R1','GPT_R2','GPT_R2','GPT_R2','GPT_R2','GPT_R2','GPT_R2','GPT_R2','GPT_R3','GPT_R3','GPT_R3','GPT_R3','GPT_R3','GPT_R3','GPT_R3','Retell_1','Retell_1','Retell_1','Retell_1','Retell_1','Retell_1','Retell_1','Retell_2','Retell_2','Retell_2','Retell_2','Retell_2','Retell_2','Retell_2','Retell_3','Retell_3','Retell_3','Retell_3','Retell_3','Retell_3','Retell_3']
count_means['type']= ['noun','verb','adj','adv','pron','con_det_prep','prep','noun','verb','adj','adv','pron','con_det_prep','prep','noun','verb','adj','adv','pron','con_det_prep','prep','noun','verb','adj','adv','pron','con_det_prep','prep','noun','verb','adj','adv','pron','con_det_prep','prep','noun','verb','adj','adv','pron','con_det_prep','prep','noun','verb','adj','adv','pron','con_det_prep','prep']

# %% [markdown]
# #### 1.6.1. First Generation

# %%
first_gen = count_means.loc[count_means['gen'].isin(['GPT_R1', 'Retell_1'])]

sns.lineplot(data=first_gen, x="type", y="mean", hue="gen").set(title='Mean of Grammatical Categories - First Generation')
# Out:
# [Text(0.5, 1.0, 'Mean of Grammatical Categories - First Generation')]

# %% [markdown]
# #### 1.6.2. Second Generation

# %%
second_gen = count_means.loc[count_means['gen'].isin(['GPT_R2', 'Retell_2'])]

sns.lineplot(data=second_gen, x="type", y="mean", hue="gen").set(title='Mean of Grammatical Categories - Second Generation')
# Out:
# [Text(0.5, 1.0, 'Mean of Grammatical Categories - Second Generation')]

# %% [markdown]
# #### 1.6.3. Third Generation

# %%
third_gen = count_means.loc[count_means['gen'].isin(['GPT_R3', 'Retell_3'])]

sns.lineplot(data=third_gen, x="type", y="mean", hue="gen").set(title='Mean of Grammatical Categories - Third Generation')
# Out:
# [Text(0.5, 1.0, 'Mean of Grammatical Categories - Third Generation')]

# %% [markdown]
# #### 1.6.4. All Together

# %%
sns.lineplot(data=count_means, x="type", y="mean", hue="gen")
# Out:
# <Axes: xlabel='type', ylabel='mean'>

# %%
human = count_means.loc[count_means['gen'].isin(['origin','Retell_1', 'Retell_2','Retell_3'])]

sns.lineplot(data=human, x="gen", y="mean", hue="type")
# Out:
# <Axes: xlabel='gen', ylabel='mean'>

# %%
gpt = count_means.loc[count_means['gen'].isin(['origin','GPT_R1', 'GPT_R2','GPT_R3'])]

sns.lineplot(data=gpt, x="gen", y="mean", hue="type")
# Out:
# <Axes: xlabel='gen', ylabel='mean'>

# %% [markdown]
# ### 1.7. Statistical Test for Ratios

# %%
ztest(x1=count_ratio.Retell_3_prep_ratio, x2=count_ratio.GPT_3_prep_ratio, value=0)
# Out:
# (1.8227518361604538, 0.06834098545804342)

# %%
#!pip3 install statsmodels
#Because the values are proportions, I conducted a z-test analysis 

import statsmodels.api as sm

# create a list of tuples for each POS category
pos_categories = [('noun', 'Retell_1_noun_ratio', 'GPT_1_noun_ratio'),
                  ('noun', 'Retell_2_noun_ratio', 'GPT_2_noun_ratio'),
                  ('noun', 'Retell_3_noun_ratio', 'GPT_3_noun_ratio'),
                  ('verb', 'Retell_1_verb_ratio', 'GPT_1_verb_ratio'),
                  ('verb', 'Retell_2_verb_ratio', 'GPT_2_verb_ratio'),
                  ('verb', 'Retell_3_verb_ratio', 'GPT_3_verb_ratio'),
                  ('adj', 'Retell_1_adj_ratio', 'GPT_1_adj_ratio'),
                  ('adj', 'Retell_2_adj_ratio', 'GPT_2_adj_ratio'),
                  ('adj', 'Retell_3_adj_ratio', 'GPT_3_adj_ratio'),
                  ('adv', 'Retell_1_adv_ratio', 'GPT_1_adv_ratio'),
                  ('adv', 'Retell_2_adv_ratio', 'GPT_2_adv_ratio'),
                  ('adv', 'Retell_3_adv_ratio', 'GPT_3_adv_ratio'),
                  ('pron', 'Retell_1_pron_ratio', 'GPT_1_pron_ratio'),
                  ('pron', 'Retell_2_pron_ratio', 'GPT_2_pron_ratio'),
                  ('pron', 'Retell_3_pron_ratio', 'GPT_3_pron_ratio'),
                  ('det_con_prep', 'Retell_1_con_det_prep_ratio', 'GPT_1_con_det_prep_ratio'),
                  ('det_con_prep', 'Retell_2_con_det_prep_ratio', 'GPT_2_con_det_prep_ratio'),
                  ('det_con_prep', 'Retell_3_con_det_prep_ratio', 'GPT_3_con_det_prep_ratio'),
                  ('prep', 'Retell_1_prep_ratio', 'GPT_1_prep_ratio'),
                  ('prep', 'Retell_2_prep_ratio', 'GPT_2_prep_ratio'),
                  ('prep', 'Retell_3_prep_ratio', 'GPT_3_prep_ratio')]

# loop through the list of tuples and conduct the z-tests
for pos_category in pos_categories:
    pos = pos_category[0]
    x1 = pos_category[1]
    x2 = pos_category[2]
    
    print(f" Analysis of {pos}")
    ztest, pval = sm.stats.ztest(count_ratio[x1], count_ratio[x2], value=0)
    if pval < 0.05:
        print(f"Significant difference in {pos} between {[x1], [x2], pval}")
    else:
        print(f"No difference in {pos} {[x1], [x2], pval}")
# Out:
#  Analysis of noun
# Significant difference in noun between (['Retell_1_noun_ratio'], ['GPT_1_noun_ratio'], 0.0030422811017619274)
#  Analysis of noun
# Significant difference in noun between (['Retell_2_noun_ratio'], ['GPT_2_noun_ratio'], 0.011625506578566373)
#  Analysis of noun
# Significant difference in noun between (['Retell_3_noun_ratio'], ['GPT_3_noun_ratio'], 9.792795015637258e-05)
#  Analysis of verb
# No difference in verb (['Retell_1_verb_ratio'], ['GPT_1_verb_ratio'], 0.8353822209560913)
#  Analysis of verb
# No difference in verb (['Retell_2_verb_ratio'], ['GPT_2_verb_ratio'], 0.1955448970443736)
#  Analysis of verb
# Significant difference in verb between (['Retell_3_verb_ratio'], ['GPT_3_verb_ratio'], 0.022301841804994692)
#  Analysis of adj
# No difference in adj (['Retell_1_adj_ratio'], ['GPT_1_adj_ratio'], 0.5417028414469971)
#  Analysis of adj
# Significant difference in adj between (['Retell_2_adj_ratio'], ['GPT_2_adj_ratio'], 0.0356214655126636)
#  Analysis of adj
# Significant difference in adj between (['Retell_3_adj_ratio'], ['GPT_3_adj_ratio'], 0.00429673672355614)
#  Analysis of adv
# Significant difference in adv between (['Retell_1_adv_ratio'], ['GPT_1_adv_ratio'], 0.00020476134139485645)
#  Analysis of adv
# Significant difference in adv between (['Retell_2_adv_ratio'], ['GPT_2_adv_ratio'], 1.264450273738154e-05)
#  Analysis of adv
# Significant difference in adv between (['Retell_3_adv_ratio'], ['GPT_3_adv_ratio'], 2.0884928396375323e-05)
#  Analysis of pron
# No difference in pron (['Retell_1_pron_ratio'], ['GPT_1_pron_ratio'], 0.06553629877303647)
#  Analysis of pron
# No difference in pron (['Retell_2_pron_ratio'], ['GPT_2_pron_ratio'], 0.09615616038621619)
#  Analysis of pron
# No difference in pron (['Retell_3_pron_ratio'], ['GPT_3_pron_ratio'], 0.31731050786291404)
#  Analysis of det_con_prep
# No difference in det_con_prep (['Retell_1_con_det_prep_ratio'], ['GPT_1_con_det_prep_ratio'], 0.564070032410344)
#  Analysis of det_con_prep
# No difference in det_con_prep (['Retell_2_con_det_prep_ratio'], ['GPT_2_con_det_prep_ratio'], 0.5888330942873085)
#  Analysis of det_con_prep
# Significant difference in det_con_prep between (['Retell_3_con_det_prep_ratio'], ['GPT_3_con_det_prep_ratio'], 0.03642364620313398)
#  Analysis of prep
# No difference in prep (['Retell_1_prep_ratio'], ['GPT_1_prep_ratio'], 0.6989738708902107)
#  Analysis of prep
# No difference in prep (['Retell_2_prep_ratio'], ['GPT_2_prep_ratio'], 0.9579110581799213)
#  Analysis of prep
# No difference in prep (['Retell_3_prep_ratio'], ['GPT_3_prep_ratio'], 0.07303403480938406)

# %% [markdown]
# RESULTS:

# %% [markdown]
# ### 1.7.1. Visualize Ratios

# %%
ratio_means = pd.DataFrame()
ratio_means['mean'] = [*count_ratio.mean()]
ratio_means['gen']= ['GPT_3', 'GPT_2','GPT_1', 'Retell_1','Retell_2','Retell_3','origin','GPT_3', 'GPT_2','GPT_1', 'Retell_1','Retell_2','Retell_3','origin','GPT_3', 'GPT_2','GPT_1', 'Retell_1','Retell_2','Retell_3','origin','GPT_3', 'GPT_2','GPT_1', 'Retell_1','Retell_2','Retell_3','origin','GPT_3', 'GPT_2','GPT_1', 'Retell_1','Retell_2','Retell_3','origin','GPT_3', 'GPT_2','GPT_1', 'Retell_1','Retell_2','Retell_3','origin','GPT_3', 'GPT_2','GPT_1', 'Retell_1','Retell_2','Retell_3','origin']
ratio_means['type']= ['noun','noun','noun','noun','noun','noun','noun','verb','verb','verb','verb','verb','verb','verb','adj','adj','adj','adj','adj','adj','adj','adv','adv','adv','adv','adv','adv','adv','con_det_prep','con_det_prep','con_det_prep','con_det_prep','con_det_prep','con_det_prep','con_det_prep','pron','pron','pron','pron','pron','pron','pron','prep','prep','prep','prep','prep','prep','prep']

# %% [markdown]
# #### 1.7.1.1. First Gen

# %%
first_gen = ratio_means.loc[ratio_means['gen'].isin(['GPT_1', 'Retell_1'])]

sns.lineplot(data=first_gen, x="type", y="mean", hue="gen").set(title='Ratio of Grammatical Categories - First Generation')
# Out:
# [Text(0.5, 1.0, 'Ratio of Grammatical Categories - First Generation')]

# %% [markdown]
# #### 1.7.1.2. Second Generation

# %%
second_gen = ratio_means.loc[ratio_means['gen'].isin(['GPT_2', 'Retell_2'])]

sns.lineplot(data=second_gen, x="type", y="mean", hue="gen").set(title='Ratio of Grammatical Categories - Second Generation')
# Out:
# [Text(0.5, 1.0, 'Ratio of Grammatical Categories - Second Generation')]

# %% [markdown]
# #### 1.7.1.3. Second Generation

# %%
third_gen = ratio_means.loc[ratio_means['gen'].isin(['GPT_3', 'Retell_3'])]

sns.lineplot(data=third_gen, x="type", y="mean", hue="gen").set(title='Ratio of Grammatical Categories - Third Generation')
# Out:
# [Text(0.5, 1.0, 'Ratio of Grammatical Categories - Third Generation')]

# %% [markdown]
# #### 1.7.1.4. All Together

# %%
sns.lineplot(data=ratio_means, x="type", y="mean", hue="gen")
# Out:
# <Axes: xlabel='type', ylabel='mean'>

# %%
human = ratio_means.loc[ratio_means['gen'].isin(['origin','Retell_1', 'Retell_2','Retell_3'])]
sns.lineplot(data=human, x="gen", y="mean", hue="type")
# Out:
# <Axes: xlabel='gen', ylabel='mean'>

# %%
gpt = ratio_means.loc[ratio_means['gen'].isin(['origin','GPT_1', 'GPT_2','GPT_3',])]

sns.lineplot(data=gpt, x="gen", y="mean", hue="type")
# Out:
# <Axes: xlabel='gen', ylabel='mean'>

# %% [markdown]
# ### 1.8. Calculate Verb-Adv and Noun-Adj Ratios

# %%
#Adverb-verb ratio
df['story_adv_to_verb_ratio']= df.tokenized_STORY_tag_adv/df.tokenized_STORY_tag_verb
df['Retell_1_adv_to_verb_ratio']= df.tokenized_Retell_1_tag_adv/df.tokenized_Retell_1_tag_verb
df['Retell_2_adv_to_verb_ratio']= df.tokenized_Retell_2_tag_adv/df.tokenized_Retell_2_tag_verb
df['Retell_3_adv_to_verb_ratio']= df.tokenized_Retell_3_tag_adv/df.tokenized_Retell_3_tag_verb
df['GPT_1_adv_to_verb_ratio']= df.tokenized_GPT_R1_tag_adv/df.tokenized_GPT_R1_tag_verb
df['GPT_2_adv_to_verb_ratio']= df.tokenized_GPT_R2_tag_adv/df.tokenized_GPT_R2_tag_verb
df['GPT_3_adv_to_verb_ratio']= df.tokenized_GPT_R3_tag_adv/df.tokenized_GPT_R3_tag_verb

#Adjective-noun ratio
df['story_adj_to_noun_ratio']= df.tokenized_STORY_tag_adj/df.tokenized_STORY_tag_noun
df['Retell_1_adj_to_noun_ratio']= df.tokenized_Retell_1_tag_adj/df.tokenized_Retell_1_tag_noun
df['Retell_2_adj_to_noun_ratio']= df.tokenized_Retell_2_tag_adj/df.tokenized_Retell_2_tag_noun
df['Retell_3_adj_to_noun_ratio']= df.tokenized_Retell_3_tag_adj/df.tokenized_Retell_3_tag_noun
df['GPT_1_adj_to_noun_ratio']= df.tokenized_GPT_R1_tag_adj/df.tokenized_GPT_R1_tag_noun
df['GPT_2_adj_to_noun_ratio']= df.tokenized_GPT_R2_tag_adj/df.tokenized_GPT_R2_tag_noun
df['GPT_3_adj_to_noun_ratio']= df.tokenized_GPT_R3_tag_adj/df.tokenized_GPT_R3_tag_noun

# %% [markdown]
# ### 1.8.2. Visualize Adb/Verb Adj/Noun Ratios

# %% [markdown]
# #### 1.8.2.1. Prepare dataset to visualize

# %%
verbnoun_ratio = df[['story_adv_to_verb_ratio',
 'Retell_1_adv_to_verb_ratio',
 'Retell_2_adv_to_verb_ratio',
 'Retell_3_adv_to_verb_ratio',
 'GPT_1_adv_to_verb_ratio',
 'GPT_2_adv_to_verb_ratio',
 'GPT_3_adv_to_verb_ratio',
 'story_adj_to_noun_ratio',
 'Retell_1_adj_to_noun_ratio',
 'Retell_2_adj_to_noun_ratio',
 'Retell_3_adj_to_noun_ratio',
 'GPT_1_adj_to_noun_ratio',
 'GPT_2_adj_to_noun_ratio',
 'GPT_3_adj_to_noun_ratio']]

# %%
verbnoun_means = pd.DataFrame()
verbnoun_means['mean'] = [*verbnoun_ratio.mean()]

# %%
verbnoun_means['gen'] = ['story','first','second','third','first','second','third','story','first','second','third','first','second','third']
verbnoun_means['type'] = ['origin','human','human','human','gpt','gpt','gpt','origin','human','human','human','gpt','gpt','gpt']
verbnoun_means['ratio'] = ['adv_verb','adv_verb','adv_verb','adv_verb','adv_verb','adv_verb','adv_verb','adj_noun','adj_noun','adj_noun','adj_noun','adj_noun','adj_noun','adj_noun']

# %%
# Adverb to Verb
verbnoun = verbnoun_means.loc[verbnoun_means['type'].isin(['human','gpt']) & verbnoun_means['ratio'].isin(['adv_verb']) ]

sns.lineplot(data=verbnoun, x="gen", y="mean", hue="type").set(title='Adverb to Verb Ratio (Significant All)')
# Out:
# [Text(0.5, 1.0, 'Adverb to Verb Ratio (Significant All)')]

# %%
# Adjective to Noun 
verbnoun = verbnoun_means.loc[verbnoun_means['type'].isin(['human','gpt']) & verbnoun_means['ratio'].isin(['adj_noun']) ]

sns.lineplot(data=verbnoun, x="gen", y="mean", hue="type").set(title='Adjective to Noun Ratio')
# Out:
# [Text(0.5, 1.0, 'Adjective to Noun Ratio')]

# %% [markdown]
# ### 1.8.1. Statistical Test for Adv/verb Adj/noun ratios

# %%
#First
ztest(x1=df.Retell_1_adj_to_noun_ratio, x2=df.GPT_1_adj_to_noun_ratio, value=0)
# Out:
# (1.078378961130782, 0.2808646720696206)

# %%
# Second
ztest(x1=df.Retell_2_adj_to_noun_ratio, x2=df.GPT_2_adj_to_noun_ratio, value=0)
# Out:
# (-0.7839179754790898, 0.4330882415272239)

# %%
# Third 
ztest(x1=df.Retell_3_adj_to_noun_ratio, x2=df.GPT_3_adj_to_noun_ratio, value=0)
# Out:
# (-1.0608020853623932, 0.28877985431875763)

# %%
#Adverb to verb
ztest(x1=df.Retell_1_adv_to_verb_ratio, x2=df.GPT_1_adv_to_verb_ratio, value=0) #significant
ztest(x1=df.Retell_2_adv_to_verb_ratio, x2=df.GPT_2_adv_to_verb_ratio, value=0) #significant
ztest(x1=df.Retell_3_adv_to_verb_ratio, x2=df.GPT_3_adv_to_verb_ratio, value=0) #significant
# Out:
# (3.243233123556205, 0.0011818146944953803)

# %% [markdown]
# ## 2. Pos-Tagging for Overall

# %% [markdown]
# This time all taggings are summed together regardless of their story

# %% [markdown]
# ### 2.1. Preprocess, Tag, Flatten (Get Rid of Stopwords)

# %%
def create_tokenized(text):
    tokenized = word_tokenize(text)
    'tag the tokens'
    tagged = nltk.pos_tag(tokenized)
    stop_words = [*set(stopwords.words('english'))]
    stop_words.append("n't") # add n't as stopword too
    
    'Removes stopwords after tagging them'
    to_remove = set()
    for i in range(len(tagged)):
        word = tagged[i][0]
        if word.lower() in stop_words:
            to_remove.add(i)
        else:
            pass

        new_tagged = [tagged[i] for i in range(len(tagged)) if i not in to_remove]        

    return new_tagged

# %%
def small_post_tagger(dataframe):
    from nltk.tokenize import word_tokenize, sent_tokenize


    story_part_tags = []
    punc = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''

    for text in dataframe:
        for ele in text:
            if ele in punc:
                text = text.replace(ele, "")

        tokenized = word_tokenize(text)
        for i in tokenized:

            # Word tokenizers is used to find the words
            # and punctuation in a string
            wordsList = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(wordsList)
            
            to_remove = set()
            for i in range(len(tagged)):
                word = tagged[i][0]
                if word.lower() in stop_words:
                    to_remove.add(i)
                else:
                    pass

                new_tagged = [tagged[i] for i in range(len(tagged)) if i not in to_remove]  


            story_part_tags.append(new_tagged)
    return story_part_tags

# %%
# Tag small 
story_part_tags_short = small_post_tagger(df['STORY'])
Retell_1_tags_short = small_post_tagger(df['Retell_1'])
Retell_2_tags_short = small_post_tagger(df['Retell_2'])
Retell_3_tags_short = small_post_tagger(df['Retell_3'])
GPT_R1_tags_short = small_post_tagger(df['GPT_R1'])
GPT_R2_tags_short = small_post_tagger(df['GPT_R2'])
GPT_R3_tags_short = small_post_tagger(df['GPT_R3'])

# %%
GPT_R3_tags_short
# Out:
# [[],
#  [('high', 'JJ')],
#  [('school', 'NN')],
#  [('teacher', 'NN')],
#  [('received', 'VBN')],
#  [],
#  [('friend', 'NN')],
#  [('request', 'NN')],
#  [],
#  [('Facebook', 'NN')],
#  [],
#  [('two', 'CD')],
#  [('former', 'JJ')],
#  [('students', 'NNS')],
#  [('Deeps', 'NNS')],
#  [],
#  [('Sravs', 'NN')],
#  [],
#  [('invited', 'VBN')],
#  [],
#  [],
#  [],
#  [('thanksgiving', 'VBG')],
#  [('dinner', 'NN')],
#  [],
#  [],
#  [('attended', 'VBD')],
#  [],
#  [('brought', 'NN')],
#  [('gifts', 'NNS')],
#  [],
#  [],
#  [],
#  [('reunion', 'NN')],
#  [('brought', 'NN')],
#  [('back', 'RB')],
#  [('fond', 'NN')],
#  [('memories', 'NNS')],
#  [],
#  [('emotions', 'NNS')],
#  [],
#  [],
#  [('teacher', 'NN')],
#  [('Abigail', 'NN')],
#  [('baked', 'VBN')],
#  [],
#  [('chocolate', 'NN')],
#  [('cake', 'NN')],
#  [],
#  [('improve', 'VB')],
#  [],
#  [('mood', 'NN')],
#  [],
#  [('gave', 'VBD')],
#  [],
#  [('slice', 'NN')],
#  [],
#  [],
#  [('neighbor', 'NN')],
#  [('Arthur', 'NNP')],
#  [],
#  [('cake', 'NN')],
#  [],
#  [('tasty', 'NN')],
#  [],
#  [],
#  [('made', 'VBN')],
#  [],
#  [],
#  [('happy', 'JJ')],
#  [('Arthur', 'NNP')],
#  [('thanked', 'NNS')],
#  [('Abigail', 'NN')],
#  [],
#  [('praised', 'VBN')],
#  [],
#  [],
#  [],
#  [('delicious', 'JJ')],
#  [('cake', 'NN')],
#  [],
#  [],
#  [('valued', 'VBN')],
#  [],
#  [('friendship', 'NN')],
#  [('Jennifer', 'NN')],
#  [('missed', 'VBN')],
#  [],
#  [],
#  [('seeing', 'VBG')],
#  [],
#  [('favorite', 'NN')],
#  [('punk', 'NN')],
#  [('rock', 'NN')],
#  [('show', 'NN')],
#  [],
#  [],
#  [('went', 'VBD')],
#  [],
#  [],
#  [('venue', 'NN')],
#  [('anyway', 'RB')],
#  [],
#  [('stranger', 'NN')],
#  [('offered', 'VBN')],
#  [],
#  [],
#  [('extra', 'JJ')],
#  [('ticket', 'NN')],
#  [],
#  [],
#  [('went', 'VBD')],
#  [],
#  [],
#  [('show', 'NN')],
#  [('together', 'RB')],
#  [('Jennifer', 'NN')],
#  [],
#  [('ecstatic', 'JJ')],
#  [],
#  [('formed', 'VBN')],
#  [],
#  [('new', 'JJ')],
#  [('friendship', 'NN')],
#  [],
#  [],
#  [('stranger', 'NN')],
#  [('Jeff', 'NN')],
#  [],
#  [('tired', 'VBN')],
#  [],
#  [],
#  [('bullied', 'VBN')],
#  [],
#  [],
#  [],
#  [('good', 'JJ')],
#  [],
#  [('sports', 'NNS')],
#  [],
#  [],
#  [('decided', 'VBD')],
#  [],
#  [('train', 'NN')],
#  [('hard', 'JJ')],
#  [],
#  [('become', 'NN')],
#  [],
#  [('best', 'JJS')],
#  [],
#  [],
#  [('class', 'NN')],
#  [],
#  [],
#  [('year', 'NN')],
#  [],
#  [('hard', 'JJ')],
#  [('work', 'NN')],
#  [],
#  [('succeeded', 'VBN')],
#  [],
#  [],
#  [],
#  [('class', 'NN')],
#  [('sports', 'NNS')],
#  [('competition', 'NN')],
#  [],
#  [],
#  [],
#  [('happy', 'JJ')],
#  [],
#  [],
#  [('achievement', 'NN')],
#  [],
#  [('couple', 'NN')],
#  [('struggled', 'VBN')],
#  [],
#  [('conceive', 'NN')],
#  [],
#  [('child', 'NN')],
#  [],
#  [('almost', 'RB')],
#  [('resorted', 'VBN')],
#  [],
#  [('invitro', 'NN')],
#  [('fertilization', 'NN')],
#  [],
#  [],
#  [('woman', 'NN')],
#  [('got', 'VBD')],
#  [('pregnant', 'NN')],
#  [],
#  [],
#  [('birth', 'NN')],
#  [],
#  [],
#  [('baby', 'NN')],
#  [],
#  [],
#  [('filled', 'VBN')],
#  [],
#  [('love', 'NN')],
#  [],
#  [('pride', 'NN')],
#  [],
#  [],
#  [('child', 'NN')],
#  [],
#  [],
#  [('watched', 'VBN')],
#  [],
#  [('grow', 'NN')],
#  [],
#  [('hiker', 'NN')],
#  [('met', 'NN')],
#  [],
#  [('woman', 'NN')],
#  [],
#  [('shared', 'VBN')],
#  [],
#  [('spicy', 'NN')],
#  [('curry', 'NN')],
#  [],
#  [('flatbread', 'NN')],
#  [('despite', 'IN')],
#  [],
#  [('language', 'NN')],
#  [('barrier', 'NN')],
#  [],
#  [('also', 'RB')],
#  [('offered', 'VBN')],
#  [('water', 'NN')],
#  [],
#  [('leaving', 'VBG')],
#  [('making', 'VBG')],
#  [],
#  [('hiker', 'NN')],
#  [('feel', 'NN')],
#  [('happy', 'JJ')],
#  [],
#  [('person', 'NN')],
#  [('moved', 'VBN')],
#  [],
#  [],
#  [('new', 'JJ')],
#  [('house', 'NN')],
#  [],
#  [],
#  [('hosta', 'NN')],
#  [('plant', 'NN')],
#  [('yard', 'NN')],
#  [('propagated', 'VBN')],
#  [('new', 'JJ')],
#  [('growth', 'NN')],
#  [],
#  [('loves', 'NNS')],
#  [],
#  [('new', 'JJ')],
#  [('colorful', 'NN')],
#  [('plants', 'NNS')],
#  [('However', 'RB')],
#  [],
#  [('plants', 'NNS')],
#  [],
#  [('prone', 'NN')],
#  [],
#  [('dryness', 'NN')],
#  [],
#  [('heat', 'NN')],
#  [],
#  [],
#  [('person', 'NN')],
#  [('needs', 'NNS')],
#  [],
#  [],
#  [('careful', 'NN')],
#  [],
#  [],
#  [('6yearold', 'CD')],
#  [('girl', 'NN')],
#  [],
#  [('excited', 'VBN')],
#  [],
#  [],
#  [('princessthemed', 'VBN')],
#  [('birthday', 'NN')],
#  [('party', 'NN')],
#  [],
#  [],
#  [('family', 'NN')],
#  [],
#  [('helping', 'VBG')],
#  [],
#  [('plan', 'NN')],
#  [],
#  [('grandfather', 'NN')],
#  [],
#  [('visiting', 'VBG')],
#  [],
#  [('Tennessee', 'NN')],
#  [],
#  [],
#  [],
#  [('surprises', 'NNS')],
#  [],
#  [('store', 'NN')],
#  [('including', 'VBG')],
#  [],
#  [('special', 'JJ')],
#  [('shirt', 'NN')],
#  [('cupcakes', 'NNS')],
#  [],
#  [],
#  [('birthday', 'NN')],
#  [('cake', 'NN')],
#  [('surprise', 'NN')],
#  [],
#  [('school', 'NN')],
#  [],
#  [('young', 'JJ')],
#  [('couple', 'NN')],
#  [('adopts', 'NNS')],
#  [],
#  [('bulldog', 'NN')],
#  [('named', 'VBN')],
#  [('Zoey', 'NN')],
#  [],
#  [('brings', 'NNS')],
#  [],
#  [('immense', 'NN')],
#  [('happiness', 'NN')],
#  [],
#  [('helps', 'NNS')],
#  [('alleviate', 'NN')],
#  [],
#  [('worries', 'NNS')],
#  [],
#  [('man', 'NN')],
#  [('moved', 'VBN')],
#  [],
#  [],
#  [('place', 'NN')],
#  [],
#  [('autumn', 'NN')],
#  [],
#  [('cool', 'NN')],
#  [],
#  [('brings', 'NNS')],
#  [('joy', 'NN')],
#  [('becoming', 'VBG')],
#  [],
#  [('favorite', 'NN')],
#  [('season', 'NN')],
#  [],
#  [('brings', 'NNS')],
#  [('pumpkin', 'NN')],
#  [('sightings', 'NNS')],
#  [('coffee', 'NN')],
#  [('drinkers', 'NNS')],
#  [],
#  [],
#  [('crunch', 'NN')],
#  [],
#  [('leaves', 'NNS')],
#  [('underfoot', 'NN')],
#  [],
#  [],
#  [('gives', 'VBZ')],
#  [],
#  [('inner', 'NN')],
#  [('peace', 'NN')],
#  [],
#  [('joy', 'NN')],
#  [],
#  [],
#  [('dislikes', 'NNS')],
#  [],
#  [('heat', 'NN')],
#  [],
#  [('summer', 'NN')],
#  [],
#  [('cow', 'NN')],
#  [('ate', 'NN')],
#  [],
#  [('much', 'JJ')],
#  [('grass', 'NN')],
#  [],
#  [('got', 'VBD')],
#  [('sick', 'NN')],
#  [],
#  [('grazing', 'NN')],
#  [],
#  [],
#  [('meadow', 'NN')],
#  [],
#  [('farmer', 'NN')],
#  [('told', 'NN')],
#  [],
#  [('cow', 'NN')],
#  [],
#  [],
#  [('eat', 'NN')],
#  [],
#  [('much', 'JJ')],
#  [('grass', 'NN')],
#  [],
#  [],
#  [('drinking', 'NN')],
#  [('water', 'NN')],
#  [],
#  [('cow', 'NN')],
#  [('felt', 'NN')],
#  [('better', 'RBR')],
#  [],
#  [('story', 'NN')],
#  [],
#  [],
#  [('Hanuxi', 'NN')],
#  [('creatures', 'NNS')],
#  [],
#  [],
#  [('blue', 'NN')],
#  [('froglike', 'NN')],
#  [],
#  [('friendly', 'RB')],
#  [],
#  [('humans', 'NNS')],
#  [],
#  [],
#  [('kind', 'NN')],
#  [],
#  [],
#  [('walk', 'NN')],
#  [('hop', 'NN')],
#  [],
#  [('fly', 'NN')],
#  [],
#  [('live', 'JJ')],
#  [],
#  [],
#  [('water', 'NN')],
#  [('landscape', 'NN')],
#  [],
#  [],
#  [],
#  [('thrive', 'NN')],
#  [('outside', 'IN')],
#  [],
#  [('homes', 'NNS')],
#  [],
#  [('hero', 'NN')],
#  [('saves', 'NNS')],
#  [('two', 'CD')],
#  [('young', 'JJ')],
#  [('people', 'NNS')],
#  [],
#  [],
#  [('witchs', 'NN')],
#  [('castle', 'NN')],
#  [],
#  [('defeating', 'VBG')],
#  [],
#  [],
#  [],
#  [('sword', 'NN')],
#  [],
#  [('leads', 'NNS')],
#  [],
#  [],
#  [('safety', 'NN')],
#  [],
#  [('returns', 'NNS')],
#  [],
#  [],
#  [],
#  [('village', 'NN')],
#  [],
#  [('boy', 'NN')],
#  [('loves', 'NNS')],
#  [],
#  [('dog', 'NN')],
#  [],
#  [('cant', 'NN')],
#  [('spend', 'NN')],
#  [('much', 'JJ')],
#  [('time', 'NN')],
#  [],
#  [],
#  [('due', 'JJ')],
#  [],
#  [('school', 'NN')],
#  [],
#  [('treasures', 'NNS')],
#  [],
#  [('memories', 'NNS')],
#  [],
#  [('thinks', 'NNS')],
#  [],
#  [],
#  [('beach', 'NN')],
#  [('adventures', 'NNS')],
#  [],
#  [('classes', 'NNS')],
#  [],
#  [],
#  [('story', 'NN')],
#  [],
#  [('lonely', 'RB')],
#  [('boy', 'NN')],
#  [('discovers', 'NNS')],
#  [],
#  [('magical', 'JJ')],
#  [('forest', 'NN')],
#  [('filled', 'VBN')],
#  [],
#  [('color', 'NN')],
#  [],
#  [('meets', 'NNS')],
#  [],
#  [('girl', 'NN')],
#  [],
#  [('helps', 'NNS')],
#  [('bring', 'NN')],
#  [],
#  [('imagination', 'NN')],
#  [],
#  [('life', 'NN')],
#  [('Together', 'RB')],
#  [],
#  [('create', 'NN')],
#  [],
#  [('world', 'NN')],
#  [],
#  [('wonder', 'NN')],
#  [],
#  [('find', 'VB')],
#  [('joy', 'NN')],
#  [],
#  [('acceptance', 'NN')],
#  [],
#  [],
#  [('others', 'NNS')],
#  [('company', 'NN')],
#  [],
#  [],
#  [('story', 'NN')],
#  [],
#  [('young', 'JJ')],
#  [('girl', 'NN')],
#  [('struggles', 'NNS')],
#  [],
#  [('find', 'VB')],
#  [],
#  [('place', 'NN')],
#  [],
#  [],
#  [('world', 'NN')],
#  [],
#  [('eventually', 'RB')],
#  [('finds', 'NNS')],
#  [],
#  [('calling', 'VBG')],
#  [],
#  [('middle', 'NN')],
#  [('school', 'NN')],
#  [('band', 'NN')],
#  [('class', 'NN')],
#  [],
#  [('forms', 'NNS')],
#  [('strong', 'JJ')],
#  [('bonds', 'NNS')],
#  [],
#  [],
#  [('classmates', 'NNS')],
#  [],
#  [],
#  [('come', 'VB')],
#  [('together', 'RB')],
#  [],
#  [('win', 'NN')],
#  [],
#  [('statewide', 'NN')],
#  [('competition', 'NN')],
#  [('finally', 'RB')],
#  [('giving', 'VBG')],
#  [],
#  [],
#  [('sense', 'NN')],
#  [],
#  [('belonging', 'NN')],
#  [],
#  [('young', 'JJ')],
#  [('animal', 'NN')],
#  [('lover', 'NN')],
#  [('unable', 'JJ')],
#  [],
#  [],
#  [],
#  [('pet', 'NN')],
#  [('volunteers', 'NNS')],
#  [],
#  [],
#  [('shelter', 'NN')],
#  [],
#  [('adopts', 'NNS')],
#  [],
#  [('white', 'JJ')],
#  [('poodle', 'NN')],
#  [],
#  [('hard', 'JJ')],
#  [('work', 'NN')],
#  [],
#  [('dedication', 'NN')],
#  [('impresses', 'NNS')],
#  [],
#  [('parents', 'NNS')],
#  [],
#  [],
#  [('finally', 'RB')],
#  [('allow', 'VB')],
#  [],
#  [],
#  [('bring', 'NN')],
#  [],
#  [('furry', 'NN')],
#  [('friend', 'NN')],
#  [('home', 'NN')],
#  [('bringing', 'VBG')],
#  [('joy', 'NN')],
#  [],
#  [],
#  [('girls', 'NNS')],
#  [('life', 'NN')],
#  [],
#  [('boy', 'NN')],
#  [],
#  [('overcame', 'NN')],
#  [('cancer', 'NN')],
#  [('adopts', 'NNS')],
#  [],
#  [('stray', 'NN')],
#  [('dog', 'NN')],
#  [],
#  [('found', 'NN')],
#  [('wandering', 'VBG')],
#  [],
#  [('streets', 'NNS')],
#  [],
#  [('boy', 'NN')],
#  [],
#  [],
#  [('puppy', 'JJ')],
#  [('bond', 'NN')],
#  [],
#  [],
#  [('boys', 'NNS')],
#  [('parents', 'NNS')],
#  [('see', 'VB')],
#  [],
#  [('connection', 'NN')],
#  [],
#  [('allow', 'VB')],
#  [],
#  [('puppy', 'JJ')],
#  [],
#  [('become', 'NN')],
#  [('part', 'NN')],
#  [],
#  [],
#  [('family', 'NN')],
#  [('Sally', 'RB')],
#  [],
#  [('independent', 'JJ')],
#  [('woman', 'NN')],
#  [],
#  [('disliked', 'NNS')],
#  [],
#  [('controlled', 'VBN')],
#  [('struggled', 'VBN')],
#  [],
#  [('money', 'NN')],
#  [],
#  [('spent', 'NN')],
#  [],
#  [('year', 'NN')],
#  [('creating', 'VBG')],
#  [],
#  [('jewelry', 'NN')],
#  [('business', 'NN')],
#  [('learning', 'VBG')],
#  [],
#  [('entrepreneurship', 'NN')],
#  [],
#  [('surviving', 'VBG')],
#  [],
#  [],
#  [('limited', 'JJ')],
#  [('diet', 'NN')],
#  [],
#  [],
#  [],
#  [('happy', 'JJ')],
#  [('selling', 'VBG')],
#  [],
#  [('jewelry', 'NN')],
#  [('fulltime', 'NN')],
#  [('Two', 'CD')],
#  [('young', 'JJ')],
#  [('boys', 'NNS')],
#  [('Tommy', 'NN')],
#  [],
#  [('Rob', 'NN')],
#  [],
#  [('fourth', 'JJ')],
#  [('graders', 'NNS')],
#  [],
#  [('walk', 'NN')],
#  [('home', 'NN')],
#  [('together', 'RB')],
#  [],
#  [('school', 'NN')],
#  [('every', 'DT')],
#  [('day', 'NN')],
#  [],
#  [('discover', 'NN')],
#  [],
#  [('explore', 'NN')],
#  [],
#  [('forest', 'NN')],
#  [('path', 'NN')],
#  [('together', 'RB')],
#  [('playing', 'VBG')],
#  [('games', 'NNS')],
#  [('like', 'IN')],
#  [('hideandseek', 'NN')],
#  [],
#  [('imagining', 'VBG')],
#  [],
#  [],
#  [('pioneers', 'NNS')],
#  [],
#  [],
#  [('adventures', 'NNS')],
#  [],
#  [('create', 'NN')],
#  [('lasting', 'VBG')],
#  [('memories', 'NNS')],
#  [],
#  [],
#  [('friendship', 'NN')],
#  [],
#  [('story', 'NN')],
#  [],
#  [],
#  [],
#  [('princess', 'NN')],
#  [('named', 'VBN')],
#  [('Clary', 'JJ')],
#  [],
#  [],
#  [('happily', 'RB')],
#  [('married', 'JJ')],
#  [],
#  [],
#  [],
#  [('loving', 'VBG')],
#  [('family', 'NN')],
#  [],
#  [('husband', 'NN')],
#  [('expresses', 'NNS')],
#  [],
#  [('love', 'NN')],
#  [],
#  [('giving', 'VBG')],
#  [],
#  [('roses', 'NNS')],
#  [],
#  [],
#  [('kiss', 'NN')],
#  [('One', 'CD')],
#  [('day', 'NN')],
#  [('Clary', 'JJ')],
#  [('finds', 'NNS')],
#  [],
#  [('shes', 'NNS')],
#  [('pregnant', 'NN')],
#  [],
#  [],
#  [('eager', 'NN')],
#  [],
#  [('share', 'NN')],
#  [],
#  [('news', 'NN')],
#  [],
#  [],
#  [('husband', 'NN')],
#  [('However', 'RB')],
#  [],
#  [('surprises', 'NNS')],
#  [],
#  [],
#  [('even', 'RB')],
#  [],
#  [('beautiful', 'NN')],
#  [('roses', 'NNS')],
#  [],
#  [],
#  [],
#  [('day', 'NN')],
#  [],
#  [('man', 'NN')],
#  [('named', 'VBN')],
#  [('Fred', 'VBN')],
#  [('helped', 'VBD')],
#  [],
#  [('client', 'NN')],
#  [],
#  [('need', 'NN')],
#  [],
#  [('giving', 'VBG')],
#  [],
#  [],
#  [('ride', 'NN')],
#  [],
#  [],
#  [('mothers', 'NNS')],
#  [('funeral', 'JJ')],
#  [],
#  [],
#  [],
#  [('called', 'VBN')],
#  [],
#  [('work', 'NN')],
#  [],
#  [],
#  [('weekend', 'NN')],
#  [],
#  [('client', 'NN')],
#  [('gave', 'VBD')],
#  [],
#  [],
#  [('generous', 'JJ')],
#  [('anonymous', 'JJ')],
#  [('reward', 'NN')],
#  [],
#  [],
#  [('kind', 'NN')],
#  [('act', 'NN')],
#  [],
#  [('math', 'NN')],
#  [('teacher', 'NN')],
#  [('started', 'VBN')],
#  [],
#  [('new', 'JJ')],
#  [('job', 'NN')],
#  [],
#  [],
#  [('high', 'JJ')],
#  [('school', 'NN')],
#  [],
#  [],
#  [],
#  [('first', 'RB')],
#  [('day', 'NN')],
#  [],
#  [('dealt', 'NN')],
#  [],
#  [],
#  [('disruptive', 'NN')],
#  [('student', 'NN')],
#  [],
#  [('still', 'RB')],
#  [('tried', 'VBN')],
#  [],
#  [('make', 'VB')],
#  [],
#  [('positive', 'JJ')],
#  [('impact', 'NN')],
#  [],
#  [],
#  [],
#  [],
#  [('determined', 'VBN')],
#  [],
#  [('make', 'VB')],
#  [],
#  [('difference', 'NN')],
#  [],
#  [],
#  [('lives', 'NNS')],
#  [],
#  [],
#  [('students', 'NNS')],
#  [],
#  [('setting', 'VBG')],
#  [('expectations', 'NNS')],
#  [],
#  [('helping', 'VBG')],
#  [],
#  [('improve', 'VB')],
#  [],
#  [('behavior', 'NN')],
#  [],
#  [('dog', 'NN')],
#  [('named', 'VBN')],
#  [('Boe', 'NN')],
#  [('gets', 'VBZ')],
#  [('lost', 'VBN')],
#  [],
#  [('jumping', 'NN')],
#  [],
#  [],
#  [('fence', 'NN')],
#  [],
#  [('eventually', 'RB')],
#  [('finds', 'NNS')],
#  [],
#  [('way', 'NN')],
#  [('home', 'NN')],
#  [],
#  [('following', 'VBG')],
#  [],
#  [('sound', 'NN')],
#  [],
#  [('water', 'NN')],
#  [],
#  [('swimming', 'VBG')],
#  [('across', 'IN')],
#  [],
#  [('stream', 'NN')],
#  [('People', 'NNS')],
#  [('tried', 'VBN')],
#  [],
#  [('help', 'NN')],
#  [],
#  [],
#  [('unsuccessful', 'JJ')],
#  [],
#  [('finding', 'VBG')],
#  [],
#  [],
#  [('man', 'NN')],
#  [('named', 'VBN')],
#  [('Christopher', 'NN')],
#  [],
#  [('works', 'NNS')],
#  [],
#  [('Starbucks', 'NNS')],
#  [],
#  [('approached', 'VBN')],
#  [],
#  [],
#  [('woman', 'NN')],
#  [('named', 'VBN')],
#  [('Janet', 'NN')],
#  [],
#  [('recognized', 'VBN')],
#  [],
#  [],
#  [],
#  [('sisters', 'NNS')],
#  [('school', 'NN')],
#  [('days', 'NNS')],
#  [],
#  [('discover', 'NN')],
#  [],
#  [],
#  [],
#  [('recently', 'RB')],
#  [('moved', 'VBN')],
#  [],
#  [],
#  [('town', 'NN')],
#  [],
#  [('dont', 'NN')],
#  [('know', 'VB')],
#  [('many', 'JJ')],
#  [('people', 'NNS')],
#  [],
#  [('make', 'VB')],
#  [('plans', 'NNS')],
#  [],
#  [('meet', 'NN')],
#  [],
#  [('Starbucks', 'NNS')],
#  [],
#  [('6', 'CD')],
#  [('pm', 'NN')],
#  [],
#  [('catch', 'NN')],
#  [],
#  [],
#  [('Christopher', 'NN')],
#  [],
#  [('thrilled', 'VBN')],
#  [],
#  [('reconnect', 'NN')],
#  [],
#  [('someone', 'NN')],
#  [],
#  ...]

# %%
#Flatten 
story_part_tags_short = [item for sublist in story_part_tags_short for item in sublist]
Retell_1_tags_short = [item for sublist in Retell_1_tags_short for item in sublist]
Retell_2_tags_short = [item for sublist in Retell_2_tags_short for item in sublist]
Retell_3_tags_short = [item for sublist in Retell_3_tags_short for item in sublist]
GPT_R1_tags_short = [item for sublist in GPT_R1_tags_short for item in sublist]
GPT_R2_tags_short = [item for sublist in GPT_R2_tags_short for item in sublist]
GPT_R3_tags_short = [item for sublist in GPT_R3_tags_short for item in sublist]

# %%
story_part_tags_short
# Out:
# [('school', 'NN'),
#  ('teacher', 'NN'),
#  ('taught', 'NN'),
#  ('high', 'JJ'),
#  ('school', 'NN'),
#  ('Kids', 'NNS'),
#  ('looking', 'VBG'),
#  ('Facebook', 'NN'),
#  ('app', 'NN'),
#  ('iPhone', 'NN'),
#  ('sees', 'NNS'),
#  ('friend', 'NN'),
#  ('request', 'NN'),
#  ('two', 'CD'),
#  ('ladies', 'NNS'),
#  ('name', 'NN'),
#  ('Deeps', 'NNS'),
#  ('Sravs', 'NN'),
#  ('took', 'VBD'),
#  ('recollect', 'NN'),
#  ('ladies', 'NNS'),
#  ('two', 'CD'),
#  ('ladies', 'NNS'),
#  ('thirties', 'NNS'),
#  ('seem', 'NN'),
#  ('small', 'JJ'),
#  ('family', 'NN'),
#  ('depicted', 'VBN'),
#  ('profile', 'NN'),
#  ('picture', 'NN'),
#  ('school', 'NN'),
#  ('teacher', 'NN'),
#  ('accepted', 'JJ'),
#  ('friend', 'NN'),
#  ('request', 'NN'),
#  ('glad', 'NN'),
#  ('see', 'VB'),
#  ('Deep', 'JJ'),
#  ('Sravs', 'NN'),
#  ('long', 'RB'),
#  ('time', 'NN'),
#  ('minutes', 'NNS'),
#  ('gets', 'VBZ'),
#  ('call', 'NN'),
#  ('surprised', 'JJ'),
#  ('know', 'VB'),
#  ('Deep', 'JJ'),
#  ('Sravs', 'NN'),
#  ('come', 'VB'),
#  ('home', 'NN'),
#  ('thanks', 'NNS'),
#  ('giving', 'VBG'),
#  ('dinner', 'NN'),
#  ('invited', 'VBN'),
#  ('school', 'NN'),
#  ('teacher', 'NN'),
#  ('join', 'NN'),
#  ('evening', 'VBG'),
#  ('teacher', 'NN'),
#  ('moved', 'VBN'),
#  ('became', 'VBD'),
#  ('emotional', 'JJ'),
#  ('invited', 'VBN'),
#  ('dinner', 'NN'),
#  ('seeing', 'VBG'),
#  ('two', 'CD'),
#  ('students', 'NNS'),
#  ('happen', 'VB'),
#  ('real', 'JJ'),
#  ('sisters', 'NNS'),
#  ('tooOn', 'NN'),
#  ('way', 'NN'),
#  ('buys', 'NNS'),
#  ('gifts', 'NNS'),
#  ('Deeps', 'NNS'),
#  ('Sravs', 'NN'),
#  ('Abigail', 'NN'),
#  ('feeling', 'VBG'),
#  ('sad', 'NN'),
#  ('one', 'CD'),
#  ('day', 'NN'),
#  ('started', 'VBN'),
#  ('thinking', 'VBG'),
#  ('things', 'NNS'),
#  ('likes', 'NNS'),
#  ('likes', 'NNS'),
#  ('nature', 'NN'),
#  ('video', 'NN'),
#  ('games', 'NNS'),
#  ('best', 'JJS'),
#  ('baked', 'VBN'),
#  ('sweets', 'NNS'),
#  ('loves', 'NNS'),
#  ('baking', 'NN'),
#  ('much', 'JJ'),
#  ('loves', 'NNS'),
#  ('eating', 'VBG'),
#  ('sweet', 'NN'),
#  ('creations', 'NNS'),
#  ('thinking', 'VBG'),
#  ('decided', 'VBD'),
#  ('go', 'VB'),
#  ('bake', 'NN'),
#  ('chocolate', 'NN'),
#  ('cake', 'NN'),
#  ('bring', 'NN'),
#  ('slice', 'NN'),
#  ('neighbor', 'NN'),
#  ('Arthur', 'NNP'),
#  ('cake', 'NN'),
#  ('turned', 'VBD'),
#  ('beautiful', 'NN'),
#  ('moist', 'NN'),
#  ('delicious', 'JJ'),
#  ('Abigail', 'NN'),
#  ('excited', 'VBN'),
#  ('share', 'NN'),
#  ('neighbor', 'NN'),
#  ('headed', 'VBN'),
#  ('Arthurs', 'NNS'),
#  ('house', 'NN'),
#  ('gave', 'VBD'),
#  ('piece', 'NN'),
#  ('also', 'RB'),
#  ('feeling', 'VBG'),
#  ('sad', 'NN'),
#  ('day', 'NN'),
#  ('really', 'RB'),
#  ('touched', 'VBN'),
#  ('brought', 'NN'),
#  ('cake', 'NN'),
#  ('tried', 'VBN'),
#  ('told', 'NN'),
#  ('amazing', 'VBG'),
#  ('feeling', 'VBG'),
#  ('lot', 'NN'),
#  ('better', 'RBR'),
#  ('exchange', 'NN'),
#  ('grateful', 'NN'),
#  ('friendship', 'NN'),
#  ('neighbors', 'NNS'),
#  ('Jennifer', 'NN'),
#  ('wanted', 'VBD'),
#  ('go', 'VB'),
#  ('punk', 'NN'),
#  ('rock', 'NN'),
#  ('show', 'NN'),
#  ('club', 'NN'),
#  ('street', 'NN'),
#  ('house', 'NN'),
#  ('saved', 'VBN'),
#  ('months', 'NNS'),
#  ('waiting', 'VBG'),
#  ('show', 'NN'),
#  ('tickets', 'NNS'),
#  ('go', 'VB'),
#  ('sale', 'NN'),
#  ('excited', 'VBN'),
#  ('three', 'CD'),
#  ('favorite', 'NN'),
#  ('bands', 'NNS'),
#  ('going', 'VBG'),
#  ('day', 'NN'),
#  ('finally', 'RB'),
#  ('came', 'VBD'),
#  ('slept', 'NN'),
#  ('alarm', 'NN'),
#  ('missed', 'VBN'),
#  ('opportunity', 'NN'),
#  ('buy', 'VB'),
#  ('tickets', 'NNS'),
#  ('sold', 'VBN'),
#  ('time', 'NN'),
#  ('logged', 'VBN'),
#  ('Jennifer', 'NN'),
#  ('devastated', 'VBN'),
#  ('day', 'NN'),
#  ('show', 'NN'),
#  ('Jennifer', 'NN'),
#  ('decided', 'VBD'),
#  ('walk', 'NN'),
#  ('street', 'NN'),
#  ('hang', 'NN'),
#  ('outside', 'IN'),
#  ('venue', 'NN'),
#  ('hopes', 'NNS'),
#  ('seeing', 'VBG'),
#  ('band', 'NN'),
#  ('members', 'NNS'),
#  ('hearing', 'NN'),
#  ('music', 'NN'),
#  ('outside', 'IN'),
#  ('Thats', 'NNS'),
#  ('someone', 'NN'),
#  ('came', 'VBD'),
#  ('said', 'VBD'),
#  ('extra', 'JJ'),
#  ('ticket', 'NN'),
#  ('since', 'IN'),
#  ('friend', 'NN'),
#  ('couldnt', 'NN'),
#  ('make', 'VB'),
#  ('Would', 'MD'),
#  ('like', 'IN'),
#  ('Jennifer', 'NN'),
#  ('happy', 'JJ'),
#  ('hugged', 'VBN'),
#  ('complete', 'JJ'),
#  ('stranger', 'NN'),
#  ('ended', 'VBN'),
#  ('seeing', 'VBG'),
#  ('show', 'NN'),
#  ('together', 'RB'),
#  ('becoming', 'VBG'),
#  ('friends', 'NNS'),
#  ('life', 'NN'),
#  ('Jeff', 'NN'),
#  ('something', 'NN'),
#  ('underdog', 'NN'),
#  ('came', 'VBD'),
#  ('sports', 'NNS'),
#  ('never', 'RB'),
#  ('largest', 'JJS'),
#  ('fastest', 'JJS'),
#  ('class', 'NN'),
#  ('always', 'RB'),
#  ('picked', 'NNS'),
#  ('life', 'NN'),
#  ('reason', 'NN'),
#  ('One', 'CD'),
#  ('day', 'NN'),
#  ('enough', 'RB'),
#  ('pestering', 'VBG'),
#  ('decided', 'VBD'),
#  ('make', 'VB'),
#  ('giant', 'NN'),
#  ('life', 'NN'),
#  ('change', 'NN'),
#  ('told', 'NN'),
#  ('would', 'MD'),
#  ('work', 'NN'),
#  ('harder', 'NN'),
#  ('longer', 'NN'),
#  ('anyone', 'NN'),
#  ('else', 'RB'),
#  ('class', 'NN'),
#  ('could', 'MD'),
#  ('best', 'JJS'),
#  ('took', 'VBD'),
#  ('long', 'RB'),
#  ('since', 'IN'),
#  ('similar', 'JJ'),
#  ('building', 'NN'),
#  ('city', 'NN'),
#  ('nothing', 'NN'),
#  ('happens', 'NNS'),
#  ('one', 'CD'),
#  ('day', 'NN'),
#  ('struggles', 'NNS'),
#  ('great', 'JJ'),
#  ('times', 'NNS'),
#  ('wanted', 'VBD'),
#  ('give', 'VB'),
#  ('couldnt', 'NN'),
#  ('one', 'CD'),
#  ('full', 'JJ'),
#  ('year', 'NN'),
#  ('disciplined', 'VBN'),
#  ('training', 'NN'),
#  ('done', 'VBN'),
#  ('finally', 'RB'),
#  ('managed', 'VBN'),
#  ('beat', 'NN'),
#  ('everyone', 'NN'),
#  ('else', 'RB'),
#  ('class', 'NN'),
#  ('sports', 'NNS'),
#  ('competitions', 'NNS'),
#  ('happiest', 'NN'),
#  ('ever', 'RB'),
#  ('ever', 'RB'),
#  ('child', 'NN'),
#  ('plan', 'NN'),
#  ('say', 'VB'),
#  ('us', 'PRP'),
#  ('rewarding', 'VBG'),
#  ('experiences', 'NNS'),
#  ('ever', 'RB'),
#  ('wanted', 'VBD'),
#  ('children', 'NNS'),
#  ('long', 'RB'),
#  ('time', 'NN'),
#  ('23', 'CD'),
#  ('29', 'CD'),
#  ('tried', 'VBN'),
#  ('tried', 'VBN'),
#  ('get', 'VB'),
#  ('pregnant', 'NN'),
#  ('luck', 'NN'),
#  ('consider', 'VB'),
#  ('invitro', 'NN'),
#  ('fertilization', 'NN'),
#  ('went', 'VBD'),
#  ('checkup', 'NN'),
#  ('introductory', 'NN'),
#  ('meeting', 'NN'),
#  ('found', 'NN'),
#  ('pregnant', 'NN'),
#  ('never', 'RB'),
#  ('elated', 'VBN'),
#  ('relieved', 'VBN'),
#  ('whole', 'JJ'),
#  ('life', 'NN'),
#  ('felt', 'NN'),
#  ('fulfilled', 'VBN'),
#  ('alivemy', 'NN'),
#  ('husband', 'NN'),
#  ('shed', 'VBN'),
#  ('tears', 'NNS'),
#  ('joy', 'NN'),
#  ('historic', 'NN'),
#  ('moment', 'NN'),
#  ('story', 'NN'),
#  ('sure', 'NN'),
#  ('arrived', 'VBN'),
#  ('felt', 'NN'),
#  ('peace', 'NN'),
#  ('calmness', 'NN'),
#  ('fulfillment', 'NN'),
#  ('cradled', 'VBN'),
#  ('tiny', 'JJ'),
#  ('body', 'NN'),
#  ('arms', 'NNS'),
#  ('felt', 'NN'),
#  ('love', 'NN'),
#  ('fierce', 'NN'),
#  ('strong', 'JJ'),
#  ('almost', 'RB'),
#  ('scared', 'VBN'),
#  ('Throughout', 'IN'),
#  ('years', 'NNS'),
#  ('watched', 'VBN'),
#  ('grow', 'NN'),
#  ('electric', 'JJ'),
#  ('young', 'JJ'),
#  ('girl', 'NN'),
#  ('feel', 'NN'),
#  ('proud', 'NN'),
#  ('hand', 'NN'),
#  ('become', 'NN'),
#  ('walking', 'VBG'),
#  ('along', 'IN'),
#  ('trail', 'NN'),
#  ('one', 'CD'),
#  ('sunny', 'NN'),
#  ('day', 'NN'),
#  ('came', 'VBD'),
#  ('across', 'IN'),
#  ('woman', 'NN'),
#  ('sitting', 'VBG'),
#  ('side', 'NN'),
#  ('trail', 'NN'),
#  ('eating', 'VBG'),
#  ('lunch', 'NN'),
#  ('speak', 'NN'),
#  ('language', 'NN'),
#  ('beckoned', 'VBN'),
#  ('come', 'VB'),
#  ('sit', 'NN'),
#  ('next', 'JJ'),
#  ('Opening', 'VBG'),
#  ('backpack', 'NN'),
#  ('reaching', 'VBG'),
#  ('inside', 'IN'),
#  ('grinned', 'VBN'),
#  ('handed', 'VBN'),
#  ('small', 'JJ'),
#  ('container', 'NN'),
#  ('full', 'JJ'),
#  ('food', 'NN'),
#  ('three', 'CD'),
#  ('pieces', 'NNS'),
#  ('flatbread', 'NN'),
#  ('opened', 'VBN'),
#  ('container', 'NN'),
#  ('overcome', 'NN'),
#  ('fragrance', 'NN'),
#  ('pouring', 'VBG'),
#  ('underneath', 'NN'),
#  ('edges', 'NNS'),
#  ('lid', 'NN'),
#  ('spicy', 'NN'),
#  ('garlicky', 'NN'),
#  ('bursting', 'NN'),
#  ('coconut', 'NN'),
#  ('lemongrass', 'NN'),
#  ('bouquets', 'NNS'),
#  ('made', 'VBN'),
#  ('nose', 'RB'),
#  ('run', 'VB'),
#  ('mouth', 'NN'),
#  ('water', 'NN'),
#  ('dipped', 'NN'),
#  ('bread', 'NN'),
#  ('slurped', 'VBD'),
#  ('curry', 'NN'),
#  ('watchful', 'NN'),
#  ('eye', 'NN'),
#  ('silent', 'NN'),
#  ('woman', 'NN'),
#  ('finished', 'VBN'),
#  ('took', 'VBD'),
#  ('back', 'RB'),
#  ('container', 'NN'),
#  ('offered', 'VBN'),
#  ('cup', 'NN'),
#  ('water', 'NN'),
#  ('began', 'VBD'),
#  ('packing', 'VBG'),
#  ('things', 'NNS'),
#  ('walked', 'VBD'),
#  ('away', 'RB'),
#  ('direction', 'NN'),
#  ('come', 'VB'),
#  ('left', 'NN'),
#  ('happy', 'JJ'),
#  ('Ive', 'NN'),
#  ('purchased', 'VBN'),
#  ('new', 'JJ'),
#  ('home', 'NN'),
#  ('yard', 'NN'),
#  ('new', 'JJ'),
#  ('home', 'NN'),
#  ('hostas', 'NNS'),
#  ('Im', 'NN'),
#  ('sure', 'NN'),
#  ('seen', 'VBN'),
#  ('hosta', 'NN'),
#  ('point', 'NN'),
#  ('life', 'NN'),
#  ('may', 'MD'),
#  ('recognize', 'VB'),
#  ('name', 'NN'),
#  ('Hostas', 'NNS'),
#  ('large', 'JJ'),
#  ('green', 'JJ'),
#  ('leafy', 'NN'),
#  ('plants', 'NNS'),
#  ('enjoy', 'NN'),
#  ('shade', 'NN'),
#  ('resilient', 'NN'),
#  ('varieties', 'NNS'),
#  ('weather', 'NN'),
#  ('conditions', 'NNS'),
#  ('exception', 'NN'),
#  ('dryness', 'NN'),
#  ('heat', 'NN'),
#  ('like', 'IN'),
#  ('love', 'NN'),
#  ('new', 'JJ'),
#  ('plants', 'NNS'),
#  ('guess', 'NN'),
#  ('home', 'NN'),
#  ('Yesterday', 'NN'),
#  ('propagated', 'VBN'),
#  ('new', 'JJ'),
#  ('hosta', 'NN'),
#  ('growths', 'NNS'),
#  ('perfect', 'NN'),
#  ('fall', 'NN'),
#  ('day', 'NN'),
#  ('activity', 'NN'),
#  ('ground', 'NN'),
#  ('damp', 'NN'),
#  ('sky', 'NN'),
#  ('overcast', 'NN'),
#  ('rained', 'VBN'),
#  ('times', 'NNS'),
#  ('matter', 'NN'),
#  ('damp', 'NN'),
#  ('weather', 'NN'),
#  ('appreciated', 'VBN'),
#  ('long', 'RB'),
#  ('hot', 'JJ'),
#  ('summer', 'NN'),
#  ('Today', 'NN'),
#  ('went', 'VBD'),
#  ('visit', 'NN'),
#  ('hostas', 'NNS'),
#  ('colorful', 'NN'),
#  ('wilted', 'VBN'),
#  ('days', 'NNS'),
#  ('daughters', 'NNS'),
#  ('6th', 'CD'),
#  ('birthday', 'NN'),
#  ('excited', 'VBN'),
#  ('birthday', 'NN'),
#  ('prepared', 'JJ'),
#  ('making', 'VBG'),
#  ('goodies', 'NNS'),
#  ('class', 'NN'),
#  ('also', 'RB'),
#  ('organized', 'VBN'),
#  ('birthday', 'NN'),
#  ('party', 'NN'),
#  ('gymnastics', 'NNS'),
#  ('studio', 'NN'),
#  ('princess', 'NN'),
#  ('theme', 'NN'),
#  ('since', 'IN'),
#  ('loves', 'NNS'),
#  ('everything', 'NN'),
#  ('pink', 'NN'),
#  ('princess', 'NN'),
#  ('wear', 'NN'),
#  ('surprise', 'NN'),
#  ('princess', 'NN'),
#  ('dress', 'NN'),
#  ('school', 'NN'),
#  ('party', 'NN'),
#  ('special', 'JJ'),
#  ('shirt', 'NN'),
#  ('made', 'VBN'),
#  ('age', 'NN'),
#  ('course', 'NN'),
#  ('crown', 'NN'),
#  ('pink', 'NN'),
#  ('cupcakes', 'NNS'),
#  ('topped', 'NNS'),
#  ('princesses', 'NNS'),
#  ('girts', 'NNS'),
#  ('wrapped', 'VBD'),
#  ('princess', 'NN'),
#  ('wrapping', 'VBG'),
#  ('paper', 'NN'),
#  ('hidden', 'NN'),
#  ('away', 'RB'),
#  ('friends', 'NNS'),
#  ('planning', 'NN'),
#  ('attending', 'VBG'),
#  ('party', 'NN'),
#  ('anxious', 'JJ'),
#  ('get', 'VB'),
#  ('birthday', 'NN'),
#  ('birthday', 'NN'),
#  ('party', 'NN'),
#  ('grandfather', 'NN'),
#  ('even', 'RB'),
#  ('driving', 'VBG'),
#  ('Tennessee', 'NN'),
#  ('big', 'JJ'),
#  ('day', 'NN'),
#  ('baking', 'NN'),
#  ('cake', 'NN'),
#  ('also', 'RB'),
#  ('surprising', 'NN'),
#  ('school', 'NN'),
#  ('going', 'VBG'),
#  ('reading', 'NN'),
#  ('book', 'NN'),
#  ('beginning', 'VBG'),
#  ('December', 'NNP'),
#  ('2018', 'CD'),
#  ('young', 'JJ'),
#  ('couple', 'NN'),
#  ('agrees', 'NNS'),
#  ('adopt', 'NN'),
#  ('dog', 'NN'),
#  ('Theyve', 'NN'),
#  ('worked', 'VBN'),
#  ('exclusively', 'RB'),
#  ('dogs', 'NNS'),
#  ('noticed', 'VBN'),
#  ('spike', 'NN'),
#  ('mood', 'NN'),
#  ('around', 'IN'),
#  ('animals', 'NNS'),
#  ('almost', 'RB'),
#  ('healing', 'VBG'),
#  ('powers', 'NNS'),
#  ('Facing', 'VBG'),
#  ('difficulty', 'NN'),
#  ('personal', 'JJ'),
#  ('lives', 'NNS'),
#  ('decide', 'NN'),
#  ('invite', 'NN'),
#  ('one', 'CD'),
#  ('home', 'NN'),
#  ('permanently', 'RB'),
#  ('start', 'NN'),
#  ('looking', 'VBG'),
#  ('apps', 'NN'),
#  ('online', 'NN'),
#  ('listings', 'NNS'),
#  ('local', 'JJ'),
#  ('shelters', 'NNS'),
#  ('find', 'VB'),
#  ('goofiest', 'NN'),
#  ('little', 'JJ'),
#  ('thing', 'NN'),
#  ('Shes', 'NNS'),
#  ('small', 'JJ'),
#  ('bulldog', 'NN'),
#  ('35', 'CD'),
#  ('pounds', 'NNS'),
#  ('low', 'JJ'),
#  ('ground', 'NN'),
#  ('tongue', 'NN'),
#  ('hangs', 'NNS'),
#  ('mouth', 'NN'),
#  ('quickly', 'RB'),
#  ('becomes', 'NNS'),
#  ('clear', 'JJ'),
#  ('way', 'NN'),
#  ('leave', 'VB'),
#  ('place', 'NN'),
#  ('without', 'IN'),
#  ('Days', 'NNS'),
#  ('weeks', 'NNS'),
#  ('go', 'VB'),
#  ('painstakingly', 'RB'),
#  ('wait', 'NN'),
#  ('adoption', 'NN'),
#  ('process', 'NN'),
#  ('go', 'VB'),
#  ('Eventually', 'RB'),
#  ('Zoey', 'NN'),
#  ('comes', 'VBZ'),
#  ('home', 'NN'),
#  ('Everything', 'NN'),
#  ('worries', 'NNS'),
#  ('melted', 'VBN'),
#  ('away', 'RB'),
#  ('miracle', 'NN'),
#  ('upon', 'IN'),
#  ('time', 'NN'),
#  ('guy', 'NN'),
#  ('really', 'RB'),
#  ('hated', 'VBN'),
#  ('heat', 'NN'),
#  ('summer', 'NN'),
#  ('moved', 'VBN'),
#  ('away', 'RB'),
#  ('south', 'NN'),
#  ('perpetually', 'RB'),
#  ('hot', 'JJ'),
#  ('Finally', 'RB'),
#  ('Autumn', 'NN'),
#  ('came', 'VBD'),
#  ('around', 'IN'),
#  ('pleased', 'JJ'),
#  ('temperatures', 'NNS'),
#  ('got', 'VBD'),
#  ('cooler', 'NN'),
#  ('nice', 'JJ'),
#  ('outside', 'IN'),
#  ('could', 'MD'),
#  ('wear', 'NN'),
#  ('hoodies', 'NNS'),
#  ('favorite', 'NN'),
#  ('type', 'NN'),
#  ('clothing', 'NN'),
#  ('leaves', 'NNS'),
#  ('changed', 'VBN'),
#  ('colors', 'NNS'),
#  ('everywhere', 'RB'),
#  ('looked', 'VBD'),
#  ('pumpkins', 'NNS'),
#  ('people', 'NNS'),
#  ('drinking', 'NN'),
#  ('coffee', 'NN'),
#  ('crisp', 'NN'),
#  ('sound', 'NN'),
#  ('leaves', 'NNS'),
#  ('crunching', 'VBG'),
#  ('underfoot', 'NN'),
#  ('satisfied', 'JJ'),
#  ('living', 'NN'),
#  ('somewhere', 'RB'),
#  ('wasnt', 'NN'),
#  ('hot', 'JJ'),
#  ('time', 'NN'),
#  ('brought', 'NN'),
#  ('lot', 'NN'),
#  ('inner', 'NN'),
#  ('peace', 'NN'),
#  ('joy', 'NN'),
#  ('Finally', 'RB'),
#  ('Summer', 'NN'),
#  ('ended', 'VBN'),
#  ('favorite', 'NN'),
#  ('time', 'NN'),
#  ('year', 'NN'),
#  ('would', 'MD'),
#  ('sure', 'NN'),
#  ('enjoy', 'NN'),
#  ('upon', 'IN'),
#  ('time', 'NN'),
#  ('joyful', 'NN'),
#  ('cow', 'NN'),
#  ('cow', 'NN'),
#  ('liked', 'VBN'),
#  ('eat', 'NN'),
#  ('grass', 'NN'),
#  ('meadow', 'NN'),
#  ('always', 'RB'),
#  ('got', 'VBD'),
#  ('lot', 'NN'),
#  ('grass', 'NN'),
#  ('always', 'RB'),
#  ('ate', 'NN'),
#  ('always', 'RB'),
#  ('got', 'VBD'),
#  ('enough', 'RB'),
#  ('grass', 'NN'),
#  ('day', 'NN'),
#  ('dawned', 'VBN'),
#  ('grass', 'NN'),
#  ('meadow', 'NN'),
#  ('next', 'JJ'),
#  ('day', 'NN'),
#  ('grass', 'NN'),
#  ('back', 'RB'),
#  ('meadow', 'NN'),
#  ('cow', 'NN'),
#  ('looked', 'VBD'),
#  ('little', 'JJ'),
#  ('sick', 'NN'),
#  ('said', 'VBD'),
#  ('Whats', 'NNS'),
#  ('wrong', 'JJ'),
#  ('drink', 'NN'),
#  ('get', 'VB'),
#  ('well', 'RB'),
#  ('big', 'JJ'),
#  ('old', 'JJ'),
#  ('farmer', 'NN'),
#  ('went', 'VBD'),
#  ('cow', 'NN'),
#  ('asked', 'VBN'),
#  ('happened', 'VBD'),
#  ('cow', 'NN'),
#  ('said', 'VBD'),
#  ('must', 'MD'),
#  ('eat', 'NN'),
#  ('much', 'JJ'),
#  ('grass', 'NN'),
#  ('must', 'MD'),
#  ('eat', 'NN'),
#  ('much', 'JJ'),
#  ('grass', 'NN'),
#  ('get', 'VB'),
#  ('drunk', 'NN'),
#  ('sick', 'NN'),
#  ('farmer', 'NN'),
#  ('amazed', 'VBN'),
#  ('cow', 'NN'),
#  ('fine', 'NN'),
#  ('got', 'VBD'),
#  ('water', 'NN'),
#  ('summertime', 'NN'),
#  ('season', 'NN'),
#  ('native', 'JJ'),
#  ('Hanuxi', 'NN'),
#  ('live', 'JJ'),
#  ('shifting', 'VBG'),
#  ('seasons', 'NNS'),
#  ('waterscape', 'NN'),
#  ('society', 'NN'),
#  ('Hanuxi', 'NN'),
#  ('lot', 'NN'),
#  ('like', 'IN'),
#  ('Earth', 'NN'),
#  ('dwelling', 'VBG'),
#  ('little', 'JJ'),
#  ('frogs', 'NNS'),
#  ('blue', 'NN'),
#  ('like', 'IN'),
#  ('common', 'JJ'),
#  ('house', 'NN'),
#  ('dog', 'NN'),
#  ('behavioral', 'JJ'),
#  ('habits', 'NNS'),
#  ('Hanuxi', 'NN'),
#  ('hop', 'NN'),
#  ('jump', 'NN'),
#  ('around', 'IN'),
#  ('also', 'RB'),
#  ('incorporate', 'NN'),
#  ('fourlegged', 'VBN'),
#  ('walking', 'VBG'),
#  ('quadrupedal', 'NN'),
#  ('well', 'RB'),
#  ('typically', 'RB'),
#  ('survive', 'NN'),
#  ('waterscape', 'NN'),
#  ('societies', 'NNS'),
#  ('AKA', 'NN'),
#  ('springlike', 'NN'),
#  ('basins', 'NNS'),
#  ('run', 'VB'),
#  ('various', 'JJ'),
#  ('unique', 'NN'),
#  ('atmospheric', 'JJ'),
#  ('areas', 'NNS'),
#  ('creatures', 'NNS'),
#  ('friendly', 'RB'),
#  ('kind', 'NN'),
#  ('even', 'RB'),
#  ('helpful', 'NN'),
#  ('one', 'CD'),
#  ('another', 'DT'),
#  ('humans', 'NNS'),
#  ('well', 'RB'),
#  ('usually', 'RB'),
#  ('maybe', 'RB'),
#  ('always', 'RB'),
#  ('Hanuxi', 'NN'),
#  ('also', 'RB'),
#  ('one', 'CD'),
#  ('unique', 'NN'),
#  ('trait', 'NN'),
#  ('fly', 'NN'),
#  ('Yes', 'UH'),
#  ('like', 'IN'),
#  ('flying', 'VBG'),
#  ('froglike', 'NN'),
#  ('creatures', 'NNS'),
#  ('act', 'NN'),
#  ('much', 'JJ'),
#  ('like', 'IN'),
#  ('dogs', 'NNS'),
#  ('comparison', 'NN'),
#  ('rementioning', 'VBG'),
#  ('creatures', 'NNS'),
#  ('thrive', 'NN'),
#  ('well', 'RB'),
#  ('outside', 'IN'),
#  ('waterscapes', 'NNS'),
#  ('welcome', 'NN'),
#  ('visitors', 'NNS'),
#  ('witch', 'NN'),
#  ('prepared', 'JJ'),
#  ('make', 'VB'),
#  ('final', 'JJ'),
#  ('brew', 'NN'),
#  ('would', 'MD'),
#  ('include', 'NN'),
#  ('one', 'CD'),
#  ('prisoners', 'NNS'),
#  ('disposal', 'NN'),
#  ('displayed', 'NN'),
#  ('cage', 'NN'),
#  ('held', 'NN'),
#  ('long', 'RB'),
#  ('hook', 'NN'),
#  ('overhead', 'NN'),
#  ('people', 'NNS'),
#  ('inside', 'IN'),
#  ('man', 'NN'),
#  ('woman', 'NN'),
#  ('could', 'MD'),
#  ('older', 'JJR'),
#  ('22', 'CD'),
#  ('knew', 'NNS'),
#  ('point', 'NN'),
#  ('could', 'MD'),
#  ('plea', 'NN'),
#  ('would', 'MD'),
#  ('save', 'VB'),
#  ('making', 'VBG'),
#  ('peace', 'NN'),
#  ('end', 'NN'),
#  ('face', 'NN'),
#  ('moment', 'NN'),
#  ('hero', 'NN'),
#  ('came', 'VBD'),
#  ('window', 'NN'),
#  ('leaped', 'VBD'),
#  ('inside', 'IN'),
#  ('fell', 'VBD'),
#  ('floor', 'NN'),
#  ('wearing', 'VBG'),
#  ('breast', 'NN'),
#  ('plate', 'NN'),
#  ('knights', 'NNS'),
#  ('helmet', 'NN'),
#  ('long', 'RB'),
#  ('sword', 'NN'),
#  ('witch', 'NN'),
#  ('caught', 'NN'),
#  ('guard', 'NN'),
#  ('could', 'MD'),
#  ('cast', 'NN'),
#  ('spell', 'NN'),
#  ('warrior', 'NN'),
#  ('slayed', 'NN'),
#  ('warrior', 'NN'),
#  ('freed', 'NN'),
#  ('two', 'CD'),
#  ('people', 'NNS'),
#  ('cage', 'NN'),
#  ('helped', 'VBD'),
#  ('back', 'RB'),
#  ('village', 'NN'),
#  ('boy', 'NN'),
#  ('loved', 'VBN'),
#  ('dog', 'NN'),
#  ('dog', 'NN'),
#  ('side', 'NN'),
#  ('since', 'IN'),
#  ('3', 'CD'),
#  ('months', 'NNS'),
#  ('old', 'JJ'),
#  ('didnt', 'NN'),
#  ('remember', 'VB'),
#  ('time', 'NN'),
#  ('life', 'NN'),
#  ('dog', 'NN'),
#  ('next', 'JJ'),
#  ('favorite', 'NN'),
#  ('thing', 'NN'),
#  ('take', 'VB'),
#  ('dog', 'NN'),
#  ('beach', 'NN'),
#  ('let', 'VB'),
#  ('run', 'VB'),
#  ('around', 'IN'),
#  ('sand', 'NN'),
#  ('play', 'NN'),
#  ('water', 'NN'),
#  ('love', 'NN'),
#  ('play', 'NN'),
#  ('waves', 'NNS'),
#  ('let', 'VB'),
#  ('crash', 'NN'),
#  ('heads', 'NNS'),
#  ('something', 'NN'),
#  ('used', 'VBN'),
#  ('time', 'NN'),
#  ('getting', 'VBG'),
#  ('older', 'JJR'),
#  ('doesnt', 'NN'),
#  ('time', 'NN'),
#  ('take', 'VB'),
#  ('dog', 'NN'),
#  ('beach', 'NN'),
#  ('busy', 'JJ'),
#  ('studying', 'VBG'),
#  ('school', 'NN'),
#  ('boy', 'NN'),
#  ('school', 'NN'),
#  ('often', 'RB'),
#  ('thinks', 'NNS'),
#  ('dog', 'NN'),
#  ('daydreams', 'NNS'),
#  ('times', 'NNS'),
#  ('beach', 'NN'),
#  ('boy', 'NN'),
#  ('gets', 'VBZ'),
#  ('day', 'NN'),
#  ('school', 'NN'),
#  ('boy', 'NN'),
#  ('always', 'RB'),
#  ('head', 'NN'),
#  ('clouds', 'NNS'),
#  ('walked', 'VBD'),
#  ('around', 'IN'),
#  ('imagining', 'VBG'),
#  ('sorts', 'NNS'),
#  ('things', 'NNS'),
#  ('Fantasies', 'NNS'),
#  ('adventure', 'NN'),
#  ('conquering', 'VBG'),
#  ('dragons', 'NNS'),
#  ('saving', 'VBG'),
#  ('princesses', 'NNS'),
#  ('battling', 'NN'),
#  ('pirates', 'NNS'),
#  ('flying', 'VBG'),
#  ('space', 'NN'),
#  ('Sometimes', 'RB'),
#  ('active', 'JJ'),
#  ('imagination', 'NN'),
#  ('enjoyed', 'VBN'),
#  ('playing', 'VBG'),
#  ('never', 'RB'),
#  ('anybody', 'NN'),
#  ('could', 'MD'),
#  ('share', 'NN'),
#  ('older', 'JJR'),
#  ('got', 'VBD'),
#  ('lonely', 'RB'),
#  ('became', 'VBD'),
#  ('Nobody', 'NN'),
#  ('else', 'RB'),
#  ('wanted', 'VBD'),
#  ('talk', 'NN'),
#  ('pirates', 'NNS'),
#  ('princesses', 'NNS'),
#  ...]

# %% [markdown]
# ### 2.2. Count Tags

# %%
def count_tags(mydata):
    counter_list=[]
    for i in mydata:
        counter_list.append(i[1])

    tag_counts = Counter(counter_list) 
    return tag_counts

# %%
# Short tags

story_part_tags_short = count_tags(story_part_tags_short)
GPT_R1_tag_counts_short = count_tags(GPT_R1_tags_short)
GPT_R2_tag_counts_short = count_tags(GPT_R2_tags_short)
GPT_R3_tag_counts_short = count_tags(GPT_R3_tags_short)

Retell_1_tag_counts_short = count_tags(Retell_1_tags_short)
Retell_2_tag_counts_short = count_tags(Retell_2_tags_short)
Retell_3_tag_counts_short = count_tags(Retell_3_tags_short)

# %% [markdown]
# ### Tags:

# %% [markdown]
# CC: It is the conjunction of coordinating
#
# CD: It is a digit of cardinal
#
# DT: It is the determiner
#
# EX: Existential
#
# FW: It is a foreign word
#
# IN: Preposition and conjunction
#
# JJ: Adjective
#
# JJR and JJS: Adjective and superlative
#
# LS: List marker
#
# MD: Modal
#
# NN: Singular noun
#
# NNS, NNP, NNPS: Proper and plural noun
#
# PDT: Predeterminer
#
# WRB: Adverb of wh
#
# WP$: Possessive wh
#
# WP: Pronoun of wh
#
# WDT: Determiner of wp
# VBZ: Verb
#
# VBP, VBN, VBG, VBD, VB: Forms of verbs
#
# UH: Interjection
#
#
# TO: To go
#
# RP: Particle
#
# RBS, RB, RBR: Adverb
#
# PRP, PRP$: Pronoun personal and professional

# %% [markdown]
# ### 2.3. Visualize

# %% [markdown]
# #### 2.3.1. First Retelling

# %%
#Human retellings
keys = Retell_1_tag_counts_short.keys()
plt.bar(keys, Retell_1_tag_counts_short.values(), color='orange', label='Human')

#GPT retellings 
keysgpt=GPT_R1_tag_counts_short.keys()
plt.bar(keysgpt, GPT_R1_tag_counts_short.values(),color='blue', label ='chatGPT',alpha = .5)
plt.xticks(rotation=45)  #rotate x labels prevent the overlap
plt.legend(loc='upper right')
plt.title('Comparison of First Retelling')
plt.show()

# %% [markdown]
# #### 2.3.2. Second Retelling

# %%
#Human retellings
keys = Retell_2_tag_counts_short.keys()
plt.bar(keys, Retell_2_tag_counts_short.values(), color='orange', label='Human')

#GPT retellings 
keysgpt=GPT_R2_tag_counts_short.keys()
plt.bar(keysgpt, GPT_R2_tag_counts_short.values(),color='blue', label ='chatGPT',alpha = .5)
plt.xticks(rotation=45)  #rotate x labels prevent the overlap
plt.legend(loc='upper right')
plt.title('Comparison of Second Retelling')
plt.show()

# %% [markdown]
# #### 2.3.3. Third Retelling

# %%
#Human retellings
keys = Retell_3_tag_counts_short.keys()
plt.bar(keys, Retell_3_tag_counts_short.values(), color='orange', label='Human')

#GPT retellings 
keysgpt=GPT_R3_tag_counts_short.keys()
plt.bar(keysgpt, GPT_R3_tag_counts_short.values(),color='blue', label ='chatGPT',alpha = .5)
plt.xticks(rotation=45)  #rotate x labels prevent the overlap
plt.legend(loc='upper right')
plt.title('Comparison of Third Retelling')
plt.show()

# %% [markdown]
# ## 3. Pos-tagging for Less Category
#
# Only noun,verb,adj,adv,pronoun, and conj/deter/prepositions

# %% [markdown]
# ### 3.1. Change data format

# %%
#Change data format
origin = pd.DataFrame.from_dict(story_part_tags_short,orient='index').reset_index()
origin.columns = ['pos', 'origin']

rt1 = pd.DataFrame.from_dict(Retell_1_tag_counts_short,orient='index').reset_index()
rt1.columns = ['pos', 'rt1']

rt2 = pd.DataFrame.from_dict(Retell_2_tag_counts_short,orient='index').reset_index()
rt2.columns = ['pos', 'rt2']

rt3 = pd.DataFrame.from_dict(Retell_3_tag_counts_short,orient='index').reset_index()
rt3.columns = ['pos', 'rt3']

gpt1 = pd.DataFrame.from_dict(GPT_R1_tag_counts_short,orient='index').reset_index()
gpt1.columns = ['pos', 'gpt1']

gpt2 = pd.DataFrame.from_dict(GPT_R2_tag_counts_short,orient='index').reset_index()
gpt2.columns = ['pos', 'gpt2']

gpt3 = pd.DataFrame.from_dict(GPT_R3_tag_counts_short,orient='index').reset_index()
gpt3.columns = ['pos', 'gpt3']

# %%
import functools as ft

#merge dfs
dfs = [origin,rt1,rt2,rt3,gpt1,gpt2,gpt3]
df_final = ft.reduce(lambda left, right: pd.merge(left, right, on='pos',how='outer'), dfs)

#if a category is missing replace with zero
df_final.fillna(0, inplace=True)

#change floats to integer
df_final = df_final.astype({'rt1': int, 'rt2':int, 'rt3':int, 'origin':int, 'gpt1':int, 'gpt2':int, 'gpt3':int})

# %% [markdown]
# ### 3.2. Merge relevant groups

# %%
pivot = pd.pivot_table(df_final,index='pos', aggfunc=np.sum).transpose()
pivot.columns
# Out:
# Index(['CD', 'DT', 'IN', 'JJ', 'JJR', 'JJS', 'MD', 'NN', 'NNP', 'NNS', 'PRP',
#        'RB', 'RBR', 'UH', 'VB', 'VBD', 'VBG', 'VBN', 'VBZ', 'WP$'],
#       dtype='object', name='pos')

# %%
pivot['NUMBERS'] = pivot['CD']

# %%
pivot['VERBS'] = pivot['VB'] + pivot['VBN'] + pivot['VBG']+pivot['VBZ'] + pivot['VBD']
pivot['NOUNS'] = pivot['NN'] + pivot['NNS'] + pivot['NNP']#+ pivot['NNPS']
pivot['ADJECTIVES'] = pivot['JJ'] + pivot['JJS'] + pivot['JJR']
pivot['ADVERBS'] = pivot['RB'] + pivot['RBR'] 
pivot['PRONOUN'] = pivot['PRP'] +pivot['WP$']
pivot['PREPOSITION'] = pivot['IN'] 
pivot['CONJUNCTIONS_DETERMINERS_PREPOSITIONS'] =pivot['DT'] + pivot['IN'] + pivot['UH']

# %%
pivot_short = pivot[['VERBS','NOUNS','ADJECTIVES','ADVERBS','PRONOUN','PREPOSITION','CONJUNCTIONS_DETERMINERS_PREPOSITIONS']].reset_index()

# %%
Human = pivot_short[(pivot_short['index']=='origin') | (pivot_short['index']=='rt1') |( pivot_short['index']=='rt2')| (pivot_short['index']=='rt3')]
GPT = pivot_short[(pivot_short['index']=='origin') | (pivot_short['index']=='gpt1') |( pivot_short['index']=='gpt2')| (pivot_short['index']=='gpt3')]

# %%
GPT = GPT.set_index(['index']).reindex(["origin","gpt1","gpt2","gpt3"]).reset_index()

# %%
Human.columns =['GENERATION', 'VERBS', 'NOUNS', 'ADJECTIVES', 'ADVERBS', 'PRONOUN','PREPOSITION',
       'CONJUNCTIONS_DETERMINERS_PREPOSITIONS']
GPT.columns =['GENERATION', 'VERBS', 'NOUNS', 'ADJECTIVES', 'ADVERBS', 'PRONOUN','PREPOSITION',
       'CONJUNCTIONS_DETERMINERS_PREPOSITIONS']

# %% [markdown]
# ### 3.3. Visualize

# %%
# Create some data
x = ['original', 'first','second','third']
y1 = Human['NOUNS']
y2 = GPT['NOUNS']

# Set the width of each bar
bar_width = 0.40

# Create the bar plot
fig, axs = plt.subplots(2, 3)
rects1 = axs[0,0].bar(x, y1, bar_width, label='Human')
rects2 = axs[0,0].bar([i + bar_width for i in range(len(x))], y2, bar_width, label='GPT')

# Add labels and a legend
axs[0,0].set_xlabel('Generation')
axs[0,0].set_ylabel('Count')
axs[0,0].set_title('NOUNS')
axs[0,0].set_xticks([i + bar_width/2 for i in range(len(x))])
axs[0,0].set_xticklabels(x)
axs[0,0].legend()

# Add text on top of each bar
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        axs[0,0].annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

# Create some data
x = ['original', 'first','second','third']
y1 = Human['VERBS']
y2 = GPT['VERBS']

# Set the width of each bar
bar_width = 0.40

# Create the bar plot
rects1 = axs[0,1].bar(x, y1, bar_width, label='Human')
rects2 = axs[0,1].bar([i + bar_width for i in range(len(x))], y2, bar_width, label='GPT')

# Add labels and a legend
axs[0,1].set_xlabel('Generation')
axs[0,1].set_ylabel('Count')
axs[0,1].set_title('VERBS')
axs[0,1].set_xticks([i + bar_width/2 for i in range(len(x))])
axs[0,1].set_xticklabels(x)
axs[0,1].legend()

# Add text on top of each bar
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        axs[0,1].annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)



# Create some data
x = ['original', 'first','second','third']
y1 = Human['ADJECTIVES']
y2 = GPT['ADJECTIVES']

# Set the width of each bar
bar_width = 0.40

# Create the bar plot
rects1 = axs[1,1].bar(x, y1, bar_width, label='Human')
rects2 = axs[1,1].bar([i + bar_width for i in range(len(x))], y2, bar_width, label='GPT')

# Add labels and a legend
axs[1,1].set_xlabel('Generation')
axs[1,1].set_ylabel('Count')
axs[1,1].set_title('ADJECTIVES')
axs[1,1].set_xticks([i + bar_width/2 for i in range(len(x))])
axs[1,1].set_xticklabels(x)
axs[1,1].legend()

# Add text on top of each bar
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        axs[1,1].annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

# Create some data
x = ['original', 'first','second','third']
y1 = Human['ADVERBS']
y2 = GPT['ADVERBS']

# Set the width of each bar
bar_width = 0.40

# Create the bar plot
rects1 = axs[1,0].bar(x, y1, bar_width, label='Human')
rects2 = axs[1,0].bar([i + bar_width for i in range(len(x))], y2, bar_width, label='GPT')

# Add labels and a legend
axs[1,0].set_xlabel('Generation')
axs[1,0].set_ylabel('Count')
axs[1,0].set_title('ADVERBS')
axs[1,0].set_xticks([i + bar_width/2 for i in range(len(x))])
axs[1,0].set_xticklabels(x)
axs[1,0].legend()

# Add text on top of each bar
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        axs[1,0].annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

fig.set_size_inches(16, 12)

plt.subplots_adjust(wspace=0.3, hspace=0.3)
fig.suptitle('Comparison of Word Usage Through Generations - No Stopword')

# prepositions
x = ['original', 'first','second','third']
y1 = Human['PREPOSITION']
y2 = GPT['PREPOSITION']

# Set the width of each bar
bar_width = 0.40

# Create the bar plot
rects1 = axs[0,2].bar(x, y1, bar_width, label='Human')
rects2 = axs[0,2].bar([i + bar_width for i in range(len(x))], y2, bar_width, label='GPT')

# Add labels and a legend
axs[0,2].set_xlabel('Generation')
axs[0,2].set_ylabel('Count')
axs[0,2].set_title('PREPOSITIONS')
axs[0,2].set_xticks([i + bar_width/2 for i in range(len(x))])
axs[0,2].set_xticklabels(x)
axs[0,2].legend()

# Add text on top of each bar
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        axs[0,2].annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)


# pronouns
x = ['original', 'first','second','third']
y1 = Human['PRONOUN']
y2 = GPT['PRONOUN']

# Set the width of each bar
bar_width = 0.40

# Create the bar plot
rects1 = axs[1,2].bar(x, y1, bar_width, label='Human')
rects2 = axs[1,2].bar([i + bar_width for i in range(len(x))], y2, bar_width, label='GPT')

# Add labels and a legend
axs[1,2].set_xlabel('Generation')
axs[1,2].set_ylabel('Count')
axs[1,2].set_title('PRONOUNS')
axs[1,2].set_xticks([i + bar_width/2 for i in range(len(x))])
axs[1,2].set_xticklabels(x)
axs[1,2].legend()

# Add text on top of each bar
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        axs[1,2].annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

# Show the plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## 3.4. Visualize Numbers

# %%
x = ['original', 'first','second','third']
y1 = Human['NUMBERS']
y2 = GPT['NUMBERS']

fig, ax = plt.subplots()



# Create the bar plot
rects1 = ax.bar(x, y1, bar_width, label='Human')
rects2 = ax.bar([i + bar_width for i in range(len(x))], y2, bar_width, label='GPT')

# Add labels and a legend
ax.set_xlabel('Generation')
ax.set_ylabel('Count')
ax.set_title('NUMBERS')
ax.set_xticks([i + bar_width/2 for i in range(len(x))])
ax.set_xticklabels(x)
ax.legend()

# Add text on top of each bar
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'NUMBERS'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[82], line 2
#       1 x = ['original', 'first','second','third']
# ----> 2 y1 = Human['NUMBERS']
#       3 y2 = GPT['NUMBERS']
#       5 fig, ax = plt.subplots()
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/mambaforge/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'NUMBERS'
