# %%
#!pip install scipy,seaborn
import seaborn as sns
from scipy.stats import kstest

import pandas as pd
import numpy as np

#!pip install -U plotly
pd.options.plotting.backend = "plotly"

#!pip3 install nltk
import nltk
from nltk import pos_tag
from nltk import word_tokenize
from nltk.corpus import stopwords
from collections import Counter
from nltk.tokenize import word_tokenize, sent_tokenize
from scipy.stats import chi2_contingency

import math
from scipy.stats import shapiro 
from scipy.stats import lognorm
from scipy.stats import mannwhitneyu
import matplotlib.pyplot as plt

#!pip3 install openpyxl
import openpyxl as px
from statsmodels.stats.weightstats import ztest

# %% [markdown]
# ### 0.1. Read Dataset ( N = 114)

# %%
df = pd.read_excel('all_gpt_human_only_text.xlsx')

# %% [markdown]
# ### 1.1. Preprocess and Tag

# %% [markdown]
# Get rid of extra white spaces

# %%
def strip(dataframe):
    return [s.strip() for s in dataframe]

df= df.apply(strip)

# %%
#clean data from stopwords, tokenize it, and tag
punc = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
stop_words = set(stopwords.words('english'))

def create_tokenized(text):
    tokenized = word_tokenize(text)
    tokenized_no_punc = [w.lower() for w in tokenized if w not in punc]
    filtered = [w for w in tokenized_no_punc]# if w not in stop_words]
    'tag the tokens'
    tagged = nltk.pos_tag(filtered)
    return tagged

# %%
## Filter and get words as tokens
for column in df.columns:
    df[f'tokenized_{column}'] = df[column].apply(lambda x: create_tokenized(x))

# %% [markdown]
# ## 2. Get Most Common Adverbs

# %% [markdown]
# ### 2.1. Find Common Adverbs
#
# Store them into list and dict

# %%
def common_adverbs(dataset):
    adverbs = []
    # for 116 stories
    for i in range(116):
        # get every token for the length of tokens in story i
        for y in range(len(dataset.iloc[i])):
            # get the second part (pos-tag), if it is adverb:
            if (dataset.iloc[i][y][1]) == ('RB'or 'RBR'or 'WBR'):
                #print('yes',i, df.tokenized_STORY.iloc[i][y])
                adverbs.append(dataset.iloc[i][y][0])
            else:
                pass
    story_adv = dict(Counter(adverbs))
    sorted_story_adv = sorted(story_adv.items(), key = lambda x:x[1], reverse = True)
    #print(sorted_story_adv[:20])
    return(sorted_story_adv[:20])

# %%
#Apply this function to all stories
story_common_adverbs = common_adverbs(df.tokenized_STORY)

Retell_1_common_adverbs = common_adverbs(df.tokenized_Retell_1)
Retell_2_common_adverbs = common_adverbs(df.tokenized_Retell_2)
Retell_3_common_adverbs = common_adverbs(df.tokenized_Retell_3)

GPT_R1_common_adverbs = common_adverbs(df.tokenized_GPT_R1)
GPT_R2_common_adverbs = common_adverbs(df.tokenized_GPT_R2)
GPT_R3_common_adverbs = common_adverbs(df.tokenized_GPT_R3)

# %%
story_common_adverbs
# Out:
# [("n't", 74),
#  ('not', 72),
#  ('so', 61),
#  ('just', 53),
#  ('very', 44),
#  ('always', 37),
#  ('away', 28),
#  ('now', 28),
#  ('once', 28),
#  ('really', 27),
#  ('well', 26),
#  ('there', 25),
#  ('even', 25),
#  ('then', 24),
#  ('finally', 21),
#  ('ever', 21),
#  ('back', 21),
#  ('never', 18),
#  ('too', 16),
#  ('together', 14)]

# %%
GPT_R1_common_adverbs
# Out:
# [("n't", 19),
#  ('not', 12),
#  ('always', 12),
#  ('away', 10),
#  ('eventually', 10),
#  ('however', 8),
#  ('then', 8),
#  ('finally', 7),
#  ('alone', 7),
#  ('back', 6),
#  ('still', 6),
#  ('together', 5),
#  ('recently', 5),
#  ('now', 5),
#  ('too', 5),
#  ('just', 5),
#  ('later', 4),
#  ('well', 4),
#  ('only', 4),
#  ('up', 4)]

# %%
Retell_1_common_adverbs
# Out:
# [("n't", 48),
#  ('not', 37),
#  ('very', 29),
#  ('so', 27),
#  ('then', 26),
#  ('just', 18),
#  ('always', 15),
#  ('now', 14),
#  ('even', 13),
#  ('well', 12),
#  ('back', 10),
#  ('also', 10),
#  ('never', 10),
#  ('really', 10),
#  ('there', 9),
#  ('once', 9),
#  ('too', 9),
#  ('away', 8),
#  ('up', 8),
#  ('eventually', 8)]

# %%
Retell_2_common_adverbs
# Out:
# [("n't", 42),
#  ('not', 24),
#  ('very', 21),
#  ('so', 17),
#  ('then', 15),
#  ('eventually', 13),
#  ('even', 12),
#  ('just', 11),
#  ('together', 9),
#  ('well', 9),
#  ('again', 8),
#  ('soon', 7),
#  ('once', 7),
#  ('now', 7),
#  ('still', 7),
#  ('too', 6),
#  ('finally', 6),
#  ('there', 6),
#  ('often', 6),
#  ('back', 5)]

# %%
GPT_R2_common_adverbs
# Out:
# [('not', 14),
#  ("n't", 10),
#  ('away', 9),
#  ('eventually', 9),
#  ('still', 7),
#  ('always', 6),
#  ('however', 6),
#  ('alone', 6),
#  ('later', 5),
#  ('only', 5),
#  ('together', 4),
#  ('now', 4),
#  ('back', 4),
#  ('even', 4),
#  ('then', 4),
#  ('never', 4),
#  ('too', 3),
#  ('often', 3),
#  ('unexpectedly', 2),
#  ('so', 2)]

# %%
Retell_3_common_adverbs
# Out:
# [("n't", 28),
#  ('not', 24),
#  ('very', 20),
#  ('then', 14),
#  ('so', 13),
#  ('together', 13),
#  ('really', 10),
#  ('eventually', 9),
#  ('even', 8),
#  ('also', 7),
#  ('just', 7),
#  ('back', 6),
#  ('now', 6),
#  ('well', 6),
#  ('however', 5),
#  ('once', 5),
#  ('up', 5),
#  ('lonely', 5),
#  ('always', 5),
#  ('away', 5)]

# %%
GPT_R3_common_adverbs
# Out:
# [('eventually', 10),
#  ('not', 9),
#  ("n't", 9),
#  ('together', 6),
#  ('still', 6),
#  ('alone', 6),
#  ('away', 5),
#  ('so', 4),
#  ('now', 4),
#  ('only', 4),
#  ('never', 4),
#  ('however', 3),
#  ('too', 3),
#  ('finally', 3),
#  ('just', 3),
#  ('back', 3),
#  ('later', 3),
#  ('always', 3),
#  ('even', 2),
#  ('especially', 2)]

# %% [markdown]
# ### 3. Visualize The Common Adverbs

# %% [markdown]
# ### First Generation

# %%
# Get values from GPT and Human lists 
names = [tup[0] for tup in GPT_R1_common_adverbs]
values = [tup[1] for tup in GPT_R1_common_adverbs]


names_r = [tup[0] for tup in Retell_1_common_adverbs]
values_r= [tup[1] for tup in Retell_1_common_adverbs]



# Human Data
plt.hlines(names_r,values_r,xmax=0, color='orange', label = 'Human', linestyles='dotted')
plt.title("The Most Common 20 Adverbs in First Generation", loc='center')

for i, v in enumerate(values_r):
    plt.text(v + 0.1, i - 0.1, str(v), color='darkorange')
 

# Add titles and axis names
plt.xlabel('Number')
plt.ylabel('Adverb')
plt.legend()
# Show the plot
plt.show()


# GPT Data
plt.hlines(names,values,xmax=0, color='skyblue', label='GPT')

for i, v in enumerate(values):
    plt.text(v + 0.1, i - 0.1, str(v), color='steelblue')

 
 
# Add titles and axis names
plt.xlabel('Number')
plt.ylabel('Adverb')
plt.legend()
# Show the plot
plt.show()


fig, ax = plt.subplots()

# The horizontal plot is made using the hline function
ax.hlines(names,values,xmax=0, color='skyblue', label='GPT')
ax.hlines(names_r,values_r,xmax=0, color='orange', label = 'Human', linestyles='dotted')

    
# Add titles and axis names
plt.xlabel('Number')
plt.ylabel('Adverb')
plt.legend()
# Show the plot
plt.show()

# %% [markdown]
# ### Second Generation

# %%
# Get values from GPT and Human lists 
names = [tup[0] for tup in GPT_R2_common_adverbs]
values = [tup[1] for tup in GPT_R2_common_adverbs]


names_r = [tup[0] for tup in Retell_2_common_adverbs]
values_r= [tup[1] for tup in Retell_2_common_adverbs]



# Human Data
plt.hlines(names_r,values_r,xmax=0, color='orange', label = 'Human', linestyles='dotted')
plt.title("The Most Common 20 Adverbs in Second Generation", loc='center')

for i, v in enumerate(values_r):
    plt.text(v + 0.1, i - 0.1, str(v), color='darkorange')
 

# Add titles and axis names
plt.xlabel('Number')
plt.ylabel('Adverb')
plt.legend()
# Show the plot
plt.show()


# GPT Data
plt.hlines(names,values,xmax=0, color='skyblue', label='GPT')

for i, v in enumerate(values):
    plt.text(v + 0.1, i - 0.1, str(v), color='steelblue')

 
 
# Add titles and axis names
plt.xlabel('Number')
plt.ylabel('Adverb')
plt.legend()
# Show the plot
plt.show()


fig, ax = plt.subplots()

# The horizontal plot is made using the hline function
ax.hlines(names,values,xmax=0, color='skyblue', label='GPT')
ax.hlines(names_r,values_r,xmax=0, color='orange', label = 'Human', linestyles='dotted')

    
# Add titles and axis names
plt.xlabel('Number')
plt.ylabel('Adverb')
plt.legend()
# Show the plot
plt.show()

# %% [markdown]
# ### Third Generation

# %%
# Get values from GPT and Human lists 
names = [tup[0] for tup in GPT_R3_common_adverbs]
values = [tup[1] for tup in GPT_R3_common_adverbs]


names_r = [tup[0] for tup in Retell_3_common_adverbs]
values_r= [tup[1] for tup in Retell_3_common_adverbs]



# Human Data
plt.hlines(names_r,values_r,xmax=0, color='orange', label = 'Human', linestyles='dotted')
plt.title("The Most Common 20 Adverbs in Third Generation", loc='center')

for i, v in enumerate(values_r):
    plt.text(v + 0.1, i - 0.1, str(v), color='darkorange')
 

# Add titles and axis names
plt.xlabel('Number')
plt.ylabel('Adverb')
plt.legend()
# Show the plot
plt.show()


# GPT Data
plt.hlines(names,values,xmax=0, color='skyblue', label='GPT')

for i, v in enumerate(values):
    plt.text(v + 0.1, i - 0.1, str(v), color='steelblue')

 
 
# Add titles and axis names
plt.xlabel('Number')
plt.ylabel('Adverb')
plt.legend()
# Show the plot
plt.show()


fig, ax = plt.subplots()

# The horizontal plot is made using the hline function
ax.hlines(names,values,xmax=0, color='skyblue', label='GPT')
ax.hlines(names_r,values_r,xmax=0, color='orange', label = 'Human', linestyles='dotted')

    
# Add titles and axis names
plt.xlabel('Number')
plt.ylabel('Adverb')
plt.legend()
# Show the plot
plt.show()

# %% [markdown]
# ### Get Unique Differences

# %%
def common_50_adverbs(dataset):
    adverbs = []
    # for 116 stories
    for i in range(116):
        # get every token for the length of tokens in story i
        for y in range(len(dataset.iloc[i])):
            # get the second part (pos-tag), if it is adverb:
            if (dataset.iloc[i][y][1]) == ('RB'or 'RBR'or 'WBR'):
                #print('yes',i, df.tokenized_STORY.iloc[i][y])
                adverbs.append(dataset.iloc[i][y][0])
            else:
                pass
    story_adv = dict(Counter(adverbs))
    #print(sorted_story_adv[:20])
    return(story_adv)

# %%
#Apply this function to all stories
story_common_adverbs = common_50_adverbs(df.tokenized_STORY)

Retell_1_common_adverbs = common_50_adverbs(df.tokenized_Retell_1)
Retell_2_common_adverbs = common_50_adverbs(df.tokenized_Retell_2)
Retell_3_common_adverbs = common_50_adverbs(df.tokenized_Retell_3)

GPT_R1_common_adverbs = common_50_adverbs(df.tokenized_GPT_R1)
GPT_R2_common_adverbs = common_50_adverbs(df.tokenized_GPT_R2)
GPT_R3_common_adverbs = common_50_adverbs(df.tokenized_GPT_R3)

# %%
# Unique to Human
set(Retell_1_common_adverbs.keys())-set(GPT_R1_common_adverbs.keys())
# Out:
# {'actually',
#  'afterward',
#  'alike',
#  'all',
#  'anymore',
#  'anywhere',
#  'around',
#  'ashore',
#  'automatically',
#  'badly',
#  'belly',
#  'chilly',
#  'clearly',
#  'completely',
#  'currently',
#  'dark',
#  'deeply',
#  'desperately',
#  'directly',
#  'down',
#  'easily',
#  'enough',
#  'exactly',
#  'excitedly',
#  'extremely',
#  'far',
#  'forever',
#  'fortunately',
#  'fought',
#  'friday',
#  'greatly',
#  'i',
#  'incredibly',
#  'inside',
#  'long',
#  'longer',
#  'math',
#  'merely',
#  'mildly',
#  'much',
#  'no',
#  'nowhere',
#  'oh',
#  'okay',
#  'otherwise',
#  'out',
#  'outside',
#  'over',
#  'overnight',
#  'perfectly',
#  'pretty',
#  'prior',
#  'probably',
#  'professionally',
#  'quite',
#  'rather',
#  'really',
#  'right',
#  'sam',
#  'seemingly',
#  'sharply',
#  'shortly',
#  'significantly',
#  'simply',
#  'somewhere',
#  'specifically',
#  'steadily',
#  'straight',
#  'suicide',
#  'terribly',
#  'thankfully',
#  'thereafter',
#  'usually',
#  'yearly',
#  'yet'}

# %%
# Unique to GPT
set(GPT_R1_common_adverbs.keys())-set(Retell_1_common_adverbs.keys())
# Out:
# {'ahead',
#  'aimlessly',
#  'almost',
#  'apart',
#  'blindly',
#  'closely',
#  'constantly',
#  'eagerly',
#  'early',
#  'especially',
#  'first',
#  'friendly',
#  'happily',
#  'ill',
#  'initially',
#  'kindly',
#  'pleasantly',
#  'politely',
#  'quietly',
#  'slowly',
#  'successfully',
#  'theater'}

# %%
def combine_dict(d1, d2,d3):
    return {
        k: tuple(d[k] for d in (d1, d2, d3) if k in d)
        for k in set(d1.keys()) | set(d2.keys() | set(d3.keys()))
    }

human_adv = combine_dict(Retell_1_common_adverbs,Retell_2_common_adverbs,Retell_3_common_adverbs)
gpt_adv = combine_dict(GPT_R1_common_adverbs,GPT_R2_common_adverbs,GPT_R3_common_adverbs)

human_adv.keys() - gpt_adv.keys()

gpt_adv.keys()-human_adv.keys()
# Out:
# {'aimlessly',
#  'apart',
#  'blindly',
#  'bravely',
#  'closely',
#  'contentedly',
#  'eagerly',
#  'early',
#  'efficiently',
#  'especially',
#  'first',
#  'friendly',
#  'happily',
#  'ill',
#  'kindly',
#  'lively',
#  'paul',
#  'pleasantly',
#  'politely',
#  'previously',
#  'quietly',
#  'slowly',
#  'successfully',
#  'taught',
#  'teacher',
#  'theater',
#  'tragically',
#  'unexpectedly',
#  'unsuccessfully'}
