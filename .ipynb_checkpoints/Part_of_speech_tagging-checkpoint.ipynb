# %%
#!pip install scipy,seaborn
import seaborn as sns
from scipy.stats import kstest
import re 
import pandas as pd
import numpy as np

#!pip install -U plotly
pd.options.plotting.backend = "plotly"

#!pip3 install nltk
import nltk
from nltk import pos_tag
from nltk import word_tokenize
from nltk.corpus import stopwords
from collections import Counter
from nltk.tokenize import word_tokenize, sent_tokenize
from scipy.stats import chi2_contingency
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

import math
from scipy.stats import shapiro 
from scipy.stats import lognorm
from scipy.stats import mannwhitneyu
import matplotlib.pyplot as plt
import scipy.stats as stats
import statistics
from statsmodels.stats.weightstats import ztest as ztest
import statsmodels

# %% [markdown]
# ### 0.1. Read Dataset ( N = 114)

# %%
df = pd.read_excel('all_gpt_human_only_text.xlsx')

# %% [markdown]
# ### 0.1.1 Preprocess

# %% [markdown]
# Get rid of extra white spaces

# %%
def strip(dataframe):
    return [s.strip() for s in dataframe]

df= df.apply(strip)

# %% [markdown]
# ## 1. Pos Tagging with Less Category Separate for Each Sentence

# %% [markdown]
# Each story's pos taggings completed separately, and counted for the story itself

# %% [markdown]
# ### 1.1. Preprocess and Tag

# %%
#clean data from stopwords, tokenize it, and tag
punc = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
stop_words = set(stopwords.words('english'))

def create_tokenized(text):
    tokenized = word_tokenize(text)
    'tag the tokens'
    tagged = nltk.pos_tag(tokenized)
    return tagged

# %%
## Filter and get words as tokens
for column in df.columns:
    df[f'tokenized_{column}'] = df[column].apply(lambda x: create_tokenized(x))

# %% [markdown]
# ### 1.2. Count the pos-tags

# %%
df.columns
# Out:
# Index(['STORY', 'GPT_R1', 'GPT_R2', 'GPT_R3', 'Retell_1', 'Retell_2',
#        'Retell_3', 'tokenized_STORY', 'tokenized_GPT_R1', 'tokenized_GPT_R2',
#        'tokenized_GPT_R3', 'tokenized_Retell_1', 'tokenized_Retell_2',
#        'tokenized_Retell_3'],
#       dtype='object')

# %%
#count the tags
def count_tags(mydata):
    counter_list=[]
    for i in mydata:
        counter_list.append(i[1])

    tag_counts = Counter(counter_list) 
    return tag_counts

# %%
for column in [col for col in df.columns if col.startswith('tokenized_')]:
    df[f'{column}_tag_counts'] = df[column].apply(lambda x: count_tags(x))

# %%
df.tokenized_STORY_tag_counts
# Out:
# 0      {'DT': 16, 'NN': 23, 'WP': 3, 'VBD': 11, 'IN':...
# 1      {'NNP': 4, 'VBD': 14, 'VBG': 7, 'JJ': 9, 'CD':...
# 2      {'DT': 20, 'NNP': 3, 'VBD': 17, 'TO': 7, 'VB':...
# 3      {'DT': 14, 'IN': 14, 'PRP$': 2, 'NN': 22, ',':...
# 4      {'VBP': 7, 'PRP': 26, 'RB': 9, 'VBD': 18, 'DT'...
#                              ...
# 111    {'NNP': 6, 'VBZ': 4, 'PRP$': 6, 'NN': 29, '``'...
# 112    {'RB': 10, 'EX': 1, 'VBD': 19, 'DT': 31, 'NN':...
# 113    {'EX': 1, 'VBD': 18, 'DT': 20, 'NN': 32, 'WP':...
# 114    {'CD': 1, 'NN': 30, 'DT': 18, 'VBD': 12, 'VBG'...
# 115    {'DT': 15, 'NN': 24, 'VBD': 12, 'RB': 10, 'IN'...
# Name: tokenized_STORY_tag_counts, Length: 116, dtype: object

# %% [markdown]
# ### 1.3. Merge relevant categories together

# %% [markdown]
# Count tags for all nouns (plural nouns, proper nouns etc.), verbs, adjectives, adverbs, pronouns and prepositions/conjuctions/determiners

# %%
for column in [col for col in df.columns if col.endswith('tag_counts')]:
    df[f'{column[:-7]}_noun'] = [*(df[column].apply(lambda x: (x['NN'] + x['NNS'] + x['NNP']+ x['NNPS'])))]
    df[f'{column[:-7]}_verb'] = [*(df[column].apply(lambda x: (x['VB'] + x['VBN'] + x['VBG']+ x['VBZ'] + x['VBP']+x['VBD'])))]
    df[f'{column[:-7]}_adj'] = [*(df[column].apply(lambda x: (x['JJ'] + x['JJS'] + x['JJR'])))]
    df[f'{column[:-7]}_adv'] = [*(df[column].apply(lambda x: (x['RB'] + x['RBR'] + x['WRB'] +x['RBS'])))]
    df[f'{column[:-7]}_pron'] = [*(df[column].apply(lambda x: (x['PRP'] + x['PRP$'] + x['WB']+ x['WB$'])))]
    df[f'{column[:-7]}_con_det_prep'] = [*(df[column].apply(lambda x: (x['DT'] + x['IN'] + x['UH']+ x['TO']+ x['WDT']+ x['EX'])))]
    df[f'{column[:-7]}_prep'] = [*(df[column].apply(lambda x: (x['IN'])))]

# %%
df['tokenized_GPT_R3'].apply(lambda x: len(x))
df.tokenized_GPT_R3_tag_noun
# Out:
# 0      15
# 1      12
# 2      12
# 3       9
# 4      10
#        ..
# 111    13
# 112     7
# 113    12
# 114    11
# 115    11
# Name: tokenized_GPT_R3_tag_noun, Length: 116, dtype: int64

# %% [markdown]
# ## 1.4. Get Ratio of Grammatical Categories to Word Count

# %%
#Nouns
df['GPT_3_noun_ratio'] = (df.tokenized_GPT_R3_tag_noun / (df['tokenized_GPT_R3'].apply(lambda x: len(x))))
df['GPT_2_noun_ratio'] = (df.tokenized_GPT_R2_tag_noun / (df['tokenized_GPT_R2'].apply(lambda x: len(x))))
df['GPT_1_noun_ratio'] = (df.tokenized_GPT_R1_tag_noun / (df['tokenized_GPT_R1'].apply(lambda x: len(x))))

df['Retell_1_noun_ratio'] = (df.tokenized_Retell_1_tag_noun / (df['tokenized_Retell_1'].apply(lambda x: len(x))))
df['Retell_2_noun_ratio'] = (df.tokenized_Retell_2_tag_noun / (df['tokenized_Retell_2'].apply(lambda x: len(x))))
df['Retell_3_noun_ratio'] = (df.tokenized_Retell_3_tag_noun / (df['tokenized_Retell_3'].apply(lambda x: len(x))))

df['story_noun_ratio'] = (df.tokenized_STORY_tag_noun / (df['tokenized_STORY'].apply(lambda x: len(x))))


#Verbs
df['GPT_3_verb_ratio'] = (df.tokenized_GPT_R3_tag_verb / (df['tokenized_GPT_R3'].apply(lambda x: len(x))))
df['GPT_2_verb_ratio'] = (df.tokenized_GPT_R2_tag_verb / (df['tokenized_GPT_R2'].apply(lambda x: len(x))))
df['GPT_1_verb_ratio'] = (df.tokenized_GPT_R1_tag_verb / (df['tokenized_GPT_R1'].apply(lambda x: len(x))))

df['Retell_1_verb_ratio'] = (df.tokenized_Retell_1_tag_verb / (df['tokenized_Retell_1'].apply(lambda x: len(x))))
df['Retell_2_verb_ratio'] = (df.tokenized_Retell_2_tag_verb / (df['tokenized_Retell_2'].apply(lambda x: len(x))))
df['Retell_3_verb_ratio'] = (df.tokenized_Retell_3_tag_verb / (df['tokenized_Retell_3'].apply(lambda x: len(x))))

df['story_verb_ratio'] = (df.tokenized_STORY_tag_verb / (df['tokenized_STORY'].apply(lambda x: len(x))))

#Adj 
df['GPT_3_adj_ratio'] = (df.tokenized_GPT_R3_tag_adj / (df['tokenized_GPT_R3'].apply(lambda x: len(x))))
df['GPT_2_adj_ratio'] = (df.tokenized_GPT_R2_tag_adj / (df['tokenized_GPT_R2'].apply(lambda x: len(x))))
df['GPT_1_adj_ratio'] = (df.tokenized_GPT_R1_tag_adj / (df['tokenized_GPT_R1'].apply(lambda x: len(x))))

df['Retell_1_adj_ratio'] = (df.tokenized_Retell_1_tag_adj / (df['tokenized_Retell_1'].apply(lambda x: len(x))))
df['Retell_2_adj_ratio'] = (df.tokenized_Retell_2_tag_adj / (df['tokenized_Retell_2'].apply(lambda x: len(x))))
df['Retell_3_adj_ratio'] = (df.tokenized_Retell_3_tag_adj / (df['tokenized_Retell_3'].apply(lambda x: len(x))))

df['story_adj_ratio'] = (df.tokenized_STORY_tag_adj / (df['tokenized_STORY'].apply(lambda x: len(x))))

#Adv
df['GPT_3_adv_ratio'] = (df.tokenized_GPT_R3_tag_adv / (df['tokenized_GPT_R3'].apply(lambda x: len(x))))
df['GPT_2_adv_ratio'] = (df.tokenized_GPT_R2_tag_adv / (df['tokenized_GPT_R2'].apply(lambda x: len(x))))
df['GPT_1_adv_ratio'] = (df.tokenized_GPT_R1_tag_adv / (df['tokenized_GPT_R1'].apply(lambda x: len(x))))

df['Retell_1_adv_ratio'] = (df.tokenized_Retell_1_tag_adv / (df['tokenized_Retell_1'].apply(lambda x: len(x))))
df['Retell_2_adv_ratio'] = (df.tokenized_Retell_2_tag_adv / (df['tokenized_Retell_2'].apply(lambda x: len(x))))
df['Retell_3_adv_ratio'] = (df.tokenized_Retell_3_tag_adv / (df['tokenized_Retell_3'].apply(lambda x: len(x))))

df['story_adv_ratio'] = (df.tokenized_STORY_tag_adv / (df['tokenized_STORY'].apply(lambda x: len(x))))


#Prep_con_det
df['GPT_3_con_det_prep_ratio'] = (df.tokenized_GPT_R3_tag_con_det_prep / (df['tokenized_GPT_R3'].apply(lambda x: len(x))))
df['GPT_2_con_det_prep_ratio'] = (df.tokenized_GPT_R2_tag_con_det_prep / (df['tokenized_GPT_R2'].apply(lambda x: len(x))))
df['GPT_1_con_det_prep_ratio'] = (df.tokenized_GPT_R1_tag_con_det_prep / (df['tokenized_GPT_R1'].apply(lambda x: len(x))))

df['Retell_1_con_det_prep_ratio'] = (df.tokenized_Retell_1_tag_con_det_prep / (df['tokenized_Retell_1'].apply(lambda x: len(x))))
df['Retell_2_con_det_prep_ratio'] = (df.tokenized_Retell_2_tag_con_det_prep / (df['tokenized_Retell_2'].apply(lambda x: len(x))))
df['Retell_3_con_det_prep_ratio'] = (df.tokenized_Retell_3_tag_con_det_prep / (df['tokenized_Retell_3'].apply(lambda x: len(x))))

df['story_con_det_prep_ratio'] = (df.tokenized_STORY_tag_con_det_prep / (df['tokenized_STORY'].apply(lambda x: len(x))))


#pron
df['GPT_3_pron_ratio'] = (df.tokenized_GPT_R3_tag_pron / (df['tokenized_GPT_R3'].apply(lambda x: len(x))))
df['GPT_2_pron_ratio'] = (df.tokenized_GPT_R2_tag_pron / (df['tokenized_GPT_R2'].apply(lambda x: len(x))))
df['GPT_1_pron_ratio'] = (df.tokenized_GPT_R1_tag_pron / (df['tokenized_GPT_R1'].apply(lambda x: len(x))))

df['Retell_1_pron_ratio'] = (df.tokenized_Retell_1_tag_pron / (df['tokenized_Retell_1'].apply(lambda x: len(x))))
df['Retell_2_pron_ratio'] = (df.tokenized_Retell_2_tag_pron / (df['tokenized_Retell_2'].apply(lambda x: len(x))))
df['Retell_3_pron_ratio'] = (df.tokenized_Retell_3_tag_pron / (df['tokenized_Retell_3'].apply(lambda x: len(x))))

df['story_pron_ratio'] = (df.tokenized_STORY_tag_pron / (df['tokenized_STORY'].apply(lambda x: len(x))))

#Prep
df['GPT_3_prep_ratio'] = (df.tokenized_GPT_R3_tag_prep / (df['tokenized_GPT_R3'].apply(lambda x: len(x))))
df['GPT_2_prep_ratio'] = (df.tokenized_GPT_R2_tag_prep / (df['tokenized_GPT_R2'].apply(lambda x: len(x))))
df['GPT_1_prep_ratio'] = (df.tokenized_GPT_R1_tag_prep / (df['tokenized_GPT_R1'].apply(lambda x: len(x))))

df['Retell_1_prep_ratio'] = (df.tokenized_Retell_1_tag_prep / (df['tokenized_Retell_1'].apply(lambda x: len(x))))
df['Retell_2_prep_ratio'] = (df.tokenized_Retell_2_tag_prep / (df['tokenized_Retell_2'].apply(lambda x: len(x))))
df['Retell_3_prep_ratio'] = (df.tokenized_Retell_3_tag_prep / (df['tokenized_Retell_3'].apply(lambda x: len(x))))

df['story_prep_ratio'] = (df.tokenized_STORY_tag_prep / (df['tokenized_STORY'].apply(lambda x: len(x))))
# Out:
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_4725/66409552.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['GPT_2_pron_ratio'] = (df.tokenized_GPT_R2_tag_pron / (df['tokenized_GPT_R2'].apply(lambda x: len(x))))
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_4725/66409552.py:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['GPT_1_pron_ratio'] = (df.tokenized_GPT_R1_tag_pron / (df['tokenized_GPT_R1'].apply(lambda x: len(x))))
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_4725/66409552.py:64: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Retell_1_pron_ratio'] = (df.tokenized_Retell_1_tag_pron / (df['tokenized_Retell_1'].apply(lambda x: len(x))))
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_4725/66409552.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Retell_2_pron_ratio'] = (df.tokenized_Retell_2_tag_pron / (df['tokenized_Retell_2'].apply(lambda x: len(x))))
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_4725/66409552.py:66: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Retell_3_pron_ratio'] = (df.tokenized_Retell_3_tag_pron / (df['tokenized_Retell_3'].apply(lambda x: len(x))))
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_4725/66409552.py:68: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['story_pron_ratio'] = (df.tokenized_STORY_tag_pron / (df['tokenized_STORY'].apply(lambda x: len(x))))
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_4725/66409552.py:71: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['GPT_3_prep_ratio'] = (df.tokenized_GPT_R3_tag_prep / (df['tokenized_GPT_R3'].apply(lambda x: len(x))))
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_4725/66409552.py:72: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['GPT_2_prep_ratio'] = (df.tokenized_GPT_R2_tag_prep / (df['tokenized_GPT_R2'].apply(lambda x: len(x))))
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_4725/66409552.py:73: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['GPT_1_prep_ratio'] = (df.tokenized_GPT_R1_tag_prep / (df['tokenized_GPT_R1'].apply(lambda x: len(x))))
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_4725/66409552.py:75: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Retell_1_prep_ratio'] = (df.tokenized_Retell_1_tag_prep / (df['tokenized_Retell_1'].apply(lambda x: len(x))))
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_4725/66409552.py:76: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Retell_2_prep_ratio'] = (df.tokenized_Retell_2_tag_prep / (df['tokenized_Retell_2'].apply(lambda x: len(x))))
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_4725/66409552.py:77: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Retell_3_prep_ratio'] = (df.tokenized_Retell_3_tag_prep / (df['tokenized_Retell_3'].apply(lambda x: len(x))))
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_4725/66409552.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['story_prep_ratio'] = (df.tokenized_STORY_tag_prep / (df['tokenized_STORY'].apply(lambda x: len(x))))

# %% [markdown]
# ### 1.4.1. Carry counts and ratios into different DataFrame

# %%
count_ratio = pd.DataFrame

count_ratio= df[['GPT_3_noun_ratio',
 'GPT_2_noun_ratio',
 'GPT_1_noun_ratio',
 'Retell_1_noun_ratio',
 'Retell_2_noun_ratio',
 'Retell_3_noun_ratio',
 'story_noun_ratio',
 'GPT_3_verb_ratio',
 'GPT_2_verb_ratio',
 'GPT_1_verb_ratio',
 'Retell_1_verb_ratio',
 'Retell_2_verb_ratio',
 'Retell_3_verb_ratio',
 'story_verb_ratio',
 'GPT_3_adj_ratio',
 'GPT_2_adj_ratio',
 'GPT_1_adj_ratio',
 'Retell_1_adj_ratio',
 'Retell_2_adj_ratio',
 'Retell_3_adj_ratio',
 'story_adj_ratio',
 'GPT_3_adv_ratio',
 'GPT_2_adv_ratio',
 'GPT_1_adv_ratio',
 'Retell_1_adv_ratio',
 'Retell_2_adv_ratio',
 'Retell_3_adv_ratio',
 'story_adv_ratio',
 'GPT_3_con_det_prep_ratio',
 'GPT_2_con_det_prep_ratio',
 'GPT_1_con_det_prep_ratio',
 'Retell_1_con_det_prep_ratio',
 'Retell_2_con_det_prep_ratio',
 'Retell_3_con_det_prep_ratio',
 'story_con_det_prep_ratio',
 'GPT_3_pron_ratio',
 'GPT_2_pron_ratio',
 'GPT_1_pron_ratio',
 'Retell_1_pron_ratio',
 'Retell_2_pron_ratio',
 'Retell_3_pron_ratio',
 'story_pron_ratio',
 'GPT_3_prep_ratio',
 'GPT_2_prep_ratio',
 'GPT_1_prep_ratio',
 'Retell_1_prep_ratio',
 'Retell_2_prep_ratio',
 'Retell_3_prep_ratio',
 'story_prep_ratio']]

# %%
#store counts into a dataframe 
counts = pd.DataFrame()

df_count = df[['tokenized_STORY_tag_noun',
 'tokenized_STORY_tag_verb',
 'tokenized_STORY_tag_adj',
 'tokenized_STORY_tag_adv',
 'tokenized_STORY_tag_pron',
 'tokenized_STORY_tag_con_det_prep',
 'tokenized_STORY_tag_prep',
 'tokenized_GPT_R1_tag_noun',
 'tokenized_GPT_R1_tag_verb',
 'tokenized_GPT_R1_tag_adj',
 'tokenized_GPT_R1_tag_adv',
 'tokenized_GPT_R1_tag_pron',
 'tokenized_GPT_R1_tag_con_det_prep',
 'tokenized_GPT_R1_tag_prep',
 'tokenized_GPT_R2_tag_noun',
 'tokenized_GPT_R2_tag_verb',
 'tokenized_GPT_R2_tag_adj',
 'tokenized_GPT_R2_tag_adv',
 'tokenized_GPT_R2_tag_pron',
 'tokenized_GPT_R2_tag_con_det_prep',
 'tokenized_GPT_R2_tag_prep',
 'tokenized_GPT_R3_tag_noun',
 'tokenized_GPT_R3_tag_verb',
 'tokenized_GPT_R3_tag_adj',
 'tokenized_GPT_R3_tag_adv',
 'tokenized_GPT_R3_tag_pron',
 'tokenized_GPT_R3_tag_con_det_prep',
 'tokenized_GPT_R3_tag_prep',
 'tokenized_Retell_1_tag_noun',
 'tokenized_Retell_1_tag_verb',
 'tokenized_Retell_1_tag_adj',
 'tokenized_Retell_1_tag_adv',
 'tokenized_Retell_1_tag_pron',
 'tokenized_Retell_1_tag_con_det_prep',
 'tokenized_Retell_1_tag_prep',
 'tokenized_Retell_2_tag_noun',
 'tokenized_Retell_2_tag_verb',
 'tokenized_Retell_2_tag_adj',
 'tokenized_Retell_2_tag_adv',
 'tokenized_Retell_2_tag_pron',
 'tokenized_Retell_2_tag_con_det_prep',
 'tokenized_Retell_2_tag_prep',
 'tokenized_Retell_3_tag_noun',
 'tokenized_Retell_3_tag_verb',
 'tokenized_Retell_3_tag_adj',
 'tokenized_Retell_3_tag_adv',
 'tokenized_Retell_3_tag_pron',
 'tokenized_Retell_3_tag_con_det_prep',
 'tokenized_Retell_3_tag_prep']

]

# %% [markdown]
# Our dataframes are:
#
# 1-count = df_count
# 2- ratio = count_ratio

# %% [markdown]
# ### 1.5. Significance Test Between Retellings (Counts of Words)

# %%
mannwhitneyu(df_count['tokenized_GPT_R3_tag_con_det_prep'], df_count['tokenized_Retell_3_tag_con_det_prep']) #significant
# Out:
# MannwhitneyuResult(statistic=7192.0, pvalue=0.3630124596135751)

# %%
shapiro(df_count) #data is not normal, so we will use Mann-u Whitney
# Out:
# /Users/eotenen/mambaforge/lib/python3.10/site-packages/scipy/stats/_morestats.py:1816: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# ShapiroResult(statistic=0.8291227221488953, pvalue=0.0)

# %%
u,p=mannwhitneyu(df_count['tokenized_GPT_R1_tag_adv'], df_count['tokenized_GPT_R1_tag_adv'])
print(u,p)
# Out:
# 6728.0 1.0

# %%
tags = ['noun', 'verb', 'adj', 'adv', 'pron', 'con_det_prep', 'prep']

for tag in tags:
    for i in range(1, 4):
        gpt_tag = f"tokenized_GPT_R{i}_tag_{tag}"
        retell_tag = f"tokenized_Retell_{i}_tag_{tag}"

        stat,p_value = mannwhitneyu(df_count[gpt_tag], df_count[retell_tag])
        if p_value < 0.05:
            print(f"{tag.capitalize()}s in GPT_R{i} and Retell_{i} are significantly different (stat={stat}, p-value={p_value:.3f}), gpt= {df_count[gpt_tag].mean()}, human= {df_count[retell_tag].mean()}.")
        else:
            print(f"{tag.capitalize()}s in GPT_R{i} and Retell_{i} are not significantly different ( stat={stat},p-value={p_value:.3f}), gpt= {df_count[gpt_tag].mean()}, human= {df_count[retell_tag].mean()}.")
# Out:
# Nouns in GPT_R1 and Retell_1 are significantly different (stat=5402.0, p-value=0.009), gpt= 13.301724137931034, human= 16.396551724137932.
# Nouns in GPT_R2 and Retell_2 are not significantly different ( stat=6819.0,p-value=0.859), gpt= 11.758620689655173, human= 12.525862068965518.
# Nouns in GPT_R3 and Retell_3 are significantly different (stat=8512.5, p-value=0.000), gpt= 10.663793103448276, human= 9.491379310344827.
# Verbs in GPT_R1 and Retell_1 are significantly different (stat=2730.0, p-value=0.000), gpt= 10.129310344827585, human= 16.189655172413794.
# Verbs in GPT_R2 and Retell_2 are significantly different (stat=4472.0, p-value=0.000), gpt= 8.387931034482758, human= 11.637931034482758.
# Verbs in GPT_R3 and Retell_3 are significantly different (stat=5542.0, p-value=0.020), gpt= 7.836206896551724, human= 9.491379310344827.
# Adjs in GPT_R1 and Retell_1 are significantly different (stat=5205.0, p-value=0.003), gpt= 3.4224137931034484, human= 4.491379310344827.
# Adjs in GPT_R2 and Retell_2 are not significantly different ( stat=7059.0,p-value=0.512), gpt= 3.1724137931034484, human= 3.060344827586207.
# Adjs in GPT_R3 and Retell_3 are significantly different (stat=7995.5, p-value=0.012), gpt= 2.75, human= 2.3448275862068964.
# Advs in GPT_R1 and Retell_1 are significantly different (stat=2775.5, p-value=0.000), gpt= 2.1551724137931036, human= 5.172413793103448.
# Advs in GPT_R2 and Retell_2 are significantly different (stat=3393.5, p-value=0.000), gpt= 1.5775862068965518, human= 3.646551724137931.
# Advs in GPT_R3 and Retell_3 are significantly different (stat=4124.0, p-value=0.000), gpt= 1.3879310344827587, human= 2.9655172413793105.
# Prons in GPT_R1 and Retell_1 are significantly different (stat=2940.0, p-value=0.000), gpt= 4.594827586206897, human= 9.525862068965518.
# Prons in GPT_R2 and Retell_2 are significantly different (stat=3776.5, p-value=0.000), gpt= 3.689655172413793, human= 6.844827586206897.
# Prons in GPT_R3 and Retell_3 are significantly different (stat=4394.5, p-value=0.000), gpt= 3.4310344827586206, human= 5.491379310344827.
# Con_det_preps in GPT_R1 and Retell_1 are significantly different (stat=4303.5, p-value=0.000), gpt= 12.64655172413793, human= 16.54310344827586.
# Con_det_preps in GPT_R2 and Retell_2 are not significantly different ( stat=6222.5,p-value=0.322), gpt= 11.181034482758621, human= 12.5.
# Con_det_preps in GPT_R3 and Retell_3 are not significantly different ( stat=7192.0,p-value=0.363), gpt= 10.155172413793103, human= 10.586206896551724.
# Preps in GPT_R1 and Retell_1 are significantly different (stat=5375.5, p-value=0.008), gpt= 5.181034482758621, human= 6.491379310344827.
# Preps in GPT_R2 and Retell_2 are not significantly different ( stat=6865.0,p-value=0.788), gpt= 4.612068965517241, human= 4.896551724137931.
# Preps in GPT_R3 and Retell_3 are not significantly different ( stat=7182.0,p-value=0.369), gpt= 4.189655172413793, human= 4.137931034482759.

# %% [markdown]
# ### Results:
#
# Means are reported in parantheses.
#
# 0-nouns are significantly different in first (human = 15.50 , gpt = 13.06) last the retelling of Human (m=9.48) and GPT(m=10.31).
#
#
# 1-verbs are significantly different in first (human=16.71, gpt = 10.22), second (human =12.09 ,gpt = 8.57) and third (human = 9.77, gpt = 8.02) retellings between Human and GPT retellings.
#
#
# 2-adjectives are significantly different in first (human = 5.11, gpt = 3.58), and third (human = 2.50, gpt = 2.90) retellings between Human and GPT retellings.
#
#
# 3-adverbs are significantly different in first (human = 4.80, gpt = 2.01 ), second (human = 3.36, gpt = 1.38) and third (human = 2.63, gpt = 1.26) retellings between Human and GPT retellings.
#
# 4- pronouns are significantly different in first (human = 8.72, gpt = 4.53), second (human = 6.23,gpt = 3.70), and last retellings (human = 5.0,gpt = 3.43)
#
# 5-prepositions/conjuctions/determiners are different in first (human = 16.85,gpt = 12.71)
#
# 6- Prepositions only are significant in first retellings (human = 6.72, gpt = 5.22).

# %% [markdown]
# ### 1.6. Visualize Counts

# %% [markdown]
# Prepare dataset accordingly

# %%
count_means = pd.DataFrame()
count_means['mean'] = [*df_count.mean()]
count_means['gen']= ['origin','origin','origin','origin','origin','origin','origin','GPT_R1','GPT_R1','GPT_R1','GPT_R1','GPT_R1','GPT_R1','GPT_R1','GPT_R2','GPT_R2','GPT_R2','GPT_R2','GPT_R2','GPT_R2','GPT_R2','GPT_R3','GPT_R3','GPT_R3','GPT_R3','GPT_R3','GPT_R3','GPT_R3','Retell_1','Retell_1','Retell_1','Retell_1','Retell_1','Retell_1','Retell_1','Retell_2','Retell_2','Retell_2','Retell_2','Retell_2','Retell_2','Retell_2','Retell_3','Retell_3','Retell_3','Retell_3','Retell_3','Retell_3','Retell_3']
count_means['type']= ['noun','verb','adj','adv','pron','con_det_prep','prep','noun','verb','adj','adv','pron','con_det_prep','prep','noun','verb','adj','adv','pron','con_det_prep','prep','noun','verb','adj','adv','pron','con_det_prep','prep','noun','verb','adj','adv','pron','con_det_prep','prep','noun','verb','adj','adv','pron','con_det_prep','prep','noun','verb','adj','adv','pron','con_det_prep','prep']

#ignore 'con_det_prep'
count_means = count_means[count_means['type']!='con_det_prep']

# %% [markdown]
# #### 1.6.1. First Generation

# %%
first_gen = count_means.loc[count_means['gen'].isin(['GPT_R1', 'Retell_1'])]

sns.lineplot(data=first_gen, x="type", y="mean", hue="gen").set(title='Mean of Grammatical Categories')
# Out:
# [Text(0.5, 1.0, 'Mean of Grammatical Categories')]

# %%
X = np.arange(6)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(X + 0.00, first_gen[first_gen['gen']=='Retell_1']['mean'], color = 'steelblue', width = 0.25, label ='Human')
ax.bar(X + 0.25, first_gen[first_gen['gen']=='GPT_R1']['mean'], color = 'orange', width = 0.25, label = 'GPT')
ax.set_xticklabels(['noun', 'verb', 'adj', 'adv', 'pron', 'prep'])  # Set the x-tick labels
ax.set_title('Mean Grammatical Categories in First Generation')
ax.grid(True, color = 'lightgrey', linewidth=1)
ax.legend()
# Out:
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_4725/404552009.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['noun', 'verb', 'adj', 'adv', 'pron', 'prep'])  # Set the x-tick labels

# %% [markdown]
# #### 1.6.2. Second Generation

# %%
second_gen = count_means.loc[count_means['gen'].isin(['GPT_R2', 'Retell_2'])]

sns.lineplot(data=second_gen, x="type", y="mean", hue="gen").set(title='Mean of Grammatical Categories')
# Out:
# [Text(0.5, 1.0, 'Mean of Grammatical Categories')]

# %%
second_gen[second_gen['gen']=='Retell_2']
# Out:
#          mean       gen  type
# 35  12.525862  Retell_2  noun
# 36  11.637931  Retell_2  verb
# 37   3.060345  Retell_2   adj
# 38   3.646552  Retell_2   adv
# 39   6.844828  Retell_2  pron
# 41   4.896552  Retell_2  prep

# %%
X = np.arange(6)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(X + 0.00, second_gen[second_gen['gen']=='Retell_2']['mean'], color = 'steelblue', width = 0.25, label ='Human')
ax.bar(X + 0.25, second_gen[second_gen['gen']=='GPT_R2']['mean'], color = 'orange', width = 0.25, label = 'GPT')
ax.set_xticklabels(['','noun', 'verb', 'adj', 'adv', 'pron', 'prep'])  # Set the x-tick labels
ax.set_title('Mean Grammatical Categories in Second Generation')
ax.grid(True, color = 'lightgrey', linewidth=1)
ax.legend()
# Out:
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_4725/214029157.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['','noun', 'verb', 'adj', 'adv', 'pron', 'prep'])  # Set the x-tick labels

# %% [markdown]
# #### 1.6.3. Third Generation

# %%
third_gen = count_means.loc[count_means['gen'].isin(['GPT_R3', 'Retell_3'])]

sns.lineplot(data=third_gen, x="type", y="mean", hue="gen").set(title='Mean of Grammatical Categories')
# Out:
# [Text(0.5, 1.0, 'Mean of Grammatical Categories')]

# %%
X = np.arange(6)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(X + 0.00, third_gen[third_gen['gen']=='Retell_3']['mean'], color = 'steelblue', width = 0.25, label ='Human')
ax.bar(X + 0.25, third_gen[third_gen['gen']=='GPT_R3']['mean'], color = 'orange', width = 0.25, label = 'GPT')
ax.set_xticklabels(['','noun', 'verb', 'adj', 'adv', 'pron', 'con_det_prep', 'prep'])  # Set the x-tick labels
ax.set_title('Mean Grammatical Categories in Third Generation')
ax.grid(True, color = 'lightgrey', linewidth=1)

ax.legend()
# Out:
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_4725/2279553967.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['','noun', 'verb', 'adj', 'adv', 'pron', 'con_det_prep', 'prep'])  # Set the x-tick labels

# %% [markdown]
# #### 1.6.4. All Together

# %%
import numpy as np
import matplotlib.pyplot as plt

# First subplot
X = np.arange(6)
fig, axes = plt.subplots(1, 3, figsize=(30, 10))  # Create a grid of subplots
ax = axes[0]  # First subplot
ax.bar(X + 0.00, first_gen[first_gen['gen'] == 'Retell_1']['mean'], color='steelblue', width=0.25, label='Human')
ax.bar(X + 0.25, first_gen[first_gen['gen'] == 'GPT_R1']['mean'], color='orange', width=0.25, label='GPT')
ax.set_xticklabels(['', 'noun', 'verb', 'adj', 'adv', 'pron', 'prep'],fontsize=30)  # Set the x-tick labels
ax.tick_params(axis='y', labelsize=30)

ax.set_title('First Generation',fontsize=34)
ax.grid(True, color='lightgrey', linewidth=0.7)
ax.legend(fontsize=30)


# Second subplot
ax = axes[1]  # Second subplot
ax.bar(X + 0.00, second_gen[second_gen['gen'] == 'Retell_2']['mean'], color='steelblue', width=0.25, label='Human')
ax.bar(X + 0.25, second_gen[second_gen['gen'] == 'GPT_R2']['mean'], color='orange', width=0.25, label='GPT')
ax.set_xticklabels(['', 'noun', 'verb', 'adj', 'adv', 'pron', 'prep'],fontsize=30)  # Set the x-tick labels
ax.set_title('Second Generation',fontsize=34)
ax.grid(True, color='lightgrey', linewidth=0.7)
ax.legend(fontsize=30)
ax.tick_params(axis='y', labelsize=30)



# Third subplot
ax = axes[2]  # Third subplot
ax.bar(X + 0.00, third_gen[third_gen['gen'] == 'Retell_3']['mean'], color='steelblue', width=0.25, label='Human')
ax.bar(X + 0.25, third_gen[third_gen['gen'] == 'GPT_R3']['mean'], color='orange', width=0.25, label='GPT')
ax.set_xticklabels(['', 'noun', 'verb', 'adj', 'adv', 'pron', 'prep'],fontsize=30)  # Set the x-tick labels
ax.set_title('Third Generation',fontsize=34)
ax.grid(True, color='lightgrey', linewidth=0.7)
ax.tick_params(axis='y', labelsize=30)
ax.legend(fontsize=30)

plt.tight_layout()  # Adjust spacing between subplots
plt.suptitle('Mean Grammatical Categories Comparison',fontsize=40)  # Add overall title
plt.subplots_adjust(top=0.85)


plt.savefig('all_count_plot.png') 
plt.show()
# Out:
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_4725/2113861403.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['', 'noun', 'verb', 'adj', 'adv', 'pron', 'prep'],fontsize=30)  # Set the x-tick labels
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_4725/2113861403.py:22: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['', 'noun', 'verb', 'adj', 'adv', 'pron', 'prep'],fontsize=30)  # Set the x-tick labels
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_4725/2113861403.py:34: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['', 'noun', 'verb', 'adj', 'adv', 'pron', 'prep'],fontsize=30)  # Set the x-tick labels

# %% [markdown]
# ### 1.7. Statistical Test for Ratios

# %%
#!pip3 install statsmodels
#Because the values are proportions, I conducted a z-test analysis 

import statsmodels.api as sm

# create a list of tuples for each POS category
pos_categories = [('noun', 'Retell_1_noun_ratio', 'GPT_1_noun_ratio'),
                  ('noun', 'Retell_2_noun_ratio', 'GPT_2_noun_ratio'),
                  ('noun', 'Retell_3_noun_ratio', 'GPT_3_noun_ratio'),
                  ('verb', 'Retell_1_verb_ratio', 'GPT_1_verb_ratio'),
                  ('verb', 'Retell_2_verb_ratio', 'GPT_2_verb_ratio'),
                  ('verb', 'Retell_3_verb_ratio', 'GPT_3_verb_ratio'),
                  ('adj', 'Retell_1_adj_ratio', 'GPT_1_adj_ratio'),
                  ('adj', 'Retell_2_adj_ratio', 'GPT_2_adj_ratio'),
                  ('adj', 'Retell_3_adj_ratio', 'GPT_3_adj_ratio'),
                  ('adv', 'Retell_1_adv_ratio', 'GPT_1_adv_ratio'),
                  ('adv', 'Retell_2_adv_ratio', 'GPT_2_adv_ratio'),
                  ('adv', 'Retell_3_adv_ratio', 'GPT_3_adv_ratio'),
                  ('pron', 'Retell_1_pron_ratio', 'GPT_1_pron_ratio'),
                  ('pron', 'Retell_2_pron_ratio', 'GPT_2_pron_ratio'),
                  ('pron', 'Retell_3_pron_ratio', 'GPT_3_pron_ratio'),
                  ('det_con_prep', 'Retell_1_con_det_prep_ratio', 'GPT_1_con_det_prep_ratio'),
                  ('det_con_prep', 'Retell_2_con_det_prep_ratio', 'GPT_2_con_det_prep_ratio'),
                  ('det_con_prep', 'Retell_3_con_det_prep_ratio', 'GPT_3_con_det_prep_ratio'),
                  ('prep', 'Retell_1_prep_ratio', 'GPT_1_prep_ratio'),
                  ('prep', 'Retell_2_prep_ratio', 'GPT_2_prep_ratio'),
                  ('prep', 'Retell_3_prep_ratio', 'GPT_3_prep_ratio')]

# loop through the list of tuples and conduct the z-tests
for pos_category in pos_categories:
    pos = pos_category[0]
    x1 = pos_category[1]
    x2 = pos_category[2]
    
    print(f" Analysis of ratio of {pos}")
    ztest, pval = sm.stats.ztest(count_ratio[x1], count_ratio[x2], value=0)
    if pval < 0.05:
        print(f"Significant difference in {pos} between {[x1],[x2],} p value: {pval}, z = {ztest}, and human m = {count_ratio[x1].mean()} gpt m = {count_ratio[x2].mean()}\n")
    else:
        print(f"No difference in {pos} between {[x1],[x2],} p value: {pval}, z = {ztest}, and human m = {count_ratio[x1].mean()} gpt m = {count_ratio[x2].mean()}\n"
        )
# Out:
#  Analysis of ratio of noun
# Significant difference in noun between (['Retell_1_noun_ratio'], ['GPT_1_noun_ratio']) p value: 0.01038213843880936, z = -2.562834969409483, and human m = 0.2089179785515647 gpt m = 0.23816699203422456
#
#  Analysis of ratio of noun
# Significant difference in noun between (['Retell_2_noun_ratio'], ['GPT_2_noun_ratio']) p value: 0.005362388513004804, z = -2.78441795768284, and human m = 0.21736709212534772 gpt m = 0.24678940764913457
#
#  Analysis of ratio of noun
# Significant difference in noun between (['Retell_3_noun_ratio'], ['GPT_3_noun_ratio']) p value: 7.539267456495625e-10, z = -6.1543360413320825, and human m = 0.20207897027774702 gpt m = 0.24569272217578325
#
#  Analysis of ratio of verb
# Significant difference in verb between (['Retell_1_verb_ratio'], ['GPT_1_verb_ratio']) p value: 0.015661071937678506, z = 2.416719699827266, and human m = 0.19494229191772317 gpt m = 0.1821071998136473
#
#  Analysis of ratio of verb
# Significant difference in verb between (['Retell_2_verb_ratio'], ['GPT_2_verb_ratio']) p value: 0.003736524233064645, z = 2.899588854550243, and human m = 0.1909065967019348 gpt m = 0.17328249164915627
#
#  Analysis of ratio of verb
# Significant difference in verb between (['Retell_3_verb_ratio'], ['GPT_3_verb_ratio']) p value: 0.0008829128551335992, z = 3.325401517454967, and human m = 0.19824604691065664 gpt m = 0.17889740122236275
#
#  Analysis of ratio of adj
# No difference in adj between (['Retell_1_adj_ratio'], ['GPT_1_adj_ratio']) p value: 0.21645146798762172, z = -1.236019089474745, and human m = 0.05549751868428395 gpt m = 0.06062971147173831
#
#  Analysis of ratio of adj
# Significant difference in adj between (['Retell_2_adj_ratio'], ['GPT_2_adj_ratio']) p value: 0.003000222915959016, z = -2.9677150849345795, and human m = 0.05354393268487712 gpt m = 0.06681344303040104
#
#  Analysis of ratio of adj
# Significant difference in adj between (['Retell_3_adj_ratio'], ['GPT_3_adj_ratio']) p value: 0.0005585767062352498, z = -3.450969491991362, and human m = 0.048246321323660184 gpt m = 0.06338157955978276
#
#  Analysis of ratio of adv
# Significant difference in adv between (['Retell_1_adv_ratio'], ['GPT_1_adv_ratio']) p value: 1.3872191684450134e-10, z = 6.4172895626470225, and human m = 0.060923794140260445 gpt m = 0.03662089908788615
#
#  Analysis of ratio of adv
# Significant difference in adv between (['Retell_2_adv_ratio'], ['GPT_2_adv_ratio']) p value: 1.3218075659372677e-12, z = 7.092007071823524, and human m = 0.059100901776731676 gpt m = 0.03166226431623967
#
#  Analysis of ratio of adv
# Significant difference in adv between (['Retell_3_adv_ratio'], ['GPT_3_adv_ratio']) p value: 2.1227972273656014e-09, z = 5.988120537265356, and human m = 0.05915832454601722 gpt m = 0.030909892486242492
#
#  Analysis of ratio of pron
# Significant difference in pron between (['Retell_1_pron_ratio'], ['GPT_1_pron_ratio']) p value: 2.288568684563002e-07, z = 5.174226662661401, and human m = 0.11215790748328092 gpt m = 0.08238372876863774
#
#  Analysis of ratio of pron
# Significant difference in pron between (['Retell_2_pron_ratio'], ['GPT_2_pron_ratio']) p value: 3.290909363321941e-08, z = 5.525210429738354, and human m = 0.10970041346770386 gpt m = 0.07725243841130296
#
#  Analysis of ratio of pron
# Significant difference in pron between (['Retell_3_pron_ratio'], ['GPT_3_pron_ratio']) p value: 1.572682525013422e-08, z = 5.653439753325997, and human m = 0.112453904662347 gpt m = 0.07850276645830698
#
#  Analysis of ratio of det_con_prep
# Significant difference in det_con_prep between (['Retell_1_con_det_prep_ratio'], ['GPT_1_con_det_prep_ratio']) p value: 0.0012578974034409122, z = -3.2254160059456973, and human m = 0.20134803529272138 gpt m = 0.22388439019003523
#
#  Analysis of ratio of det_con_prep
# Significant difference in det_con_prep between (['Retell_2_con_det_prep_ratio'], ['GPT_2_con_det_prep_ratio']) p value: 0.01556233306806651, z = -2.4190212029672953, and human m = 0.2111269230792989 gpt m = 0.22940713816982755
#
#  Analysis of ratio of det_con_prep
# No difference in det_con_prep between (['Retell_3_con_det_prep_ratio'], ['GPT_3_con_det_prep_ratio']) p value: 0.21591365052492562, z = -1.237467290480252, and human m = 0.22040271415626528 gpt m = 0.23019206692524613
#
#  Analysis of ratio of prep
# Significant difference in prep between (['Retell_1_prep_ratio'], ['GPT_1_prep_ratio']) p value: 0.0015430832150541203, z = -3.166456691936653, and human m = 0.07835023387094064 gpt m = 0.09289703135303935
#
#  Analysis of ratio of prep
# Significant difference in prep between (['Retell_2_prep_ratio'], ['GPT_2_prep_ratio']) p value: 0.0035170845969571497, z = -2.918510119214245, and human m = 0.08160756370940778 gpt m = 0.09513401824536155
#
#  Analysis of ratio of prep
# No difference in prep between (['Retell_3_prep_ratio'], ['GPT_3_prep_ratio']) p value: 0.1400088982012619, z = -1.4757578929966886, and human m = 0.0879479341657057 gpt m = 0.09511365517548397

# %% [markdown]
# ### 1.7.1. Visualize Ratios

# %%
ratio_means = pd.DataFrame()
ratio_means['mean'] = [*count_ratio.mean()]
ratio_means['gen']= ['GPT_3', 'GPT_2','GPT_1', 'Retell_1','Retell_2','Retell_3','origin','GPT_3', 'GPT_2','GPT_1', 'Retell_1','Retell_2','Retell_3','origin','GPT_3', 'GPT_2','GPT_1', 'Retell_1','Retell_2','Retell_3','origin','GPT_3', 'GPT_2','GPT_1', 'Retell_1','Retell_2','Retell_3','origin','GPT_3', 'GPT_2','GPT_1', 'Retell_1','Retell_2','Retell_3','origin','GPT_3', 'GPT_2','GPT_1', 'Retell_1','Retell_2','Retell_3','origin','GPT_3', 'GPT_2','GPT_1', 'Retell_1','Retell_2','Retell_3','origin']
ratio_means['type']= ['noun','noun','noun','noun','noun','noun','noun','verb','verb','verb','verb','verb','verb','verb','adj','adj','adj','adj','adj','adj','adj','adv','adv','adv','adv','adv','adv','adv','con_det_prep','con_det_prep','con_det_prep','con_det_prep','con_det_prep','con_det_prep','con_det_prep','pron','pron','pron','pron','pron','pron','pron','prep','prep','prep','prep','prep','prep','prep']

# %% [markdown]
# #### 1.7.1.1. First Gen

# %%
first_gen = ratio_means.loc[ratio_means['gen'].isin(['GPT_1', 'Retell_1'])]

sns.lineplot(data=first_gen, x="type", y="mean", hue="gen").set(title='Ratio of Grammatical Categories')
# Out:
# [Text(0.5, 1.0, 'Ratio of Grammatical Categories')]

# %%
X = np.arange(7)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(X + 0.00, first_gen[first_gen['gen']=='Retell_1']['mean'], color = 'steelblue', width = 0.25, label ='Human')
ax.bar(X + 0.25, first_gen[first_gen['gen']=='GPT_1']['mean'], color = 'orange', width = 0.25, label = 'GPT')
ax.set_xticklabels(['','noun', 'verb', 'adj', 'adv', 'pron', 'con_det_prep', 'prep'])  # Set the x-tick labels
ax.set_title('Mean Ratio of Grammatical Categories in First Generation')
ax.legend()
# Out:
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_4725/1762402061.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['','noun', 'verb', 'adj', 'adv', 'pron', 'con_det_prep', 'prep'])  # Set the x-tick labels

# %% [markdown]
# #### 1.7.1.2. Second Generation

# %%
second_gen = ratio_means.loc[ratio_means['gen'].isin(['GPT_2', 'Retell_2'])]

sns.lineplot(data=second_gen, x="type", y="mean", hue="gen").set(title='Ratio of Grammatical Categories')
# Out:
# [Text(0.5, 1.0, 'Ratio of Grammatical Categories')]

# %%
X = np.arange(7)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(X + 0.00, second_gen[second_gen['gen']=='Retell_2']['mean'], color = 'steelblue', width = 0.25, label ='Human')
ax.bar(X + 0.25, second_gen[second_gen['gen']=='GPT_2']['mean'], color = 'orange', width = 0.25, label = 'GPT')
ax.set_xticklabels(['','noun', 'verb', 'adj', 'adv', 'pron', 'con_det_prep', 'prep'])  # Set the x-tick labels
ax.set_title('Mean Ratio of Grammatical Categories in Second Generation')
ax.legend()
# Out:
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_4725/1986436186.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['','noun', 'verb', 'adj', 'adv', 'pron', 'con_det_prep', 'prep'])  # Set the x-tick labels

# %% [markdown]
# #### 1.7.1.3. Third Generation

# %%
third_gen = ratio_means.loc[ratio_means['gen'].isin(['GPT_3', 'Retell_3'])]

sns.lineplot(data=third_gen, x="type", y="mean", hue="gen").set(title='Ratio of Grammatical Categories')
# Out:
# [Text(0.5, 1.0, 'Ratio of Grammatical Categories')]

# %%
X = np.arange(7)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(X + 0.00, third_gen[third_gen['gen']=='Retell_3']['mean'], color = 'steelblue', width = 0.25, label ='Human')
ax.bar(X + 0.25, third_gen[third_gen['gen']=='GPT_3']['mean'], color = 'orange', width = 0.25, label = 'GPT')
ax.set_xticklabels(['','noun', 'verb', 'adj', 'adv', 'pron', 'con_det_prep', 'prep'])  # Set the x-tick labels
ax.set_title('Mean Ratio of Grammatical Categories in Third Generation')
ax.legend()
# Out:
# /var/folders/l4/1xnf5c593754ph42_t0k68480000gq/T/ipykernel_4725/1464003046.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['','noun', 'verb', 'adj', 'adv', 'pron', 'con_det_prep', 'prep'])  # Set the x-tick labels

# %% [markdown]
# #### 1.7.1.4. All Together

# %%
sns.lineplot(data=ratio_means, x="type", y="mean", hue="gen")
# Out:
# <Axes: xlabel='type', ylabel='mean'>

# %%
human = ratio_means.loc[ratio_means['gen'].isin(['origin','Retell_1', 'Retell_2','Retell_3'])]
sns.lineplot(data=human, x="gen", y="mean", hue="type")
# Out:
# <Axes: xlabel='gen', ylabel='mean'>

# %%
gpt = ratio_means.loc[ratio_means['gen'].isin(['origin','GPT_1', 'GPT_2','GPT_3',])]

sns.lineplot(data=gpt, x="gen", y="mean", hue="type")
# Out:
# <Axes: xlabel='gen', ylabel='mean'>

# %% [markdown]
# ### 1.8. Calculate Verb-Adv and Noun-Adj Ratios

# %%
#Adverb-verb ratio
df['story_adv_to_verb_ratio']= df.tokenized_STORY_tag_adv/df.tokenized_STORY_tag_verb
df['Retell_1_adv_to_verb_ratio']= df.tokenized_Retell_1_tag_adv/df.tokenized_Retell_1_tag_verb
df['Retell_2_adv_to_verb_ratio']= df.tokenized_Retell_2_tag_adv/df.tokenized_Retell_2_tag_verb
df['Retell_3_adv_to_verb_ratio']= df.tokenized_Retell_3_tag_adv/df.tokenized_Retell_3_tag_verb
df['GPT_1_adv_to_verb_ratio']= df.tokenized_GPT_R1_tag_adv/df.tokenized_GPT_R1_tag_verb
df['GPT_2_adv_to_verb_ratio']= df.tokenized_GPT_R2_tag_adv/df.tokenized_GPT_R2_tag_verb
df['GPT_3_adv_to_verb_ratio']= df.tokenized_GPT_R3_tag_adv/df.tokenized_GPT_R3_tag_verb

#Adjective-noun ratio
df['story_adj_to_noun_ratio']= df.tokenized_STORY_tag_adj/df.tokenized_STORY_tag_noun
df['Retell_1_adj_to_noun_ratio']= df.tokenized_Retell_1_tag_adj/df.tokenized_Retell_1_tag_noun
df['Retell_2_adj_to_noun_ratio']= df.tokenized_Retell_2_tag_adj/df.tokenized_Retell_2_tag_noun
df['Retell_3_adj_to_noun_ratio']= df.tokenized_Retell_3_tag_adj/df.tokenized_Retell_3_tag_noun
df['GPT_1_adj_to_noun_ratio']= df.tokenized_GPT_R1_tag_adj/df.tokenized_GPT_R1_tag_noun
df['GPT_2_adj_to_noun_ratio']= df.tokenized_GPT_R2_tag_adj/df.tokenized_GPT_R2_tag_noun
df['GPT_3_adj_to_noun_ratio']= df.tokenized_GPT_R3_tag_adj/df.tokenized_GPT_R3_tag_noun

# %% [markdown]
# ### 1.8.2. Visualize Adb/Verb Adj/Noun Ratios

# %% [markdown]
# #### 1.8.2.1. Prepare dataset to visualize

# %%
verbnoun_ratio = df[['story_adv_to_verb_ratio',
 'Retell_1_adv_to_verb_ratio',
 'Retell_2_adv_to_verb_ratio',
 'Retell_3_adv_to_verb_ratio',
 'GPT_1_adv_to_verb_ratio',
 'GPT_2_adv_to_verb_ratio',
 'GPT_3_adv_to_verb_ratio',
 'story_adj_to_noun_ratio',
 'Retell_1_adj_to_noun_ratio',
 'Retell_2_adj_to_noun_ratio',
 'Retell_3_adj_to_noun_ratio',
 'GPT_1_adj_to_noun_ratio',
 'GPT_2_adj_to_noun_ratio',
 'GPT_3_adj_to_noun_ratio']]

# %%
verbnoun_means = pd.DataFrame()
verbnoun_means['mean'] = [*verbnoun_ratio.mean()]

# %%
verbnoun_means['gen'] = ['story','first','second','third','first','second','third','story','first','second','third','first','second','third']
verbnoun_means['type'] = ['origin','human','human','human','gpt','gpt','gpt','origin','human','human','human','gpt','gpt','gpt']
verbnoun_means['ratio'] = ['adv_verb','adv_verb','adv_verb','adv_verb','adv_verb','adv_verb','adv_verb','adj_noun','adj_noun','adj_noun','adj_noun','adj_noun','adj_noun','adj_noun']

# %%
# Adverb to Verb
verbnoun = verbnoun_means.loc[verbnoun_means['type'].isin(['human','gpt']) & verbnoun_means['ratio'].isin(['adv_verb']) ]

plot = sns.lineplot(data=verbnoun, x="gen", y="mean", hue="type")
plot.set_xlabel('Iteration')
plot.set(title='Adverb to Verb Ratio')
plot.set_ylabel('Mean')
plt.savefig('adverb_verb_ratio.pdf', dpi=300)
plt.show()

# %%
# Adjective to Noun 
verbnoun = verbnoun_means.loc[verbnoun_means['type'].isin(['human','gpt']) & verbnoun_means['ratio'].isin(['adj_noun']) ]

sns.lineplot(data=verbnoun, x="gen", y="mean", hue="type").set(title='Adjective to Noun Ratio (Significant at First)')
# Out:
# [Text(0.5, 1.0, 'Adjective to Noun Ratio (Significant at First)')]

# %%
a=[*df.Retell_1_adj_to_noun_ratio]
b=[*df.GPT_1_adj_to_noun_ratio]

statsmodels.stats.weightstats.ztest(a,b,value=0)
# Out:
# (1.5622340855771681, 0.1182328535357849)

# %%
a=[*df.Retell_2_adj_to_noun_ratio]
b=[*df.GPT_2_adj_to_noun_ratio]

statsmodels.stats.weightstats.ztest(a,b,value=0)
# Out:
# (-0.6216816366491781, 0.5341512287912816)

# %%
# adj to noun in third retelling

a=[*df.Retell_3_adj_to_noun_ratio]
b=[*df.GPT_3_adj_to_noun_ratio]

statsmodels.stats.weightstats.ztest(a,b,value=0)
# Out:
# (-0.7906226517421934, 0.42916422444668256)

# %% [markdown]
# ### 1.8.1. Statistical Test for Adv/verb Adj/noun ratios

# %%
# adv to verb in first retelling

a=[*df.Retell_1_adv_to_verb_ratio]
b=[*df.GPT_1_adv_to_verb_ratio]

statsmodels.stats.weightstats.ztest(a,b,value=0) 

statistics.mean(a)
statistics.mean(b)
# Out:
# 0.21471271783771784

# %%
# adv to verb in second retelling

a=[*df.Retell_2_adv_to_verb_ratio]
b=[*df.GPT_2_adv_to_verb_ratio]

statsmodels.stats.weightstats.ztest(a,b,value=0) 

statistics.mean(a)
statistics.mean(b)
# Out:
# 0.18559822600770876

# %%
# adv to verb in third retelling

a=[*df.Retell_3_adv_to_verb_ratio]
b=[*df.GPT_3_adv_to_verb_ratio]

statsmodels.stats.weightstats.ztest(a,b,value=0) 

statistics.mean(a)
statistics.mean(b)
# Out:
# 0.1741811419930081

# %% [markdown]
# Adv/verb:
#
#
# Retell 1 human mean =  0.29, gpt = 0.20 #significant
#
# Retell 2 human mean =  0.28, gpt = 0.16 #significant
#
# Retell 3 human mean =  0.27, gpt = 0.15 #significant
#
# Adj/noun
#
#
#
# Retell 1 human mean =  0.36, gpt = 0.28 #significant
#
# Retell 2 human mean =  0.30, gpt = 0.31
#
# Retell 3 human mean =  0.28, gpt = 0.30

# %% [markdown]
# ## 2. Pos-Tagging for Overall

# %% [markdown]
# This time all taggings are summed together regardless of their story

# %% [markdown]
# ### 2.1. Preprocess, Tag, Flatten

# %%
def small_post_tagger(dataframe):
    from nltk.tokenize import word_tokenize, sent_tokenize
   # stop_words = set(stopwords.words('english'))

    story_part_tags = []
    punc = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''

    for text in dataframe:
        for ele in text:
            if ele in punc:
                text = text.replace(ele, "")

        tokenized = word_tokenize(text)
        for i in tokenized:

            # Word tokenizers is used to find the words
            # and punctuation in a string
            wordsList = nltk.word_tokenize(i)

            # removing stop words from wordList
            wordsList = [w for w in wordsList] #if not w in stop_words]

            #  Using a Tagger. Which is part-of-speech
            # tagger or POS-tagger.
            tagged = nltk.pos_tag(wordsList)

            story_part_tags.append(tagged)
    return story_part_tags

# %%
# Tag small 
story_part_tags_short = small_post_tagger(df['STORY'])
Retell_1_tags_short = small_post_tagger(df['Retell_1'])
Retell_2_tags_short = small_post_tagger(df['Retell_2'])
Retell_3_tags_short = small_post_tagger(df['Retell_3'])
GPT_R1_tags_short = small_post_tagger(df['GPT_R1'])
GPT_R2_tags_short = small_post_tagger(df['GPT_R2'])
GPT_R3_tags_short = small_post_tagger(df['GPT_R3'])

# %%
#Flatten 
story_part_tags_short = [item for sublist in story_part_tags_short for item in sublist]
Retell_1_tags_short = [item for sublist in Retell_1_tags_short for item in sublist]
Retell_2_tags_short = [item for sublist in Retell_2_tags_short for item in sublist]
Retell_3_tags_short = [item for sublist in Retell_3_tags_short for item in sublist]
GPT_R1_tags_short = [item for sublist in GPT_R1_tags_short for item in sublist]
GPT_R2_tags_short = [item for sublist in GPT_R2_tags_short for item in sublist]
GPT_R3_tags_short = [item for sublist in GPT_R3_tags_short for item in sublist]

# %% [markdown]
# ### 2.2. Count Tags

# %%
def count_tags(mydata):
    counter_list=[]
    for i in mydata:
        counter_list.append(i[1])

    tag_counts = Counter(counter_list) 
    return tag_counts

# %%
# Short tags

story_part_tags_short = count_tags(story_part_tags_short)
GPT_R1_tag_counts_short = count_tags(GPT_R1_tags_short)
GPT_R2_tag_counts_short = count_tags(GPT_R2_tags_short)
GPT_R3_tag_counts_short = count_tags(GPT_R3_tags_short)

Retell_1_tag_counts_short = count_tags(Retell_1_tags_short)
Retell_2_tag_counts_short = count_tags(Retell_2_tags_short)
Retell_3_tag_counts_short = count_tags(Retell_3_tags_short)

# %% [markdown]
# ### Tags:

# %% [markdown]
# CC: It is the conjunction of coordinating
#
# CD: It is a digit of cardinal
#
# DT: It is the determiner
#
# EX: Existential
#
# FW: It is a foreign word
#
# IN: Preposition and conjunction
#
# JJ: Adjective
#
# JJR and JJS: Adjective and superlative
#
# LS: List marker
#
# MD: Modal
#
# NN: Singular noun
#
# NNS, NNP, NNPS: Proper and plural noun
#
# PDT: Predeterminer
#
# WRB: Adverb of wh
#
# WP$: Possessive wh
#
# WP: Pronoun of wh
#
# WDT: Determiner of wp
# VBZ: Verb
#
# VBP, VBN, VBG, VBD, VB: Forms of verbs
#
# UH: Interjection
#
#
# TO: To go
#
# RP: Particle
#
# RBS, RB, RBR: Adverb
#
# PRP, PRP$: Pronoun personal and professional

# %% [markdown]
# ### 2.3. Visualize

# %% [markdown]
# #### 2.3.1. First Retelling

# %%
#Human retellings
keys = Retell_1_tag_counts_short.keys()
plt.bar(keys, Retell_1_tag_counts_short.values(), color='orange', label='Human')

#GPT retellings 
keysgpt=GPT_R1_tag_counts_short.keys()
plt.bar(keysgpt, GPT_R1_tag_counts_short.values(),color='blue', label ='chatGPT',alpha = .5)
plt.xticks(rotation=45)  #rotate x labels prevent the overlap
plt.legend(loc='upper right')
plt.title('Comparison of First Retelling')
plt.show()

# %% [markdown]
# #### 2.3.2. Second Retelling

# %%
#Human retellings
keys = Retell_2_tag_counts_short.keys()
plt.bar(keys, Retell_2_tag_counts_short.values(), color='orange', label='Human')

#GPT retellings 
keysgpt=GPT_R2_tag_counts_short.keys()
plt.bar(keysgpt, GPT_R2_tag_counts_short.values(),color='blue', label ='chatGPT',alpha = .5)
plt.xticks(rotation=45)  #rotate x labels prevent the overlap
plt.legend(loc='upper right')
plt.title('Comparison of Second Retelling')
plt.show()

# %% [markdown]
# #### 2.3.3. Third Retelling

# %%
#Human retellings
keys = Retell_3_tag_counts_short.keys()
plt.bar(keys, Retell_3_tag_counts_short.values(), color='orange', label='Human')

#GPT retellings 
keysgpt=GPT_R3_tag_counts_short.keys()
plt.bar(keysgpt, GPT_R3_tag_counts_short.values(),color='blue', label ='chatGPT',alpha = .5)
plt.xticks(rotation=45)  #rotate x labels prevent the overlap
plt.legend(loc='upper right')
plt.title('Comparison of Third Retelling')
plt.show()

# %% [markdown]
# ## 3. Pos-tagging for Less Category
#
# Only noun,verb,adj,adv,pronoun, and conj/deter/prepositions

# %% [markdown]
# ### 3.1. Change data format

# %%
#Change data format
origin = pd.DataFrame.from_dict(story_part_tags_short,orient='index').reset_index()
origin.columns = ['pos', 'origin']

rt1 = pd.DataFrame.from_dict(Retell_1_tag_counts_short,orient='index').reset_index()
rt1.columns = ['pos', 'rt1']

rt2 = pd.DataFrame.from_dict(Retell_2_tag_counts_short,orient='index').reset_index()
rt2.columns = ['pos', 'rt2']

rt3 = pd.DataFrame.from_dict(Retell_3_tag_counts_short,orient='index').reset_index()
rt3.columns = ['pos', 'rt3']

gpt1 = pd.DataFrame.from_dict(GPT_R1_tag_counts_short,orient='index').reset_index()
gpt1.columns = ['pos', 'gpt1']

gpt2 = pd.DataFrame.from_dict(GPT_R2_tag_counts_short,orient='index').reset_index()
gpt2.columns = ['pos', 'gpt2']

gpt3 = pd.DataFrame.from_dict(GPT_R3_tag_counts_short,orient='index').reset_index()
gpt3.columns = ['pos', 'gpt3']

# %%
import functools as ft

#merge dfs
dfs = [origin,rt1,rt2,rt3,gpt1,gpt2,gpt3]
df_final = ft.reduce(lambda left, right: pd.merge(left, right, on='pos',how='outer'), dfs)

#if a category is missing replace with zero
df_final.fillna(0, inplace=True)

#change floats to integer
df_final = df_final.astype({'rt1': int, 'rt2':int, 'rt3':int, 'origin':int, 'gpt1':int, 'gpt2':int, 'gpt3':int})

# %% [markdown]
# ### 3.2. Merge relevant groups

# %%
pivot = pd.pivot_table(df_final,index='pos', aggfunc=np.sum).transpose()
pivot.columns
# Out:
# Index(['CC', 'CD', 'DT', 'EX', 'IN', 'JJ', 'JJR', 'JJS', 'MD', 'NN', 'NNP',
#        'NNS', 'PRP', 'PRP$', 'RB', 'RBR', 'TO', 'UH', 'VB', 'VBD', 'VBG',
#        'VBN', 'VBP', 'VBZ', 'WDT', 'WP', 'WP$', 'WRB'],
#       dtype='object', name='pos')

# %%
pivot['NUMBERS'] = pivot['CD']

# %%
pivot
# Out:
# pos      CC   CD    DT  EX    IN   JJ  JJR  JJS   MD    NN  ...   VBD  VBG  \
# gpt1    343   50   661   0   631  238    5    8   26  1570  ...   270  213
# gpt2    276   35   572   1   569  231    6    4   16  1346  ...   192  173
# gpt3    235   33   518   0   513  202    4    2   16  1232  ...   181  140
# origin  807  155  1694  19  1888  682   18   43  201  4037  ...  1098  399
# rt1     404   91   817  13   828  333    9   14   79  2079  ...   615  202
# rt2     278   61   612   9   611  228    6   10   46  1582  ...   439  137
# rt3     215   57   533   8   516  178    4    7   31  1216  ...   367  119
#
# pos     VBN  VBP  VBZ  WDT  WP  WP$  WRB  NUMBERS
# gpt1    228   10   56    5  32    0   17       50
# gpt2    205   12   67   10  41    0   19       35
# gpt3    191   13   68   11  41    0   16       33
# origin  605   35  101    7  71    1  114      155
# rt1     317    9   62   12  40    0   53       91
# rt2     235    7   35   10  31    0   39       61
# rt3     189    7   36    4  29    0   36       57
#
# [7 rows x 29 columns]

# %%
pivot['VERBS'] = pivot['VB'] + pivot['VBN'] + pivot['VBG']+pivot['VBZ'] + pivot['VBP'] +pivot['VBD']
pivot['NOUNS'] = pivot['NN'] + pivot['NNS'] + pivot['NNP']#+ pivot['NNPS']
pivot['ADJECTIVES'] = pivot['JJ'] + pivot['JJS'] + pivot['JJR']
pivot['ADVERBS'] = pivot['RB'] + pivot['RBR'] + pivot['WRB']
pivot['PRONOUN'] = pivot['PRP'] + pivot['PRP$'] + pivot['WP']+pivot['WP$']
pivot['PREPOSITION'] = pivot['IN'] 
pivot['CONJUNCTIONS_DETERMINERS_PREPOSITIONS'] =pivot['DT'] + pivot['IN'] + pivot['UH']+pivot['TO']+pivot['WDT']+pivot['EX']

# %%
pivot_short = pivot[['VERBS','NOUNS','ADJECTIVES','ADVERBS','PRONOUN','PREPOSITION','CONJUNCTIONS_DETERMINERS_PREPOSITIONS','NUMBERS']].reset_index()

# %%
pivot_short
# Out:
# pos   index  VERBS  NOUNS  ADJECTIVES  ADVERBS  PRONOUN  PREPOSITION  \
# 0      gpt1    860   1980         251      277      555          631
# 1      gpt2    724   1717         241      217      466          569
# 2      gpt3    662   1580         208      186      435          513
# 3    origin   2689   4960         743     1324     2265         1888
# 4       rt1   1410   2492         356      605     1139          828
# 5       rt2   1018   1874         244      432      818          611
# 6       rt3    829   1445         189      356      660          516
#
# pos  CONJUNCTIONS_DETERMINERS_PREPOSITIONS  NUMBERS
# 0                                     1492       50
# 1                                     1321       35
# 2                                     1197       33
# 3                                     4229      155
# 4                                     1979       91
# 5                                     1484       61
# 6                                     1250       57

# %%
Human = pivot_short[(pivot_short['index']=='origin') | (pivot_short['index']=='rt1') |( pivot_short['index']=='rt2')| (pivot_short['index']=='rt3')]
GPT = pivot_short[(pivot_short['index']=='origin') | (pivot_short['index']=='gpt1') |( pivot_short['index']=='gpt2')| (pivot_short['index']=='gpt3')]

# %%
Human
# Out:
# pos   index  VERBS  NOUNS  ADJECTIVES  ADVERBS  PRONOUN  PREPOSITION  \
# 3    origin   2689   4960         743     1324     2265         1888
# 4       rt1   1410   2492         356      605     1139          828
# 5       rt2   1018   1874         244      432      818          611
# 6       rt3    829   1445         189      356      660          516
#
# pos  CONJUNCTIONS_DETERMINERS_PREPOSITIONS  NUMBERS
# 3                                     4229      155
# 4                                     1979       91
# 5                                     1484       61
# 6                                     1250       57

# %%
GPT
# Out:
# pos   index  VERBS  NOUNS  ADJECTIVES  ADVERBS  PRONOUN  PREPOSITION  \
# 0      gpt1    860   1980         251      277      555          631
# 1      gpt2    724   1717         241      217      466          569
# 2      gpt3    662   1580         208      186      435          513
# 3    origin   2689   4960         743     1324     2265         1888
#
# pos  CONJUNCTIONS_DETERMINERS_PREPOSITIONS  NUMBERS
# 0                                     1492       50
# 1                                     1321       35
# 2                                     1197       33
# 3                                     4229      155

# %%
GPT = GPT.set_index(['index']).reindex(["origin","gpt1","gpt2","gpt3"]).reset_index()

# %%
Human.columns =['GENERATION', 'VERBS', 'NOUNS', 'ADJECTIVES', 'ADVERBS', 'PRONOUN','PREPOSITION',
       'CONJUNCTIONS_DETERMINERS_PREPOSITIONS','NUMBERS']
GPT.columns =['GENERATION', 'VERBS', 'NOUNS', 'ADJECTIVES', 'ADVERBS', 'PRONOUN','PREPOSITION',
       'CONJUNCTIONS_DETERMINERS_PREPOSITIONS','NUMBERS']

# %% [markdown]
# ### 3.3. Visualize

# %%
# Create some data
x = ['original', 'first','second','third']
y1 = Human['NOUNS']
y2 = GPT['NOUNS']

# Set the width of each bar
bar_width = 0.40

# Create the bar plot
fig, axs = plt.subplots(2, 3)
rects1 = axs[0,0].bar(x, y1, bar_width, label='Human')
rects2 = axs[0,0].bar([i + bar_width for i in range(len(x))], y2, bar_width, label='GPT')

# Add labels and a legend
axs[0,0].set_xlabel('Iteration',fontsize=16)
axs[0,0].set_ylabel('Count',fontsize=16)
axs[0,0].set_title('NOUNS',fontsize=18)
axs[0,0].set_xticks([i + bar_width/2 for i in range(len(x))])
axs[0,0].set_xticklabels(x, fontsize=14)
axs[0,0].legend(fontsize=12)

axs[0, 0].tick_params(axis='y', labelsize=12)
axs[0, 0].tick_params(axis='x', labelsize=12)

# Add text on top of each bar
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        axs[0,0].annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

# Create some data
x = ['original', 'first','second','third']
y1 = Human['VERBS']
y2 = GPT['VERBS']

# Set the width of each bar
bar_width = 0.40

# Create the bar plot
rects1 = axs[0,1].bar(x, y1, bar_width, label='Human')
rects2 = axs[0,1].bar([i + bar_width for i in range(len(x))], y2, bar_width, label='GPT')

# Add labels and a legend
axs[0,1].set_xlabel('Iteration',fontsize=16)
axs[0,1].set_ylabel('Count',fontsize=16)
axs[0,1].set_title('VERBS',fontsize=18)
axs[0,1].set_xticks([i + bar_width/2 for i in range(len(x))])
axs[0,1].set_xticklabels(x, fontsize=14)
axs[0,1].legend(fontsize=12)

axs[0, 1].tick_params(axis='y', labelsize=12)
axs[0, 1].tick_params(axis='x', labelsize=12)

# Add text on top of each bar
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        axs[0,1].annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)



# Create some data
x = ['original', 'first','second','third']
y1 = Human['ADJECTIVES']
y2 = GPT['ADJECTIVES']

# Set the width of each bar
bar_width = 0.40

# Create the bar plot
rects1 = axs[1,1].bar(x, y1, bar_width, label='Human')
rects2 = axs[1,1].bar([i + bar_width for i in range(len(x))], y2, bar_width, label='GPT')

# Add labels and a legend
axs[1,1].set_xlabel('Iteration',fontsize=16)
axs[1,1].set_ylabel('Count',fontsize=16)
axs[1,1].set_title('ADJECTIVES',fontsize=18)
axs[1,1].set_xticks([i + bar_width/2 for i in range(len(x))])
axs[1,1].set_xticklabels(x, fontsize=14)
axs[1,1].legend(fontsize=12)

axs[1, 1].tick_params(axis='y', labelsize=12)
axs[1, 1].tick_params(axis='x', labelsize=12)

# Add text on top of each bar
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        axs[1,1].annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

# Create some data
x = ['original', 'first','second','third']
y1 = Human['ADVERBS']
y2 = GPT['ADVERBS']

# Set the width of each bar
bar_width = 0.40

# Create the bar plot
rects1 = axs[1,0].bar(x, y1, bar_width, label='Human')
rects2 = axs[1,0].bar([i + bar_width for i in range(len(x))], y2, bar_width, label='GPT')

# Add labels and a legend
axs[1,0].set_xlabel('Iteration',fontsize=16)
axs[1,0].set_ylabel('Count',fontsize=16)
axs[1,0].set_title('ADVERBS',fontsize=18)
axs[1,0].set_xticks([i + bar_width/2 for i in range(len(x))])
axs[1,0].set_xticklabels(x, fontsize=14)
axs[1,0].legend(fontsize=12)

axs[1, 0].tick_params(axis='y', labelsize=12)
axs[1, 0].tick_params(axis='x', labelsize=12)

# Add text on top of each bar
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        axs[1,0].annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

fig.set_size_inches(16, 12)

plt.subplots_adjust(wspace=0.3, hspace=0.3)
fig.suptitle('Comparison of Grammatical Categories Through Iterations',fontsize=22)

# prepositions
x = ['original', 'first','second','third']
y1 = Human['PREPOSITION']
y2 = GPT['PREPOSITION']

# Set the width of each bar
bar_width = 0.40

# Create the bar plot
rects1 = axs[0,2].bar(x, y1, bar_width, label='Human')
rects2 = axs[0,2].bar([i + bar_width for i in range(len(x))], y2, bar_width, label='GPT')

# Add labels and a legend
axs[0,2].set_xlabel('Iteration',fontsize=16)
axs[0,2].set_ylabel('Count',fontsize=16)
axs[0,2].set_title('PREPOSITIONS',fontsize=18)
axs[0,2].set_xticks([i + bar_width/2 for i in range(len(x))])
axs[0,2].set_xticklabels(x, fontsize=14)
axs[0,2].legend(fontsize=12)

axs[0, 2].tick_params(axis='y', labelsize=12)
axs[0, 2].tick_params(axis='x', labelsize=12)

# Add text on top of each bar
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        axs[0,2].annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)


# pronouns
x = ['original', 'first','second','third']
y1 = Human['PRONOUN']
y2 = GPT['PRONOUN']

# Set the width of each bar
bar_width = 0.40

# Create the bar plot
rects1 = axs[1,2].bar(x, y1, bar_width, label='Human')
rects2 = axs[1,2].bar([i + bar_width for i in range(len(x))], y2, bar_width, label='GPT')

# Add labels and a legend
axs[1,2].set_xlabel('Iteration',fontsize=16)
axs[1,2].set_ylabel('Count',fontsize=16)
axs[1,2].set_title('PRONOUNS',fontsize=18)
axs[1,2].set_xticks([i + bar_width/2 for i in range(len(x))])
axs[1,2].set_xticklabels(x, fontsize=14)
axs[1,2].legend(fontsize=12)

axs[1, 2].tick_params(axis='y', labelsize=12)
axs[1, 2].tick_params(axis='x', labelsize=12)

# Add text on top of each bar
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        axs[1,2].annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')
        


autolabel(rects1)
autolabel(rects2)

# Show the plot
plt.savefig('all_count_plot.pdf', dpi=300)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.lineplot(data=ratio_means, x="type", y="mean", hue="gen")
ratio_means
# Out:
#         mean       gen          type
# 0   0.245693     GPT_3          noun
# 1   0.246789     GPT_2          noun
# 2   0.238167     GPT_1          noun
# 3   0.208918  Retell_1          noun
# 4   0.217367  Retell_2          noun
# 5   0.202079  Retell_3          noun
# 6   0.190876    origin          noun
# 7   0.178897     GPT_3          verb
# 8   0.173282     GPT_2          verb
# 9   0.182107     GPT_1          verb
# 10  0.194942  Retell_1          verb
# 11  0.190907  Retell_2          verb
# 12  0.198246  Retell_3          verb
# 13  0.186473    origin          verb
# 14  0.063382     GPT_3           adj
# 15  0.066813     GPT_2           adj
# 16  0.060630     GPT_1           adj
# 17  0.055498  Retell_1           adj
# 18  0.053544  Retell_2           adj
# 19  0.048246  Retell_3           adj
# 20  0.056220    origin           adj
# 21  0.030910     GPT_3           adv
# 22  0.031662     GPT_2           adv
# 23  0.036621     GPT_1           adv
# 24  0.060924  Retell_1           adv
# 25  0.059101  Retell_2           adv
# 26  0.059158  Retell_3           adv
# 27  0.064145    origin           adv
# 28  0.230192     GPT_3  con_det_prep
# 29  0.229407     GPT_2  con_det_prep
# 30  0.223884     GPT_1  con_det_prep
# 31  0.201348  Retell_1  con_det_prep
# 32  0.211127  Retell_2  con_det_prep
# 33  0.220403  Retell_3  con_det_prep
# 34  0.214278    origin  con_det_prep
# 35  0.078503     GPT_3          pron
# 36  0.077252     GPT_2          pron
# 37  0.082384     GPT_1          pron
# 38  0.112158  Retell_1          pron
# 39  0.109700  Retell_2          pron
# 40  0.112454  Retell_3          pron
# 41  0.113461    origin          pron
# 42  0.095114     GPT_3          prep
# 43  0.095134     GPT_2          prep
# 44  0.092897     GPT_1          prep
# 45  0.078350  Retell_1          prep
# 46  0.081608  Retell_2          prep
# 47  0.087948  Retell_3          prep
# 48  0.090234    origin          prep

# %% [markdown]
# ## 3.4. Visualize Numbers

# %%
x = ['original', 'first','second','third']
y1 = Human['NUMBERS']
y2 = GPT['NUMBERS']

fig, ax = plt.subplots()



# Create the bar plot
rects1 = ax.bar(x, y1, bar_width, label='Human')
rects2 = ax.bar([i + bar_width for i in range(len(x))], y2, bar_width, label='GPT')

# Add labels and a legend
ax.set_xlabel('Generation')
ax.set_ylabel('Count')
ax.set_title('NUMBERS')
ax.set_xticks([i + bar_width/2 for i in range(len(x))])
ax.set_xticklabels(x)
ax.legend()

# Add text on top of each bar
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)
